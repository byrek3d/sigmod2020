# %%
import os
import numpy as np
import json
import pandas as pd
import itertools
from tqdm import tqdm
import nltk
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
import re

# %%
def create_dataframe(dataset_path, source, columns_df):
    """Function used to create a Pandas DataFrame containing specifications page titles

    Reads products specifications from the file system ("dataset_path" variable in the main function) and creates a Pandas DataFrame where each row is a
    specification. The columns are 'source' (e.g. www.sourceA.com), 'spec_number' (e.g. 1) and the 'page title'. Note that this script will consider only
    the page title attribute for simplicity.

    Args:
        dataset_path (str): The path to the dataset

    Returns:
        df (pd.DataFrame): The Pandas DataFrame containing specifications and page titles
    """

    print('>>> Creating dataframe...\n')

    progressive_id = 0
    progressive_id2row_df = {}
    for specification in os.listdir(os.path.join(dataset_path, source)):
        specification_number = specification.replace('.json', '')
        specification_id = '{}//{}'.format(source, specification_number)
        with open(os.path.join(dataset_path, source, specification)) as specification_file:
            specification_data = json.load(specification_file)
            weight = specification_data.get("weight")
            title = specification_data.get("<page title>")
            row = (specification_id, title, weight)
            progressive_id2row_df.update({progressive_id: row})
            progressive_id += 1
    df = pd.DataFrame.from_dict(progressive_id2row_df, orient='index', columns=columns_df)
    print('>>> Dataframe created successfully!\n')
    return df

# %%
df = create_dataframe('../datasets/unlabeled/2013_camera_specs', "www.alibaba.com",["spec_id", "<page title>", "weight"])
# Out:
# >>> Creating dataframe...
#
# >>> Dataframe created successfully!

# %%
df = df.rename(columns = {"<page title>" : "page_title"})

# %% [markdown]
# ### Weight

# %%
df[df['weight'].notnull()]
# Out:
#                      spec_id  \
# 2     www.alibaba.com//23684
# 3     www.alibaba.com//24141
# 4     www.alibaba.com//22996
# 5     www.alibaba.com//24511
# 6     www.alibaba.com//35300
# ...                      ...
# 7960  www.alibaba.com//34210
# 7962  www.alibaba.com//29588
# 7968  www.alibaba.com//35051
# 7969  www.alibaba.com//24210
# 7970  www.alibaba.com//35401
#
#                                              page_title            weight
# 2     Slr Portable Camera Inner Partition Padded Pro...            0.19KG
# 3     Cheap Outdoor Ip Camera Ds-2cd2632f-is Hikvisi...             1200g
# 4     Hikvision Ds-2cd2532f-is Ir 3mp Mini Dome Hd 1...  600 g (1.32 lbs)
# 5     2colors Fashion Abs Plastic Dslr Slr Hard Comp...            0.09Kg
# 6     Hikvision Ir Cctv Camera 3mp Bullet Ip Camera ...             1200g
# ...                                                 ...               ...
# 7960  Mini Camera Ds-2cd2532f-i 3 Megapixel Dome Hik...  600 g (1.32 lbs)
# 7962  Ds-2cd2012-i Network Video Server Hikvision Ip...    500g (1.1 lbs)
# 7968  Genuine For Gopro Hero 3 3+plus Underwater Wat...          0.1KG/pc
# 7969  Ds-2cd3332-i Ip Network Camera Hikvision Weath...    670g (1.5 lbs)
# 7970  Sd6a220-hn 2mp Ir Speed Dome Dahua Ptz Camera ...            6.75kg
#
# [3099 rows x 3 columns]

# %%
def parse_weight(value):
    if (isinstance(value, list)):
        return float("NaN")
        

    if pd.isna(value):
        return value
    else:
        value = value.lower()
       
        match1 = re.search('(approx.|)(\d*\,\d+|\d*\.\d+|\d+)( g|g| kg|kg|lbs| lbs)', str(value))
        if match1 is None: 
            return float("NaN")


        to_convert= match1.group(2).replace(" ","").replace(",",".")
        metric= match1.group(3).replace(" ","")
        converted=float("NaN")
        if metric == "oz":
            converted= int(round(float(to_convert) * 28.35))
        elif metric == "lbs":
            converted= int(round(float(to_convert) * 454))
        elif metric == "kg":
            converted= int(round(float(to_convert) * 1000))
        else:
            converted= int(round(float(to_convert)))
        return converted

# %%
df["weight"] = df["weight"].apply(parse_weight)

# %% [markdown]
# ## Title

# %%
df.head()
# Out:
#                   spec_id                                         page_title  \
# 0  www.alibaba.com//37297  New Arrival Metal Case 1.3mp Vandalproof Ip Ca...
# 1  www.alibaba.com//29289  New Design In 2014 Camera Case For Iphone - Bu...
# 2  www.alibaba.com//23684  Slr Portable Camera Inner Partition Padded Pro...
# 3  www.alibaba.com//24141  Cheap Outdoor Ip Camera Ds-2cd2632f-is Hikvisi...
# 4  www.alibaba.com//22996  Hikvision Ds-2cd2532f-is Ir 3mp Mini Dome Hd 1...
#
#    weight
# 0     NaN
# 1     NaN
# 2   190.0
# 3  1200.0
# 4   600.0

# %%
stopWords = set(['itself', 'down', 'by', 'with', 'doesn', 'wouldn', 'other', 'ours', 'of', 'then', 'where', 'don', 'these', 'nor', 'she', "should've", 'won', 'ma', 'from', 'had', "you're", 'our', 'did', 'them', 'too', 'her', 'that', 'haven', 'after', "you'll", 'hers', 'because', 'yourself', 'against', 'mightn', 'as', 'll', 'whom', 'how', 'couldn', 'further', 'aren', "you'd", 'and', 'needn', "couldn't", 'those', 'to', "doesn't", "weren't", 'both', 'ourselves', 'in', 'which', 'yours', 'under', 'some', 'what', 'during', 'before', "needn't", "shan't", 'here', 'having', 'hasn', 'your', "hasn't", 'between', 'me', "she's", 'into', 'all', 'at', 'shan', 'who', 'o', 'an', 'very', 'can', 'you', 'shouldn', 'such', 'but', 'do', 'out', 'am', "shouldn't", 'above', 'wasn', 'or', 'were', 'own', 'didn', "you've", 'on', 'will', 'my', 'it', 'have', 'once', 'only', 'been', 'themselves', 'his', 'be', "mightn't", 'they', 'not', 'so', 'up', 'any', 'most', 'has', 'myself', 't', 'yourselves', 'isn', "it's", 'y', 'm', 'now', 'until', 're', 'there', 'their', 'mustn', "mustn't", 'again', 'being', 'hadn', 'doing', 'just', 'no', 'if', 've', "wasn't", "won't", 'we', 'below', 'does', 'more', 'this', 'should', "isn't", 'ain', "don't", 'i', "haven't", 'than', "didn't", 'are', 'about', 'off', 'him', 'for', 'few', "wouldn't", 'was', 'weren', 'why', 'he', "that'll", 'd', 'the', 'its', 'a', 'each', 'is', 'while', "aren't", 'when', 'theirs', 'same', 's', 'himself', 'herself', "hadn't", 'through', 'over'])

# %%
punctuation = "!#$%&'()*+,-./:;<=>?@[\]^_`{|}~€£¥₹₽"

# %%
def replace_punctuation(word):
    return ''.join(c for c in word if c not in punctuation)

# %%
df["page_title"] = df["page_title"].apply(lambda x : [i.lower() for i in list(map(lambda y: replace_punctuation(y), word_tokenize(x))) if i and i.lower() not in stopWords])

# %% [markdown]
# ## Modelwords

# %%
pattern = re.compile("(\S*[A-Za-z]\S*[0-9]\S*|\S*[0-9]\S*[A-Za-z]\S*)")

# %%
brands = ['360fly', 'acer', 'achiever', 'acorn', 'actionpro', 'activeon', 'aee', 'agfa', 'agfaphoto', 'aiptek', 'akaso', 'alpine', 'alpine', 'amkov', 'andoer', 'annke', 'ansco', 'apeman', 'apex', 'apple', 'archos', 'argus', 'arlo', 'arri', 'axis', 'bell', 'benq', 'blackmagic', 'blackmagic', 'bosch', 'bower', 'brinno', 'brookstone', 'browning', 'cambo', 'campark', 'canon', 'carl', 'casio', 'celestron', 'chinon', 'cisco', 'cobra', 'coleman', 'concord', 'contax', 'contour', 'covert', 'craig', 'crayola', 'creative', 'creative', 'crosstour', 'crumpler', 'datavideo', 'delkin', 'dell', 'digitrex', 'discovery', 'disney', 'dji', 'd-link', 'domke', 'dörr', 'dragon', 'dxg', 'dxo', 'easypix', 'elecom', 'elmo', 'emerson', 'energizer', 'epson', 'fisher-price', 'flip', 'flir', 'foscam', 'fotoman', 'fotopro', 'fuji', 'fujifilm', 'fujinon', 'garmin', 'gateway', 'godox', 'goodmans', 'google', 'gopro', 'grundig', 'hahnel', 'hamilton', 'hasselblad', 'hello', 'herofiber', 'hitachi', 'holga', 'horseman', 'hoya', 'htc', 'huawei', 'ikelite', 'ilford', 'impossible', 'innovage', 'insignia', 'insta360', 'intel', 'intova', 'ion', 'iris', 'jazz', 'jenoptik', 'jjrc', 'jvc', 'kaiser', 'kenko', 'keyence', 'king', 'kitvision', 'kodak', 'konica', 'kyocera', 'leaf', 'lego', 'leica', 'lenovo', 'lexibook', 'linhof', 'liquid', 'little', 'logitech', 'lomography', 'lowepro', 'ltl', 'lytro', 'maginon', 'magnavox', 'mamiya', 'manfrotto', 'marshall', 'marumi', 'mattel', 'maxell', 'meade', 'medion', 'memorex', 'mercury', 'metz', 'microsoft', 'microtek', 'midland', 'minolta', 'minox', 'monster', 'motorola', 'moultrie', 'mustek', 'nabi', 'neewer', 'nest', 'netgear', 'night', 'nikkon', 'nikkor', 'nikon', 'nilox', 'nintendo', 'nippon', 'nokia', 'norcent', 'olympus', 'optech', 'ordro', 'oregon', 'packard', 'palm', 'panasonic', 'parrot', 'pelco', 'pentacon', 'pentax', 'phase', 'philips', 'philips', 'phoenix', 'pioneer', 'playskool', 'polaroid', 'polarpro', 'praktica', 'premier', 'promaster', 'proscan', 'pyle', 'radioshack', 'raymarine', 'raynox', 'rca', 'ricoh', 'ring', 'rode', 'rokinon', 'rollei', 'ryobi', 'sakar', 'samsung', 'sandisk', 'sanyo', 'schneider', 'schneider', 'schneider', 'scosche', 'seasea', 'sealife', 'sharp', 'sharper', 'sigma', 'sinar', 'sipix', 'sjcam', 'sony', 'soocoo', 'stealth', 'superheadz', 'svp', 'swann', 'tamrac', 'tamron', 'technika', 'tenba', 'think', 'thule', 'tokina', 'tomy', 'toshiba', 'transcend', 'traveler', 'trust', 'verbatim', 'vibe', 'victure', 'vistaquest', 'vivitar', 'voigtländer', 'vtech', 'vupoint', 'walimex', 'wyze', 'xiaomi', 'xit', 'xtreme', 'yashica', 'zeiss']

# %%
def clean_mp_mm_g_oz(value):
    if not isinstance(value, list) and pd.isna(value):
        return np.nan
    regex = r"[0-9]+mm(\n|)"
    regex1 = r"[0-9]+m$"
    regex2 = r"[0-9]+mp(\n|)"
    regex3 = r"[0-9]+oz"
    regex4 = r"[0-9]+g(\n|)$"
    repl = value
    for e in repl:
        if bool(re.match(regex, e)) or bool(re.match(regex2, e)) or bool(re.match(regex3, e)) or bool(re.match(regex4, e)) or bool(re.match(regex1, e)):
            repl.remove(e)
    return repl

# %%
df["page_title_model"] = df["page_title"].apply(lambda line : list(set(filter(lambda word : bool(pattern.match(word)),line)))).apply(lambda row : clean_mp_mm_g_oz(row))

# %%
df.head()
# Out:
#                   spec_id                                         page_title  \
# 0  www.alibaba.com//37297  [new, arrival, metal, case, 13mp, vandalproof,...
# 1  www.alibaba.com//29289  [new, design, 2014, camera, case, iphone, buy,...
# 2  www.alibaba.com//23684  [slr, portable, camera, inner, partition, padd...
# 3  www.alibaba.com//24141  [cheap, outdoor, ip, camera, ds2cd2632fis, hik...
# 4  www.alibaba.com//22996  [hikvision, ds2cd2532fis, ir, 3mp, mini, dome,...
#
#    weight             page_title_model
# 0     NaN                           []
# 1     NaN                           []
# 2   190.0                           []
# 3  1200.0               [ds2cd2632fis]
# 4   600.0  [1080p, ds2cd2532fis, ip66]

# %%
def jaccard_similarity(query, document):
    intersection = set(query).intersection(set(document))
    union = set(query).union(set(document))
    return len(intersection)/len(union)

# %%
def get_merged_df(dataframe):
    merged = dataframe
    merged = (merged.merge(merged, on=merged.assign(key_col=1)['key_col'], suffixes=('', '_right'))
 .query('spec_id < spec_id_right') # filter out joins on the same row and keep unique combinations
 .reset_index(drop=True))
    merged.drop(columns = ["key_0"], axis = 1, inplace=True)
    merged.rename(columns = {"spec_id" : "left_spec_id", "spec_id_right" : "right_spec_id"}, inplace=True)
    merged.reset_index(inplace=True, drop=True)
    return merged

# %%
merged = get_merged_df(df)

# %%
small_merged = merged#.sample(frac = 0.001)

# %%
len(small_merged)
# Out:
# 317206

# %%
small_merged.head()
# Out:
#              left_spec_id                                         page_title  \
# 0  www.alibaba.com//35400  [cheap, best, selling, dslr, digital, camera, ...
# 1  www.alibaba.com//35400  [cheap, best, selling, dslr, digital, camera, ...
# 2  www.alibaba.com//35400  [cheap, best, selling, dslr, digital, camera, ...
# 3  www.alibaba.com//35400  [cheap, best, selling, dslr, digital, camera, ...
# 4  www.alibaba.com//35400  [cheap, best, selling, dslr, digital, camera, ...
#
#    weight             page_title_model           right_spec_id  \
# 0     NaN  [d5100, d7000, d700, d2000]  www.alibaba.com//37522
# 1     NaN  [d5100, d7000, d700, d2000]  www.alibaba.com//37025
# 2     NaN  [d5100, d7000, d700, d2000]  www.alibaba.com//37274
# 3     NaN  [d5100, d7000, d700, d2000]  www.alibaba.com//37023
# 4     NaN  [d5100, d7000, d700, d2000]   www.alibaba.com//6942
#
#                                     page_title_right  weight_right  \
# 0  [camera, pouch, bag, dslr, slr, compact, digit...           NaN
# 1  [hikvision, camaras, cctv, 3, megapixel, mini,...         500.0
# 2  [dslr, slr, underwater, camera, waterproof, ca...           NaN
# 3  [viewerframe, mode, ip, camera, ds2cd2632fis, ...        1200.0
# 4  [support, 32g, alarm, trigger, local, memory, ...           NaN
#
#   page_title_model_right
# 0                  [gx1]
# 1           [ds2cd2132i]
# 2                [nex5n]
# 3         [ds2cd2632fis]
# 4               [hfwo14]

# %%
def determine_match(row):
    score = 0
    
    if pd.isna(row["weight"]) or pd.isna(row["weight_right"]):
        target = 0.5
    else:
        target = 0.8
    
    
    
    weight_l = row["weight"]
    weight_r = row["weight_right"]
    page_title_l = row["page_title"]
    page_title_r = row["page_title_right"]
    model_l = row["page_title_model"]
    model_r = row["page_title_model_right"]
    
    weight_weight = 0.6
    
    if model_l != [] and model_r != []:
        model_count = 0
        for spec1 in model_l:
            for spec2 in model_r:
                if spec1 == spec2: 
                    return True
        return False
    
    if not pd.isna(weight_l) and not pd.isna(weight_r) and abs(weight_l - weight_r) <= 2:
        score += weight_weight


    if page_title_l != [] and page_title_r != []:
        score += jaccard_similarity(page_title_l, page_title_r)
                    
    return score > target

# %%
tqdm.pandas()
# Out:
# /Users/gfotiadis/anaconda3/lib/python3.7/site-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
labels = []
labels.append(list(small_merged.progress_apply(determine_match, axis = 1)))
labels = sum(labels, [])
small_merged["label"] = labels
# Out:
# 100%|██████████| 317206/317206 [00:50<00:00, 6225.04it/s]

# %%
small_merged[small_merged["label"] == True]
# Out:
#                   left_spec_id  \
# 416     www.alibaba.com//34221
# 427     www.alibaba.com//34221
# 610     www.alibaba.com//34221
# 676     www.alibaba.com//37522
# 1437    www.alibaba.com//35197
# ...                        ...
# 317162  www.alibaba.com//29494
# 317170  www.alibaba.com//29494
# 317176  www.alibaba.com//29494
# 317191  www.alibaba.com//29494
# 317194  www.alibaba.com//29494
#
#                                                page_title  weight  \
# 416     [top, 1, camera, china, hikvision, ds2cd2032i,...   500.0
# 427     [top, 1, camera, china, hikvision, ds2cd2032i,...   500.0
# 610     [top, 1, camera, china, hikvision, ds2cd2032i,...   500.0
# 676     [camera, pouch, bag, dslr, slr, compact, digit...     NaN
# 1437    [hikvision, cctv, camera, housing, mini, ir, b...   500.0
# ...                                                   ...     ...
# 317162  [fashion, camera, bags, buy, camera, case, wat...     NaN
# 317170  [fashion, camera, bags, buy, camera, case, wat...     NaN
# 317176  [fashion, camera, bags, buy, camera, case, wat...     NaN
# 317191  [fashion, camera, bags, buy, camera, case, wat...     NaN
# 317194  [fashion, camera, bags, buy, camera, case, wat...     NaN
#
#        page_title_model           right_spec_id  \
# 416        [ds2cd2032i]  www.alibaba.com//36126
# 427        [ds2cd2032i]  www.alibaba.com//37832
# 610        [ds2cd2032i]  www.alibaba.com//36396
# 676               [gx1]  www.alibaba.com//37708
# 1437       [ds2cd2012i]  www.alibaba.com//37820
# ...                 ...                     ...
# 317162               []  www.alibaba.com//29763
# 317170               []  www.alibaba.com//37708
# 317176               []  www.alibaba.com//37238
# 317191               []  www.alibaba.com//29595
# 317194               []  www.alibaba.com//35009
#
#                                          page_title_right  weight_right  \
# 416     [surveillance, hikvision, ds2cd2032i, hikvisio...         500.0
# 427     [1080p, exmor, cmos, ip, camera, hikvision, 3,...         500.0
# 610     [ds2cd2012i, similiar, hikvision, 3mp, ir, bul...         500.0
# 676     [fashion, digital, camera, case, buy, digital,...           NaN
# 1437    [ds2cd2012i, best, cheap, hd, video, camera, i...         500.0
# ...                                                   ...           ...
# 317162  [fashion, cool, camera, bag, waterproof, polye...           NaN
# 317170  [fashion, digital, camera, case, buy, digital,...           NaN
# 317176  [neoprene, digital, camera, pouch, buy, waterp...           NaN
# 317191  [1112, waterproof, pu, digital, camera, case, ...           NaN
# 317194  [camera, bag, buy, camera, bag, digital, camer...           NaN
#
#            page_title_model_right  label
# 416            [ds2cd2032i, ip66]   True
# 427     [1080p, ds2cd2032i, ip66]   True
# 610      [ds2cd2032i, ds2cd2012i]   True
# 676                            []   True
# 1437                 [ds2cd2012i]   True
# ...                           ...    ...
# 317162                         []   True
# 317170                         []   True
# 317176                         []   True
# 317191                         []   True
# 317194                         []   True
#
# [8331 rows x 9 columns]

# %%
len(small_merged[small_merged["label"] == True]) / len(small_merged)
# Out:
# 0.02626368984193237

# %%
small_merged = small_merged[small_merged["label"] == True]
cols = ["left_spec_id", "right_spec_id"]
small_merged = small_merged[cols]
small_merged.to_csv("alibaba.csv", index = False)
# Out:
#   0%|          | 89506/31772406 [00:41<1:45:37, 4998.92it/s]

# %% [markdown]
# # Ebay

# %%
def create_dataframe_ebay(dataset_path, source, columns_df):
    """Function used to create a Pandas DataFrame containing specifications page titles

    Reads products specifications from the file system ("dataset_path" variable in the main function) and creates a Pandas DataFrame where each row is a
    specification. The columns are 'source' (e.g. www.sourceA.com), 'spec_number' (e.g. 1) and the 'page title'. Note that this script will consider only
    the page title attribute for simplicity.

    Args:
        dataset_path (str): The path to the dataset

    Returns:
        df (pd.DataFrame): The Pandas DataFrame containing specifications and page titles
    """

    print('>>> Creating dataframe...\n')

    progressive_id = 0
    progressive_id2row_df = {}
    for specification in os.listdir(os.path.join(dataset_path, source)):
        specification_number = specification.replace('.json', '')
        specification_id = '{}//{}'.format(source, specification_number)
        with open(os.path.join(dataset_path, source, specification)) as specification_file:
            specification_data = json.load(specification_file)
            weight = specification_data.get("weight")
            brand = specification_data.get("brand")
            mp = specification_data.get("megapixels")
            scr = specification_data.get("screen size")
            title = specification_data.get("<page title>")
            row = (specification_id, title, brand, mp, scr, weight)
            progressive_id2row_df.update({progressive_id: row})
            progressive_id += 1
    df = pd.DataFrame.from_dict(progressive_id2row_df, orient='index', columns=columns_df)
    print('>>> Dataframe created successfully!\n')
    return df

# %%
df = create_dataframe_ebay('../datasets/unlabeled/2013_camera_specs', "www.ebay.com",["spec_id", "<page title>", "brand", "megapixels", "screen size", "weight"])
# Out:
# >>> Creating dataframe...
#
# >>> Dataframe created successfully!

# %%
df = df.rename(columns = {"<page title>" : "page_title"})

# %%
df.head()
# Out:
#                spec_id                                         page_title  \
# 0  www.ebay.com//56784  Sony Cyber Shot DSC S85 4 0 MP Digital Camera ...
# 1  www.ebay.com//24141  Olympus VH 210 14 0 MP Digital Camera Purple 4...
# 2  www.ebay.com//59471  New Canon PowerShot 130 Is ELPH 16MP Digital C...
# 3  www.ebay.com//47195  Canon EOS 10D 6 3MP Digital SLR Camera Body 10...
# 4  www.ebay.com//41942  Lumix Panasonic AVCHD Lite DMC TS1 12 MP Digit...
#
#        brand megapixels screen size weight
# 0       Sony     4.0 MP        1.8"   None
# 1    Olympus    14.0 MP        None   None
# 2      Canon    16.0 MP          3"   None
# 3      Canon     6.3 MP        1.8"   None
# 4  Panasonic    12.0 MP        None   None

# %%
df.isna().sum()
# Out:
# spec_id            0
# page_title         0
# brand            290
# megapixels      1731
# screen size     3030
# weight         13719
# dtype: int64

# %% [markdown]
# ### megapixels

# %%
df[df['megapixels'].notnull()]
# Out:
#                    spec_id                                         page_title  \
# 0      www.ebay.com//56784  Sony Cyber Shot DSC S85 4 0 MP Digital Camera ...
# 1      www.ebay.com//24141  Olympus VH 210 14 0 MP Digital Camera Purple 4...
# 2      www.ebay.com//59471  New Canon PowerShot 130 Is ELPH 16MP Digital C...
# 3      www.ebay.com//47195  Canon EOS 10D 6 3MP Digital SLR Camera Body 10...
# 4      www.ebay.com//41942  Lumix Panasonic AVCHD Lite DMC TS1 12 MP Digit...
# ...                    ...                                                ...
# 14268  www.ebay.com//58832  GE A830 8 0 MP Digital Camera Silver 081002701...
# 14269  www.ebay.com//24210        Ximea USB 3 0 4 2 Mpix Colour Camera | eBay
# 14271  www.ebay.com//44811  Nikon Coolpix P330 12 2 MP Digital Camera Blac...
# 14272  www.ebay.com//48131  Olympus Camedia Camera C3000 C 3000 U1 05 0050...
# 14273  www.ebay.com//54112  Nikon Coolpix L24 14 0 MP Digital Camera 18208...
#
#            brand megapixels screen size weight
# 0           Sony     4.0 MP        1.8"   None
# 1        Olympus    14.0 MP        None   None
# 2          Canon    16.0 MP          3"   None
# 3          Canon     6.3 MP        1.8"   None
# 4      Panasonic    12.0 MP        None   None
# ...          ...        ...         ...    ...
# 14268         GE     8.0 MP        2.5"   None
# 14269      Ximea        4.2        None    32g
# 14271      Nikon    12.2 MP          3"   None
# 14272    Olympus     3.3 MP        1.8"   None
# 14273      Nikon    14.0 MP          3"   None
#
# [12543 rows x 6 columns]

# %%
def parse_megapixels(value):
    if(isinstance(value, list)):
        
        value=value[0]
    if pd.isna(value):
        return value
    else:
        match1 = re.search('(\d*\,\d+|\d*\.\d+|\d+)( MP|)', str(value))
        if match1 is None: 
            return float("NaN")


        return (match1.group(1).replace(",","."))

# %%
df["megapixels"] = df["megapixels"].apply(parse_megapixels)

# %%
df.head()
# Out:
#                spec_id                                         page_title  \
# 0  www.ebay.com//56784  Sony Cyber Shot DSC S85 4 0 MP Digital Camera ...
# 1  www.ebay.com//24141  Olympus VH 210 14 0 MP Digital Camera Purple 4...
# 2  www.ebay.com//59471  New Canon PowerShot 130 Is ELPH 16MP Digital C...
# 3  www.ebay.com//47195  Canon EOS 10D 6 3MP Digital SLR Camera Body 10...
# 4  www.ebay.com//41942  Lumix Panasonic AVCHD Lite DMC TS1 12 MP Digit...
#
#        brand megapixels screen size weight
# 0       Sony        4.0        1.8"   None
# 1    Olympus       14.0        None   None
# 2      Canon       16.0          3"   None
# 3      Canon        6.3        1.8"   None
# 4  Panasonic       12.0        None   None

# %% [markdown]
# ### Weight

# %%
df[df['weight'].notnull()]
# Out:
#                    spec_id                                         page_title  \
# 17     www.ebay.com//46784  Olympus Stylus 50x Zoom SP 100 HD Digital Came...
# 19     www.ebay.com//47896  Nikon D70 6 1 MP Digital SLR Camera Black Body...
# 60     www.ebay.com//60120  Canon EOS Rebel T3 SLR Digital Camera w 18 55m...
# 75     www.ebay.com//44886  Canon EOS Rebel T5 Digital SLR Camera Body EF ...
# 129    www.ebay.com//53928  Nikon D60 with DX 18 55mm VR Lens Nikon SB 600...
# ...                    ...                                                ...
# 14143  www.ebay.com//54846  Sony Alpha SLT A58 Digital SLR Camera Body 18 ...
# 14186  www.ebay.com//55979  Sony Cyber Shot 63X Super Zoom DSC H400 HD Dig...
# 14262  www.ebay.com//58998  Canon PowerShot S3 Is 6 0MP 12x Optical Zoom 2...
# 14264  www.ebay.com//46986  Panasonic Lumix DMC GM1 Digital Camera with G ...
# 14269  www.ebay.com//24210        Ximea USB 3 0 4 2 Mpix Colour Camera | eBay
#
#            brand megapixels screen size  \
# 17          None       16.0        None
# 19         Nikon        6.1          2"
# 60         Canon       12.2        2.7"
# 75         Canon       18.0          3"
# 129        Nikon       10.2        2.5"
# ...          ...        ...         ...
# 14143       Sony       20.1        2.7"
# 14186       None       20.1        None
# 14262      Canon        6.0          2"
# 14264  Panasonic       16.0          3"
# 14269      Ximea        4.2        None
#
#                                               weight
# 17                                   20.8 oz. (589g)
# 19                                            600 gr
# 60                                    7.1 oz (201 g)
# 75     [15.3 oz. (434g) (body only), 7.1 oz. (200g)]
# 129                                         16.1 Oz.
# ...                                              ...
# 14143                                  7.8 oz.(222g)
# 14186                                22.2 oz. (628g)
# 14262                                       14.5 Oz.
# 14264                                 2.47 oz (70 g)
# 14269                                            32g
#
# [555 rows x 6 columns]

# %%
def parse_weight(value):
    if (isinstance(value, list)):
        value=value[0]
        

    if pd.isna(value):
        return value
    else:
        value = value.lower()
       
        match1 = re.search('()(\d*\,\d+|\d*\.\d+|\d+)( g|g| kg|kg|lbs| lbs| oz| ounce)', str(value))
        if match1 is None: 
            return float("NaN")




        to_convert= match1.group(2).replace(" ","").replace(",",".")
        metric= match1.group(3).replace(" ","")
        converted=float("NaN")
        if (metric == "oz" or metric== "ounce"):
            converted= int(round(float(to_convert) * 28.35))
        elif metric == "lbs":
            converted= int(round(float(to_convert) * 454))
        elif metric == "kg":
            converted= int(round(float(to_convert) * 1000))
        else:
            converted= int(round(float(to_convert)))

        return converted

# %%
df["weight"] = df["weight"].apply(parse_weight)

# %%
df.head()
# Out:
#                spec_id                                         page_title  \
# 0  www.ebay.com//56784  Sony Cyber Shot DSC S85 4 0 MP Digital Camera ...
# 1  www.ebay.com//24141  Olympus VH 210 14 0 MP Digital Camera Purple 4...
# 2  www.ebay.com//59471  New Canon PowerShot 130 Is ELPH 16MP Digital C...
# 3  www.ebay.com//47195  Canon EOS 10D 6 3MP Digital SLR Camera Body 10...
# 4  www.ebay.com//41942  Lumix Panasonic AVCHD Lite DMC TS1 12 MP Digit...
#
#        brand megapixels screen size  weight
# 0       Sony        4.0        1.8"     NaN
# 1    Olympus       14.0        None     NaN
# 2      Canon       16.0          3"     NaN
# 3      Canon        6.3        1.8"     NaN
# 4  Panasonic       12.0        None     NaN

# %% [markdown]
# ## screen size

# %%
df[df['screen size'].notnull()]
# Out:
#                    spec_id                                         page_title  \
# 0      www.ebay.com//56784  Sony Cyber Shot DSC S85 4 0 MP Digital Camera ...
# 2      www.ebay.com//59471  New Canon PowerShot 130 Is ELPH 16MP Digital C...
# 3      www.ebay.com//47195  Canon EOS 10D 6 3MP Digital SLR Camera Body 10...
# 5      www.ebay.com//54243  Canon EOS 5D Mark III 22 3MP Digital Camera Bo...
# 8      www.ebay.com//45002  Canon PowerShot S5 Is 8 MP 12x Optical Zoom Di...
# ...                    ...                                                ...
# 14267  www.ebay.com//45703  Used Sony Alpha NEX F3 Digital Camera 16 1 MP ...
# 14268  www.ebay.com//58832  GE A830 8 0 MP Digital Camera Silver 081002701...
# 14271  www.ebay.com//44811  Nikon Coolpix P330 12 2 MP Digital Camera Blac...
# 14272  www.ebay.com//48131  Olympus Camedia Camera C3000 C 3000 U1 05 0050...
# 14273  www.ebay.com//54112  Nikon Coolpix L24 14 0 MP Digital Camera 18208...
#
#          brand megapixels screen size  weight
# 0         Sony        4.0        1.8"     NaN
# 2        Canon       16.0          3"     NaN
# 3        Canon        6.3        1.8"     NaN
# 5        Canon       22.3        3.2"     NaN
# 8        Canon        8.0        2.5"     NaN
# ...        ...        ...         ...     ...
# 14267     Sony       16.1          3"     NaN
# 14268       GE        8.0        2.5"     NaN
# 14271    Nikon       12.2          3"     NaN
# 14272  Olympus        3.3        1.8"     NaN
# 14273    Nikon       14.0          3"     NaN
#
# [11244 rows x 6 columns]

# %%
def parse_screen_size(value):
    if (isinstance(value, list)):
        return float("NaN")
    if pd.isna(value):
        return value

    else:
        m = re.search('(\d*\.\d+|\d*\,\d+|\d+)(cm|\"| \"| in|)', str(value))
        if m is None:

            return float("NaN")

        to_convert= m.group(1).replace(" ","").replace(",",".")
        metric= m.group(2).replace(" ","")
        converted=float("NaN")
        if (metric == "cm"):

            converted= int(round(float(to_convert) / 2.54))
        else:
            converted= int(round(float(to_convert)))

        return converted

# %%
df["screen size"] = df["screen size"].apply(parse_screen_size)

# %%
df.head()
# Out:
#                spec_id                                         page_title  \
# 0  www.ebay.com//56784  Sony Cyber Shot DSC S85 4 0 MP Digital Camera ...
# 1  www.ebay.com//24141  Olympus VH 210 14 0 MP Digital Camera Purple 4...
# 2  www.ebay.com//59471  New Canon PowerShot 130 Is ELPH 16MP Digital C...
# 3  www.ebay.com//47195  Canon EOS 10D 6 3MP Digital SLR Camera Body 10...
# 4  www.ebay.com//41942  Lumix Panasonic AVCHD Lite DMC TS1 12 MP Digit...
#
#        brand megapixels  screen size  weight
# 0       Sony        4.0          2.0     NaN
# 1    Olympus       14.0          NaN     NaN
# 2      Canon       16.0          3.0     NaN
# 3      Canon        6.3          2.0     NaN
# 4  Panasonic       12.0          NaN     NaN

# %% [markdown]
# ## Brand

# %%
df['brand'] = df['brand'].apply(lambda x: str(x).lower())

# %%
pd.set_option('display.max_rows', 500)
print(df.brand.value_counts())
# Out:
# canon                                                           3580
# nikon                                                           2959
# sony                                                            1866
# fujifilm                                                         835
# olympus                                                          833
# kodak                                                            646
# samsung                                                          602
# panasonic                                                        583
# pentax                                                           301
# none                                                             290
# vivitar                                                          162
# casio                                                            147
# leica                                                            111
# polaroid                                                          99
# ge                                                                90
# hp                                                                87
# gopro                                                             59
# ricoh                                                             58
# konica minolta                                                    54
# svp                                                               51
# sanyo                                                             45
# vizio                                                             31
# minolta                                                           27
# fvanor                                                            24
# coleman                                                           24
# sakar                                                             23
# fuji                                                              22
# bell & howell                                                     22
# toshiba                                                           18
# unbranded/generic                                                 17
# lg                                                                17
# sigma                                                             16
# philips                                                           16
# lytro                                                             15
# sealife                                                           12
# hasselblad                                                        11
# digital blue corporation                                          10
# vistaquest                                                        10
# emerson                                                           10
# disney                                                             9
# naxa                                                               9
# cobra digital                                                      9
# minox                                                              8
# easypix                                                            8
# rca                                                                8
# sharp                                                              8
# fotopix                                                            7
# lowrance                                                           7
# aiptek                                                             7
# oregon scientific                                                  7
# superheadz                                                         7
# insignia                                                           7
# vtech                                                              7
# argus                                                              7
# intova                                                             7
# sj4000                                                             7
# magnavox                                                           6
# jvc                                                                6
# dxg technology                                                     5
# dxg                                                                5
# toi kamera                                                         5
# epson                                                              5
# mustek                                                             5
# digital blue                                                       5
# digital concepts                                                   5
# sylvania                                                           4
# sharper image                                                      4
# coby                                                               4
# global point                                                       4
# benq                                                               4
# vibe                                                               4
# unknown                                                            4
# fisher price                                                       4
# mattel                                                             4
# shimano                                                            3
# limited too                                                        3
# brinno                                                             3
# hello kitty                                                        3
# the sharper image                                                  3
# jazz                                                               3
# keedox                                                             3
# lg electronics                                                     3
# dji                                                                3
# pioneer                                                            3
# crayola                                                            3
# supersonic                                                         3
# new                                                                3
# apple                                                              3
# flip video                                                         3
# sciwin                                                             3
# bushnell                                                           3
# apex digital                                                       2
# motorolathis is a nice, motorola                                   2
# element                                                            2
# mikona                                                             2
# yashica                                                            2
# zenith                                                             2
# proscan                                                            2
# gateway                                                            2
# gizmon                                                             2
# discovery kids                                                     2
# advancedplus                                                       2
# vivitar & samsung                                                  2
# blackmagicdesign                                                   2
# slick                                                              2
# panasonic limix                                                    2
# contour, inc                                                       2
# spongebob                                                          2
# mitsuba                                                            2
# humminbird                                                         2
# agfa                                                               2
# quantumfx                                                          2
# monoprice                                                          2
# skyworth                                                           2
# sipix                                                              2
# sealife reefmaster                                                 2
# kyocera                                                            2
# unbranded 252 generic                                              2
# precision                                                          2
# westinghouse                                                       2
# midland                                                            2
# vupoint solutions                                                  2
# iclick                                                             2
# chobi                                                              2
# axess                                                              2
# phase one                                                          2
# audiovox                                                           2
# praktica                                                           2
# mitsubishi                                                         2
# innovage                                                           2
# topixo                                                             2
# cobra                                                              2
# little acorn                                                       2
# pyle-sport                                                         1
# ktv                                                                1
# bang & olufsen                                                     1
# star system                                                        1
# revo                                                               1
# horseman                                                           1
# seiki digital inc.                                                 1
# jakks pacific                                                      1
# dv                                                                 1
# wingscapes                                                         1
# emprex                                                             1
# vupoint                                                            1
# venturer                                                           1
# garmin parts                                                       1
# ximea                                                              1
# speedo                                                             1
# hewlett packard                                                    1
# 2000 ixla                                                          1
# pentax corporation                                                 1
# vizio, inc.                                                        1
# jumbl                                                              1
# contour                                                            1
# dgx                                                                1
# mamiya afd ii                                                      1
# mercury                                                            1
# unbrand                                                            1
# motorola                                                           1
# optimus                                                            1
# sceptre                                                            1
# kenko                                                              1
# general imaging ge                                                 1
# evolt                                                              1
# panasonic / lumix                                                  1
# fantasea                                                           1
# imaging apparatus                                                  1
# qfx                                                                1
# vivitar, kodak, sanyo, nikon                                       1
# access hd                                                          1
# nik                                                                1
# sears                                                              1
# action                                                             1
# unbranded                                                          1
# ltl acorn                                                          1
# mobius                                                             1
# ['nikon\ntype:\ndigital slr', 'nikon']                             1
# general imaging                                                    1
# palm clix                                                          1
# i_p.mium                                                           1
# aee                                                                1
# canon/japan                                                        1
# ion                                                                1
# fujifilm finepix telephoto digitalcamera                           1
# d-link                                                             1
# wusthof                                                            1
# next                                                               1
# action shot                                                        1
# largan group                                                       1
# digital camera                                                     1
# mega pro                                                           1
# little shots                                                       1
# betterlight                                                        1
# favi entertainment                                                 1
# olympu                                                             1
# elite screens                                                      1
# megapix                                                            1
# lifeworks                                                          1
# protron                                                            1
# kodak, samsung, vivitar, canon , olympus                           1
# optiz                                                              1
# tenvis                                                             1
# pure digital                                                       1
# islands earth                                                      1
# aquapix                                                            1
# nokia                                                              1
# tandberg                                                           1
# gpx                                                                1
# magellan                                                           1
# trendnet                                                           1
# kbgear interactive                                                 1
# olivia                                                             1
# combotek                                                           1
# digital labs                                                       1
# "easy shot" clip                                                   1
# phoenix                                                            1
# ['nikon megapixels: 12.1 mp', 'nikon\nmegapixels:\n12.1 mp']       1
# intel                                                              1
# joco                                                               1
# garmin                                                             1
# bonzart                                                            1
# telecom                                                            1
# alpine                                                             1
# akai (built by samsung)                                            1
# digital prism                                                      1
# eos                                                                1
# aee magicam                                                        1
# radio shack                                                        1
# pioneer research                                                   1
# nec                                                                1
# vistaquestâ                                                        1
# ge general imaging                                                 1
# panasonic/lumix                                                    1
# symphonic                                                          1
# kowa                                                               1
# jlb                                                                1
# tcl                                                                1
# ['pentax', 'pentax']                                               1
# zmodo                                                              1
# kogan                                                              1
# contax                                                             1
# spectra merchandising international                                1
# logitech                                                           1
# hisense                                                            1
# vista quest                                                        1
# oem                                                                1
# agfaphoto                                                          1
# nabi                                                               1
# zeiss                                                              1
# god condition                                                      1
# skyguide                                                           1
# protax                                                             1
# insigniaâ¢                                                        1
# mamiya                                                             1
# 6.0 mp                                                             1
# concord                                                            1
# lexar media                                                        1
# ['kodak optical zoom: 8x', 'kodak\noptical zoom:\n8x']             1
# computer partner                                                   1
# winait                                                             1
# kobian group                                                       1
# blackmagic design                                                  1
# fotoman                                                            1
# dnt                                                                1
# dynex                                                              1
# moultrie feeders                                                   1
# jazz dv150                                                         1
# ['kodak', 'kodak']                                                 1
# cambo                                                              1
# chinon                                                             1
# mercury electronics                                                1
# hitachi                                                            1
# digital camera for dummies                                         1
# ge general electric                                                1
# cyber-cam                                                          1
# canon power shot sx130                                             1
# Name: brand, dtype: int64

# %%
df.loc[df['brand'] == 'blackmagicdesign', 'brand'] = "blackmagic"
df.loc[df['brand'] == 'lg electronics', 'brand'] = "lg"
df.loc[df['brand'] == 'new', 'brand'] = float("NaN")
df.loc[df['brand'] == 'panasonic limix', 'brand'] = "panasonic"
df.loc[df['brand'] == 'unbrand', 'brand'] = float("NaN")
df.loc[df['brand'] == 'dxg technology', 'brand'] = "dxg"
df.loc[df['brand'] == 'unknown', 'brand'] = float("NaN")
df.loc[df['brand'] == 'panasonic / lumix', 'brand'] = "panasonic"
df.loc[df['brand'] == str(['nikon\ntype:\ndigital slr', 'nikon']), 'brand'] = "nikon"
df.loc[df['brand'] == 'canon/japan', 'brand'] = "canon"
df.loc[df['brand'] == '2000 ixla', 'brand'] = float("NaN")
df.loc[df['brand'] == 'insigniaâ¢', 'brand'] = "insignia"
df.loc[df['brand'] == 'vizio, inc.', 'brand'] = "vizio"
df.loc[df['brand'] == str(['nikon megapixels: 12.1 mp', 'nikon\nmegapixels:\n12.1 mp']), 'brand'] = "nikon"
df.loc[df['brand'] == 'motorolathis is a nice, motorola', 'brand'] = "motorola"
df.loc[df['brand'] == str(['kodak', 'kodak'])  , 'brand'] = "kodak"
df.loc[df['brand'] == 'panasonic/lumix ', 'brand'] = "panasonic"
df.loc[df['brand'] == 'unbranded 252 generic', 'brand'] = float("NaN")
df.loc[df['brand'] == 'mamiya afd ii', 'brand'] = float("NaN")
df.loc[df['brand'] == 'unbranded/generic', 'brand'] = float("NaN")
df.loc[df['brand'] == 'sj4000', 'brand'] = float("NaN")
df.loc[df['brand'] == "akai (built by samsung)", 'brand'] = "akai"
df.loc[df['brand'] == 'vivitar & samsung', 'brand'] = "samsung"
df.loc[df['brand'] == '[\'pentax\', \'pentax\']', 'brand'] = "pentax"
df.loc[df['brand'] == '"easy shot" clip', 'brand'] = float("NaN")
df.loc[df['brand'] == 'jazz dv150', 'brand'] = "jazz"
df.loc[df['brand'] == 'spectra merchandising international', 'brand'] = "spectra"
df.loc[df['brand'] == 'vistaquestâ', 'brand'] = "pentax"
df.loc[df['brand'] == 'canon power shot sx130', 'brand'] = 'canon'
df.loc[df['brand'] == '6.0 mp', 'brand'] = float("NaN")
df.loc[df['brand'] == 'olympu', 'brand'] = "olympus"
df.loc[df['brand'] == 'blackmagic design', 'brand'] = "blackmagic"
df.loc[df['brand'] == 'vivitar, kodak, sanyo, nikon', 'brand'] = "vivitar"
df.loc[df['brand'] == 'pentax corporation', 'brand'] = "pentax"
df.loc[df['brand'] == 'kodak, samsung, vivitar, canon , olympus', 'brand'] = "kodak"
df.loc[df['brand'] == 'i_p.mium', 'brand'] = float("NaN")
df.loc[df['brand'] == str(['kodak optical zoom: 8x', 'kodak\noptical zoom:\n8x']), 'brand'] = "kodak"
df.loc[df['brand'] == 'kobian group', 'brand'] = "kobian"
df.loc[df['brand'] == 'fujifilm finepix telephoto digitalcamera', 'brand'] = "fujifilm"
df.loc[df['brand'] == 'hewlett packard', 'brand'] = "hp"
df.loc[df['brand'] == 'unbranded', 'brand'] = float("NaN")
df.loc[df['brand'] == 'pioneer research', 'brand'] = "pioneer"
df.loc[df['brand'] == 'kodak, samsung, vivitar, canon , olympus ', 'brand'] = "kodak "

# %%
df.head()
# Out:
#                spec_id                                         page_title  \
# 0  www.ebay.com//56784  Sony Cyber Shot DSC S85 4 0 MP Digital Camera ...
# 1  www.ebay.com//24141  Olympus VH 210 14 0 MP Digital Camera Purple 4...
# 2  www.ebay.com//59471  New Canon PowerShot 130 Is ELPH 16MP Digital C...
# 3  www.ebay.com//47195  Canon EOS 10D 6 3MP Digital SLR Camera Body 10...
# 4  www.ebay.com//41942  Lumix Panasonic AVCHD Lite DMC TS1 12 MP Digit...
#
#        brand megapixels  screen size  weight
# 0       sony        4.0          2.0     NaN
# 1    olympus       14.0          NaN     NaN
# 2      canon       16.0          3.0     NaN
# 3      canon        6.3          2.0     NaN
# 4  panasonic       12.0          NaN     NaN

# %% [markdown]
# ## Page title

# %%
stopWords = set(['itself', 'down', 'by', 'with', 'doesn', 'wouldn', 'other', 'ours', 'of', 'then', 'where', 'don', 'these', 'nor', 'she', "should've", 'won', 'ma', 'from', 'had', "you're", 'our', 'did', 'them', 'too', 'her', 'that', 'haven', 'after', "you'll", 'hers', 'because', 'yourself', 'against', 'mightn', 'as', 'll', 'whom', 'how', 'couldn', 'further', 'aren', "you'd", 'and', 'needn', "couldn't", 'those', 'to', "doesn't", "weren't", 'both', 'ourselves', 'in', 'which', 'yours', 'under', 'some', 'what', 'during', 'before', "needn't", "shan't", 'here', 'having', 'hasn', 'your', "hasn't", 'between', 'me', "she's", 'into', 'all', 'at', 'shan', 'who', 'o', 'an', 'very', 'can', 'you', 'shouldn', 'such', 'but', 'do', 'out', 'am', "shouldn't", 'above', 'wasn', 'or', 'were', 'own', 'didn', "you've", 'on', 'will', 'my', 'it', 'have', 'once', 'only', 'been', 'themselves', 'his', 'be', "mightn't", 'they', 'not', 'so', 'up', 'any', 'most', 'has', 'myself', 't', 'yourselves', 'isn', "it's", 'y', 'm', 'now', 'until', 're', 'there', 'their', 'mustn', "mustn't", 'again', 'being', 'hadn', 'doing', 'just', 'no', 'if', 've', "wasn't", "won't", 'we', 'below', 'does', 'more', 'this', 'should', "isn't", 'ain', "don't", 'i', "haven't", 'than', "didn't", 'are', 'about', 'off', 'him', 'for', 'few', "wouldn't", 'was', 'weren', 'why', 'he', "that'll", 'd', 'the', 'its', 'a', 'each', 'is', 'while', "aren't", 'when', 'theirs', 'same', 's', 'himself', 'herself', "hadn't", 'through', 'over'])

# %%
punctuation = "!#$%&'()*+,-./:;<=>?@[\]^_`{|}~€£¥₹₽"

# %%
def replace_punctuation(word):
    return ''.join(c for c in word if c not in punctuation)

# %%
df["page_title"] = df["page_title"].apply(lambda x : [i.lower() for i in list(map(lambda y: replace_punctuation(y), word_tokenize(x))) if i and i.lower() not in stopWords])

# %% [markdown]
# ## Modelwords

# %%
pattern = re.compile("(\S*[A-Za-z]\S*[0-9]\S*|\S*[0-9]\S*[A-Za-z]\S*)")

# %%
brands = ['360fly', 'acer', 'achiever', 'acorn', 'actionpro', 'activeon', 'aee', 'agfa', 'agfaphoto', 'aiptek', 'akaso', 'alpine', 'alpine', 'amkov', 'andoer', 'annke', 'ansco', 'apeman', 'apex', 'apple', 'archos', 'argus', 'arlo', 'arri', 'axis', 'bell', 'benq', 'blackmagic', 'blackmagic', 'bosch', 'bower', 'brinno', 'brookstone', 'browning', 'cambo', 'campark', 'canon', 'carl', 'casio', 'celestron', 'chinon', 'cisco', 'cobra', 'coleman', 'concord', 'contax', 'contour', 'covert', 'craig', 'crayola', 'creative', 'creative', 'crosstour', 'crumpler', 'datavideo', 'delkin', 'dell', 'digitrex', 'discovery', 'disney', 'dji', 'd-link', 'domke', 'dörr', 'dragon', 'dxg', 'dxo', 'easypix', 'elecom', 'elmo', 'emerson', 'energizer', 'epson', 'fisher-price', 'flip', 'flir', 'foscam', 'fotoman', 'fotopro', 'fuji', 'fujifilm', 'fujinon', 'garmin', 'gateway', 'godox', 'goodmans', 'google', 'gopro', 'grundig', 'hahnel', 'hamilton', 'hasselblad', 'hello', 'herofiber', 'hitachi', 'holga', 'horseman', 'hoya', 'htc', 'huawei', 'ikelite', 'ilford', 'impossible', 'innovage', 'insignia', 'insta360', 'intel', 'intova', 'ion', 'iris', 'jazz', 'jenoptik', 'jjrc', 'jvc', 'kaiser', 'kenko', 'keyence', 'king', 'kitvision', 'kodak', 'konica', 'kyocera', 'leaf', 'lego', 'leica', 'lenovo', 'lexibook', 'linhof', 'liquid', 'little', 'logitech', 'lomography', 'lowepro', 'ltl', 'lytro', 'maginon', 'magnavox', 'mamiya', 'manfrotto', 'marshall', 'marumi', 'mattel', 'maxell', 'meade', 'medion', 'memorex', 'mercury', 'metz', 'microsoft', 'microtek', 'midland', 'minolta', 'minox', 'monster', 'motorola', 'moultrie', 'mustek', 'nabi', 'neewer', 'nest', 'netgear', 'night', 'nikkon', 'nikkor', 'nikon', 'nilox', 'nintendo', 'nippon', 'nokia', 'norcent', 'olympus', 'optech', 'ordro', 'oregon', 'packard', 'palm', 'panasonic', 'parrot', 'pelco', 'pentacon', 'pentax', 'phase', 'philips', 'philips', 'phoenix', 'pioneer', 'playskool', 'polaroid', 'polarpro', 'praktica', 'premier', 'promaster', 'proscan', 'pyle', 'radioshack', 'raymarine', 'raynox', 'rca', 'ricoh', 'ring', 'rode', 'rokinon', 'rollei', 'ryobi', 'sakar', 'samsung', 'sandisk', 'sanyo', 'schneider', 'schneider', 'schneider', 'scosche', 'seasea', 'sealife', 'sharp', 'sharper', 'sigma', 'sinar', 'sipix', 'sjcam', 'sony', 'soocoo', 'stealth', 'superheadz', 'svp', 'swann', 'tamrac', 'tamron', 'technika', 'tenba', 'think', 'thule', 'tokina', 'tomy', 'toshiba', 'transcend', 'traveler', 'trust', 'verbatim', 'vibe', 'victure', 'vistaquest', 'vivitar', 'voigtländer', 'vtech', 'vupoint', 'walimex', 'wyze', 'xiaomi', 'xit', 'xtreme', 'yashica', 'zeiss']

# %%
def clean_mp_mm_g_oz(value):
    if not isinstance(value, list) and pd.isna(value):
        return np.nan
    regex = r"[0-9]+mm(\n|)"
    regex2 = r"[0-9]+mp(\n|)"
    regex3 = r"[0-9]+oz"
    regex4 = r"[0-9]+g(\n|)$"
    repl = value
    for e in repl:
        if bool(re.match(regex, e)) or bool(re.match(regex2, e)) or bool(re.match(regex3, e)) or bool(re.match(regex4, e)):
            repl.remove(e)
    return repl

# %%
df["page_title_model"] = df["page_title"].apply(lambda line : list(set(filter(lambda word : bool(pattern.match(word)),line)))).apply(lambda row : clean_mp_mm_g_oz(row))

# %%
df.head()
# Out:
#                spec_id                                         page_title  \
# 0  www.ebay.com//56784  [sony, cyber, shot, dsc, s85, 4, 0, mp, digita...
# 1  www.ebay.com//24141  [olympus, vh, 210, 14, 0, mp, digital, camera,...
# 2  www.ebay.com//59471  [new, canon, powershot, 130, elph, 16mp, digit...
# 3  www.ebay.com//47195  [canon, eos, 10d, 6, 3mp, digital, slr, camera...
# 4  www.ebay.com//41942  [lumix, panasonic, avchd, lite, dmc, ts1, 12, ...
#
#        brand megapixels  screen size  weight page_title_model
# 0       sony        4.0          2.0     NaN            [s85]
# 1    olympus       14.0          NaN     NaN               []
# 2      canon       16.0          3.0     NaN               []
# 3      canon        6.3          2.0     NaN            [10d]
# 4  panasonic       12.0          NaN     NaN            [ts1]

# %%
def jaccard_similarity(query, document):
    intersection = set(query).intersection(set(document))
    union = set(query).union(set(document))
    return len(intersection)/len(union)

# %%
def get_merged_df(dataframe):
    merged = dataframe
    merged = (merged.merge(merged, on=merged.assign(key_col=1)['key_col'], suffixes=('', '_right'))
 .query('spec_id < spec_id_right') # filter out joins on the same row and keep unique combinations
 .reset_index(drop=True))
    merged.drop(columns = ["key_0"], axis = 1, inplace=True)
    merged.rename(columns = {"spec_id" : "left_spec_id", "spec_id_right" : "right_spec_id"}, inplace=True)
    merged.reset_index(inplace=True, drop=True)
    return merged

# %%
len(df)
# Out:
# 14274

# %%
df_small = df#.sample(frac = 0.01)

# %%
merged = get_merged_df(df_small)

# %%
len(merged)
# Out:
# 10153

# %%
small_merged = merged
#small_merged = merged.sample(frac = 0.001)

# %%
len(small_merged)
# Out:
# 10153

# %%
small_merged.head()
# Out:
#           left_spec_id                                         page_title  \
# 0  www.ebay.com//45689  [nikon, series, d200, 10, 2, mp, digital, slr,...
# 1  www.ebay.com//45689  [nikon, series, d200, 10, 2, mp, digital, slr,...
# 2  www.ebay.com//45689  [nikon, series, d200, 10, 2, mp, digital, slr,...
# 3  www.ebay.com//45689  [nikon, series, d200, 10, 2, mp, digital, slr,...
# 4  www.ebay.com//45689  [nikon, series, d200, 10, 2, mp, digital, slr,...
#
#    brand megapixels  screen size  weight page_title_model  \
# 0  nikon       10.2          2.0     NaN           [d200]
# 1  nikon       10.2          2.0     NaN           [d200]
# 2  nikon       10.2          2.0     NaN           [d200]
# 3  nikon       10.2          2.0     NaN           [d200]
# 4  nikon       10.2          2.0     NaN           [d200]
#
#          right_spec_id                                   page_title_right  \
# 0  www.ebay.com//53575  [samsung, st, series, st150f, 16, 2, mp, digit...
# 1  www.ebay.com//60281  [canon, eos, rebel, t1i, 500d, 15, 1, mp, digi...
# 2  www.ebay.com//58563  [hp, photosmart, m407, used, parts, repair, ebay]
# 3  www.ebay.com//56381  [car, camera, video, recorder, full, hd, dvr, ...
# 4  www.ebay.com//54776  [canon, eos, 20d, 8, 2mp, digital, slr, camera...
#
#   brand_right megapixels_right  screen size_right  weight_right  \
# 0     samsung             16.2                3.0           NaN
# 1       canon             15.1                3.0           NaN
# 2          hp             None                NaN           NaN
# 3        none             1200              960.0           NaN
# 4       canon              8.2                2.0           NaN
#
#   page_title_model_right
# 0               [st150f]
# 1            [500d, t1i]
# 2                 [m407]
# 3                [1080p]
# 4                  [20d]

# %%
small_merged.isna().sum() / len(small_merged)
# Out:
# left_spec_id              0.000000
# page_title                0.000000
# brand                     0.000000
# megapixels                0.104501
# screen size               0.183788
# weight                    0.925244
# page_title_model          0.000000
# right_spec_id             0.000000
# page_title_right          0.000000
# brand_right               0.000000
# megapixels_right          0.091303
# screen size_right         0.137890
# weight_right              0.962868
# page_title_model_right    0.000000
# dtype: float64

# %%
def determine_match(row):
    score = 0
    
#     if pd.isna(row["weight"]) or pd.isna(row["weight_right"]):
#         target = 0.5
#     else:
    target = 1.2
    
    brand_l = row["brand"]
    brand_r = row["brand_right"]
    megapixels_l = row["megapixels"]
    megapixels_r = row["megapixels_right"]
    screen_size_l = row["screen size"]
    screen_size_r = row["screen size_right"]
    weight_l = row["weight"]
    weight_r = row["weight_right"]
    page_title_l = row["page_title"]
    page_title_r = row["page_title_right"]
    model_l = row["page_title_model"]
    model_r = row["page_title_model_right"]
    
    weight_weight = 0.6
    brand_weight = 0.3
    mp_weight = 0.3
    scr_weight = 0.3
    
    if model_l != [] and model_r != []:
        model_count = 0
        for spec1 in model_l:
            for spec2 in model_r:
                if spec1 == spec2: 
                    score += 0.8
                    model_count += 1
                if model_count >= 2:
                    return True
        if model_count == 0:
            return False
    
    if not pd.isna(weight_l) and not pd.isna(weight_r):
        if abs(weight_l - weight_r) <= 2:
            score += weight_weight
        else:
            score -= weight_weight
    
    
    if not pd.isna(megapixels_l) and not pd.isna(megapixels_r):
        if abs(float(megapixels_l.replace("mp", "")) - float(megapixels_r.replace("mp", ""))) == 0:
            score += mp_weight
        else:
            score -= mp_weight
    
    if not pd.isna(brand_l) and not pd.isna(brand_r):
        if brand_l == brand_r:
            score += brand_weight
        else:
            score -= brand_weight
    
    if not pd.isna(screen_size_l) and not pd.isna(screen_size_r):
        if abs(screen_size_l - screen_size_r) == 0:
            score += scr_weight
        else:
            score -= scr_weight

    if page_title_l != [] and page_title_r != []:
        score += jaccard_similarity(page_title_l, page_title_r) * 0.7
                    
    return score > target

# %%
tqdm.pandas()
# Out:
# /Users/gfotiadis/anaconda3/lib/python3.7/site-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
labels = []
labels.append(list(small_merged.progress_apply(determine_match, axis = 1)))
labels = sum(labels, [])
small_merged["label"] = labels
# Out:
#   0%|          | 0/10153 [00:00<?, ?it/s]
#   4%|▎         | 363/10153 [00:00<00:02, 3623.80it/s]
#   7%|▋         | 666/10153 [00:00<00:02, 3422.14it/s]
#  10%|█         | 1025/10153 [00:00<00:02, 3467.05it/s]
#  13%|█▎        | 1305/10153 [00:00<00:02, 3233.93it/s]
#  16%|█▋        | 1664/10153 [00:00<00:02, 3332.22it/s]
#  20%|█▉        | 1994/10153 [00:00<00:02, 3321.55it/s]
#  23%|██▎       | 2300/10153 [00:00<00:02, 3235.62it/s]
#  26%|██▌       | 2597/10153 [00:00<00:02, 3089.07it/s]
#  29%|██▉       | 2933/10153 [00:00<00:02, 3161.89it/s]
#  33%|███▎      | 3321/10153 [00:01<00:02, 3347.64it/s]
#  36%|███▌      | 3651/10153 [00:01<00:02, 3235.33it/s]
#  39%|███▉      | 3972/10153 [00:01<00:01, 3207.13it/s]
#  42%|████▏     | 4298/10153 [00:01<00:01, 3213.75it/s]
#  45%|████▌     | 4618/10153 [00:01<00:01, 3207.19it/s]
#  49%|████▊     | 4938/10153 [00:01<00:01, 3083.53it/s]
#  52%|█████▏    | 5286/10153 [00:01<00:01, 3192.28it/s]
#  55%|█████▌    | 5630/10153 [00:01<00:01, 3261.56it/s]
#  59%|█████▊    | 5958/10153 [00:01<00:01, 3149.95it/s]
#  62%|██████▏   | 6275/10153 [00:01<00:01, 3118.50it/s]
#  65%|██████▌   | 6621/10153 [00:02<00:01, 3213.33it/s]
#  69%|██████▊   | 6961/10153 [00:02<00:00, 3266.33it/s]
#  72%|███████▏  | 7289/10153 [00:02<00:00, 3138.89it/s]
#  75%|███████▌  | 7633/10153 [00:02<00:00, 3223.12it/s]
#  78%|███████▊  | 7958/10153 [00:02<00:00, 2988.49it/s]
#  81%|████████▏ | 8262/10153 [00:02<00:00, 2486.21it/s]
#  84%|████████▍ | 8529/10153 [00:02<00:00, 2037.86it/s]
#  87%|████████▋ | 8820/10153 [00:02<00:00, 2238.82it/s]
#  90%|█████████ | 9142/10153 [00:03<00:00, 2463.98it/s]
#  93%|█████████▎| 9458/10153 [00:03<00:00, 2637.81it/s]
#  96%|█████████▌| 9742/10153 [00:03<00:00, 2668.97it/s]
# 100%|██████████| 10153/10153 [00:03<00:00, 2968.05it/s]

# %%
len(small_merged)
# Out:
# 10153

# %%
small_merged.loc[(small_merged["label"] == True)]
# Out:
#              left_spec_id                                         page_title  \
# 42    www.ebay.com//45689  [nikon, series, d200, 10, 2, mp, digital, slr,...
# 430   www.ebay.com//25187  [canon, powershot, sx50, hs, 12, 1, mp, digita...
# 474   www.ebay.com//25187  [canon, powershot, sx50, hs, 12, 1, mp, digita...
# 561   www.ebay.com//58768  [canon, eos, rebel, t1i, 500d, 15, 1, mp, digi...
# 2310  www.ebay.com//43436  [canon, powershot, digital, elph, sd1300, ixus...
# 4006  www.ebay.com//42092  [canon, powershot, digital, elph, sd940, 12, 1...
# 4049  www.ebay.com//42092  [canon, powershot, digital, elph, sd940, 12, 1...
# 4161  www.ebay.com//45749  [nikon, d80, 10, 2, mp, digital, slr, camera, ...
# 4714  www.ebay.com//53451  [nikon, d3100, 14, 2, mp, digital, slr, camera...
# 5137  www.ebay.com//45637  [canon, powershot, elph, 100, hs, ixus, 115, h...
# 5141  www.ebay.com//45637  [canon, powershot, elph, 100, hs, ixus, 115, h...
# 5387  www.ebay.com//43711  [canon, powershot, digital, elph, sd850, 8, 0,...
# 5686  www.ebay.com//45929  [brand, new, canon, rebel, t3i, 18mp, slr, 18,...
# 7400  www.ebay.com//45277  [canon, eos, rebel, t5i, 700d, dslr, camera, 4...
# 7705  www.ebay.com//56224  [canon, eos, rebel, t5, 18, 0, mp, ef, 18, 55,...
# 8061  www.ebay.com//46613  [canon, eos, 20d, digital, slr, camera, body, ...
# 8482  www.ebay.com//42614  [new, canon, powershot, n, 12, 1, mp, digital,...
# 8579  www.ebay.com//47043  [nikon, d3200, digital, slr, camera, black, ki...
# 9150  www.ebay.com//24883  [two, nikon, d700, body, 2, md10, 21, compact,...
# 9589  www.ebay.com//54363  [canon, eos, 7d, 18, 0, mp, digital, slr, came...
#
#       brand megapixels  screen size  weight   page_title_model  \
# 42    nikon       10.2          2.0     NaN             [d200]
# 430   canon       12.1          3.0     NaN             [sx50]
# 474   canon       12.1          3.0     NaN             [sx50]
# 561   canon       15.1          3.0     NaN        [500d, t1i]
# 2310  canon       12.1          3.0     NaN           [sd1300]
# 4006  canon       12.1          3.0     NaN            [sd940]
# 4049  canon       12.1          3.0     NaN            [sd940]
# 4161  nikon       10.2          2.0     NaN              [d80]
# 4714  nikon       14.2          3.0     NaN            [d3100]
# 5137  canon       12.1          3.0     NaN                 []
# 5141  canon       12.1          3.0     NaN                 []
# 5387  canon        8.0          NaN     NaN            [sd850]
# 5686  canon         18          3.0   516.0        p, t3i]
# 7400  canon       18.0          3.0     NaN  [700d, t5i, 80gb]
# 7705  canon       18.0          NaN     NaN               [t5]
# 8061  canon        8.2          2.0     NaN              [20d]
# 8482  canon       12.1          3.0     NaN                 []
# 8579  nikon       24.2          3.0     NaN            [d3200]
# 9150  nikon       12.1          3.0     NaN       [md10, d700]
# 9589  canon       18.0          3.0     NaN               [7d]
#
#             right_spec_id                                   page_title_right  \
# 42    www.ebay.com//48020  [nikon, d200, 10, 2, mp, digital, slr, camera,...
# 430   www.ebay.com//45637  [canon, powershot, elph, 100, hs, ixus, 115, h...
# 474   www.ebay.com//42614  [new, canon, powershot, n, 12, 1, mp, digital,...
# 561   www.ebay.com//60281  [canon, eos, rebel, t1i, 500d, 15, 1, mp, digi...
# 2310  www.ebay.com//45637  [canon, powershot, elph, 100, hs, ixus, 115, h...
# 4006  www.ebay.com//45637  [canon, powershot, elph, 100, hs, ixus, 115, h...
# 4049  www.ebay.com//42614  [new, canon, powershot, n, 12, 1, mp, digital,...
# 4161  www.ebay.com//47739  [nikon, d80, 10, 2mp, digital, slr, camera, bo...
# 4714  www.ebay.com//60477  [nikon, d3100, 14, 2, mp, digital, slr, camera...
# 5137  www.ebay.com//60852  [brand, new, canon, powershot, sx130, 12, 1, m...
# 5141  www.ebay.com//59634  [canon, elph, 100, hs, dark, gray, digital, ca...
# 5387  www.ebay.com//56227                    [canon, powershot, sd850, ebay]
# 5686  www.ebay.com//55705  [canon, eos, rebel, t3i, 600d, 18, 0, mp, digi...
# 7400  www.ebay.com//58415  [canon, eos, rebel, t5i, 700d, digital, slr, b...
# 7705  www.ebay.com//56847  [canon, eos, rebel, t5, digital, camera, ef, 1...
# 8061  www.ebay.com//54776  [canon, eos, 20d, 8, 2mp, digital, slr, camera...
# 8482  www.ebay.com//60852  [brand, new, canon, powershot, sx130, 12, 1, m...
# 8579  www.ebay.com//58750  [nikon, d3200, digital, slr, camera, w, 18, 55...
# 9150  www.ebay.com//53723  [nikon, d700, body, accessories, extras, 01820...
# 9589  www.ebay.com//54972  [canon, eos, 7d, 18, 0, mp, digital, slr, came...
#
#      brand_right megapixels_right  screen size_right  weight_right  \
# 42         nikon             10.2                2.0           NaN
# 430        canon             12.1                3.0           NaN
# 474        canon             12.1                3.0           NaN
# 561        canon             15.1                3.0           NaN
# 2310       canon             12.1                3.0           NaN
# 4006       canon             12.1                3.0           NaN
# 4049       canon             12.1                3.0           NaN
# 4161       nikon             10.2                2.0           NaN
# 4714       nikon             14.2                3.0           NaN
# 5137       canon             12.1                3.0           NaN
# 5141       canon             12.1                3.0           NaN
# 5387       canon              8.0                2.0           NaN
# 5686       canon             18.0                3.0           NaN
# 7400       canon             18.0                3.0           NaN
# 7705       canon             18.0                3.0           NaN
# 8061       canon              8.2                2.0           NaN
# 8482       canon             12.1                3.0           NaN
# 8579       nikon             24.2                3.0         270.0
# 9150       nikon             12.1                3.0           NaN
# 9589       canon             18.0                3.0           NaN
#
#      page_title_model_right  label
# 42                   [d200]   True
# 430                      []   True
# 474                      []   True
# 561             [500d, t1i]   True
# 2310                     []   True
# 4006                     []   True
# 4049                     []   True
# 4161                  [d80]   True
# 4714                [d3100]   True
# 5137                [sx130]   True
# 5141                     []   True
# 5387                [sd850]   True
# 5686            [600d, t3i]   True
# 7400        [1k, 700d, t5i]   True
# 7705                   [t5]   True
# 8061                  [20d]   True
# 8482                [sx130]   True
# 8579          [d3200, 24gb]   True
# 9150                 [d700]   True
# 9589                   [7d]   True

# %%
small_merged["label"].sum() / len(df_small)
# Out:
# 0.13986013986013987

# %%
small_merged = small_merged[small_merged["label"] == True]
cols = ["left_spec_id", "right_spec_id"]
small_merged = small_merged[cols]
small_merged.to_csv("ebay.csv", index = False)
# Out:
#   0%|          | 89506/31772406 [00:41<1:45:37, 4998.92it/s]

# %%
import os
import numpy as np
import json
import pandas as pd
import itertools
from tqdm import tqdm
import nltk
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
import re

# %%
def create_dataframe(dataset_path, source, columns_df):
    """Function used to create a Pandas DataFrame containing specifications page titles

    Reads products specifications from the file system ("dataset_path" variable in the main function) and creates a Pandas DataFrame where each row is a
    specification. The columns are 'source' (e.g. www.sourceA.com), 'spec_number' (e.g. 1) and the 'page title'. Note that this script will consider only
    the page title attribute for simplicity.

    Args:
        dataset_path (str): The path to the dataset

    Returns:
        df (pd.DataFrame): The Pandas DataFrame containing specifications and page titles
    """

    print('>>> Creating dataframe...\n')

    progressive_id = 0
    progressive_id2row_df = {}
    for specification in os.listdir(os.path.join(dataset_path, source)):
        specification_number = specification.replace('.json', '')
        specification_id = '{}//{}'.format(source, specification_number)
        with open(os.path.join(dataset_path, source, specification)) as specification_file:
            specification_data = json.load(specification_file)
            dimensions = specification_data.get("dimensions w x h x d")
            weight = specification_data.get("weight")
            row = (specification_id, dimensions, weight)
            progressive_id2row_df.update({progressive_id: row})
            progressive_id += 1
    df = pd.DataFrame.from_dict(progressive_id2row_df, orient='index', columns=columns_df)
    print('>>> Dataframe created successfully!\n')
    return df

# %%
df = create_dataframe('../../datasets/unlabeled/2013_camera_specs', "www.cambuy.com.au",['spec_id',"dimensions w x h x d", "weight"])
# Out:
# >>> Creating dataframe...
#
# >>> Dataframe created successfully!

# %%
df.head()
# Out:
#                   spec_id                              dimensions w x h x d  \
# 0  www.cambuy.com.au//115                             109.9 x 64.1 x 27.6mm
# 1  www.cambuy.com.au//142                             95.3 x 56.8 x 23.7 mm
# 2  www.cambuy.com.au//103                                              None
# 3   www.cambuy.com.au//20  122.60x 70.7 x 54.6 mm / 4.83 x 2.78 x 2.15 inch
# 4   www.cambuy.com.au//98                                              None
#
#                                               weight
# 0                                               217g
# 1  Approx. 142 g (including battery/batteries and...
# 2                                               None
# 3  Approx. 402g / 0.89 lb （SD card, Battery, Body...
# 4  Approx. 304 g (including battery and memory card)

# %% [markdown]
# ### Weight

# %%
df[df['weight'].notnull()]
# Out:
#                     spec_id  \
# 0    www.cambuy.com.au//115
# 1    www.cambuy.com.au//142
# 3     www.cambuy.com.au//20
# 4     www.cambuy.com.au//98
# 5     www.cambuy.com.au//77
# 6    www.cambuy.com.au//139
# 7     www.cambuy.com.au//61
# 8     www.cambuy.com.au//36
# 9    www.cambuy.com.au//119
# 11   www.cambuy.com.au//158
# 12    www.cambuy.com.au//94
# 13    www.cambuy.com.au//82
# 14     www.cambuy.com.au//6
# 15   www.cambuy.com.au//162
# 17     www.cambuy.com.au//7
# 19    www.cambuy.com.au//95
# 21    www.cambuy.com.au//56
# 22    www.cambuy.com.au//17
# 24    www.cambuy.com.au//40
# 26   www.cambuy.com.au//138
# 27    www.cambuy.com.au//60
# 28    www.cambuy.com.au//99
# 29    www.cambuy.com.au//76
# 30    www.cambuy.com.au//21
# 32   www.cambuy.com.au//155
# 33   www.cambuy.com.au//143
# 34   www.cambuy.com.au//114
# 35    www.cambuy.com.au//47
# 36   www.cambuy.com.au//148
# 37    www.cambuy.com.au//10
# ..                      ...
# 78   www.cambuy.com.au//106
# 80    www.cambuy.com.au//64
# 82    www.cambuy.com.au//13
# 83    www.cambuy.com.au//52
# 84    www.cambuy.com.au//29
# 85    www.cambuy.com.au//91
# 86    www.cambuy.com.au//68
# 87    www.cambuy.com.au//87
# 89     www.cambuy.com.au//8
# 91    www.cambuy.com.au//22
# 92    www.cambuy.com.au//59
# 93   www.cambuy.com.au//101
# 94   www.cambuy.com.au//140
# 95    www.cambuy.com.au//38
# 96   www.cambuy.com.au//160
# 98    www.cambuy.com.au//79
# 101   www.cambuy.com.au//55
# 102   www.cambuy.com.au//14
# 103   www.cambuy.com.au//43
# 104   www.cambuy.com.au//15
# 105   www.cambuy.com.au//54
# 106   www.cambuy.com.au//78
# 107  www.cambuy.com.au//120
# 109  www.cambuy.com.au//136
# 110   www.cambuy.com.au//81
# 111    www.cambuy.com.au//5
# 112  www.cambuy.com.au//116
# 113  www.cambuy.com.au//157
# 114   www.cambuy.com.au//58
# 117    www.cambuy.com.au//9
#
#                                   dimensions w x h x d  \
# 0                                109.9 x 64.1 x 27.6mm
# 1                                95.3 x 56.8 x 23.7 mm
# 3     122.60x 70.7 x 54.6 mm / 4.83 x 2.78 x 2.15 inch
# 4                                                 None
# 5    Approx. 97.1 x 57.9 x 19.9 mm (3.9 x 2.3 x 0.8...
# 6                                  116.2 x 87 x 56.5mm
# 7                                111.5 x 65.9 x 31.2mm
# 8       Approx. 124 x 98 x 75.5 mm (4.9 x 3.9 x 3 in.)
# 9    Approx. 143.5 × 110 × 66.5 mm (5.6 × 4.3 × 2.6...
# 11   122.45 x 84.6 x 71.4 mm / 4.82 x 3.33 x 2.81 i...
# 12   Approx. 97.1 x 57.9 x 19.9 mm (3.9 x 2.3 x 0.8...
# 13      Approx. 124 x 98 x 75.5 mm (4.9 x 3.9 x 3 in.)
# 14                                                None
# 15                               95.3 x 56.8 x 23.7 mm
# 17    122.60x 70.7 x 54.6 mm / 4.83 x 2.78 x 2.15 inch
# 19   Approx. 93.8 x 58.4 x 19.8 mm (3.7 x 2.3 x 0.8...
# 21      Approx. 124 x 98 x 75.5 mm (4.9 x 3.9 x 3 in.)
# 22   Approx. 108.6 x 61.0 x 31.6 mm (4.3 x 2.5 x 1....
# 24   Approx. 108.6 x 61.0 x 31.6 mm (4.3 x 2.5 x 1....
# 26                                                None
# 27       Approx. 125 x 98 x 76 mm (49.2 x 3.9 x 3 in.)
# 28                              109.4 x 68.0 x 27.5 mm
# 29   Approx. 111.0 x 75.8 x 91.2 mm (4.4 x 3.0 x 3....
# 30   Approx. 97.1 x 57.9 x 19.9 mm (3.9 x 2.3 x 0.8...
# 32   Approx. 135.5 x 106.5 x 76 mm (5.3 x 4.2 x 3.0...
# 33     Approx. 141 x 113 x 82 mm (5.6 x 4.4 x 3.2 in.)
# 34      Approx.146, x123, x81.5mm (5.8, x4.9, x3.3in.)
# 35   Approx. 143.5 × 110 × 66.5 mm (5.6 × 4.3 × 2.6...
# 36       Approx. 125 x 98 x 76 mm (49.2 x 3.9 x 3 in.)
# 37    122.60x 70.7 x 54.6 mm / 4.83 x 2.78 x 2.15 inch
# ..                                                 ...
# 78                              112.7 x 65.8 x 34.8 mm
# 80   Approx. 96.8 x 57.5 x 22.9 mm (3.9 x 2.3 x 1.0...
# 82                               111.5 x 65.9 x 31.2mm
# 83      Approx. 124 x 98 x 75.5 mm (4.9 x 3.9 x 3 in.)
# 84                                                None
# 85       Approx. 125 x 98 x 76 mm (49.2 x 3.9 x 3 in.)
# 86                              112.7 x 65.8 x 34.8 mm
# 87                               95.2 x 54.3 x 22.1 mm
# 89                              120.0 x 81.7 x 91.9 mm
# 91                               100.2 x 59.0 x 29.0mm
# 92   Approx. 108.6 x 61.0 x 31.6 mm (4.3 x 2.5 x 1....
# 93   Approx. 93.8 x 58.4 x 19.8 mm (3.7 x 2.3 x 0.8...
# 94   Approx. 107.6 x 66.1 x 40.4 mm (4.3 x 2.7 x 1....
# 95   Approx. 143.5 × 110 × 66.5 mm (5.6 × 4.3 × 2.6...
# 96   Approx. 93.8 x 58.4 x 19.8 mm (3.7 x 2.3 x 0.8...
# 98   122.45 x 84.6 x 71.4 mm / 4.82 x 3.33 x 2.81 i...
# 101                                               None
# 102      Approx. 125 x 98 x 76 mm (49.2 x 3.9 x 3 in.)
# 103  Approx. 111.0 x 75.8 x 91.2 mm (4.4 x 3.0 x 3....
# 104                                               None
# 105     Approx. 124 x 98 x 75.5 mm (4.9 x 3.9 x 3 in.)
# 106                             104.4 x 69.1 x 80.1 mm
# 107                              95.2 x 54.3 x 22.1 mm
# 109                                               None
# 110  Approx. 103.0 x 58.3 x 32.0mm (4.1 x 2.3 x 1.3...
# 111                                               None
# 112                               95.2 x 54.3 x 22.1mm
# 113                          Approx.140.5 x 113 x 78mm
# 114  122.45 x 84.6 x 71.4 mm / 4.82 x 3.33 x 2.81 i...
# 117                                               None
#
#                                                 weight
# 0                                                 217g
# 1    Approx. 142 g (including battery/batteries and...
# 3    Approx. 402g / 0.89 lb （SD card, Battery, Body...
# 4    Approx. 304 g (including battery and memory card)
# 5    Approx. 125 g (4.5 oz) (with battery and SD me...
# 6    Approx. 346g [CIPA with BLS-5 Battery and Memo...
# 7                                                 247g
# 8    Approx. 460 g (1 lb 0.2 oz) with battery and m...
# 9    Approx. 765 g (1 lb 11 oz) with battery and me...
# 11   Approx. 340g / 0.75 lb （Body only) / Approx. 6...
# 12   Approx. 125 g (4.5 oz) (with battery and SD me...
# 13   Approx. 460 g (1 lb 0.2 oz) with battery and m...
# 14   497g (CIPA compliant, with BLN-1 battery and S...
# 15   Approx. 142 g (including battery/batteries and...
# 17   Approx. 402g / 0.89 lb （SD card, Battery, Body...
# 19   Approx. 120 g (4.3 oz) (with battery and SD me...
# 21   Approx. 460 g (1 lb 0.2 oz) with battery and m...
# 22   Approx. 206 g (7.3 oz) (including battery and ...
# 24   Approx. 206 g (7.3 oz) (including battery and ...
# 26       209g (unloaded) 229g (with battery & SD card)
# 27   Approx. 530 g (1 lb 2.7 oz) with battery and m...
# 28   Approx. 218 g (including battery/batteries and...
# 29   Approx. 508 g (1 lb 2.0 oz) (including batteri...
# 30   Approx. 125 g (4.5 oz) (with battery and SD me...
# 32   Approx. 765 g (1 lb 11.0 oz) with battery and ...
# 33   Approx. 850 g (1 lb 14.0 oz) with battery and ...
# 34   Approx.980g (2 lb 2.6 oz), with battery and SD...
# 35   Approx. 765 g (1 lb 11 oz) with battery and me...
# 36   Approx. 530 g (1 lb 2.7 oz) with battery and m...
# 37   Approx. 402g / 0.89 lb （SD card, Battery, Body...
# ..                                                 ...
# 78   Approx. 269 g (including battery/batteries and...
# 80   Approx. 145 g (5.2 oz) (including battery and ...
# 82                                                247g
# 83   Approx. 460 g (1 lb 0.2 oz) with battery and m...
# 84   Approx. 558 g (including battery/batteries and...
# 85   Approx. 530 g (1 lb 2.7 oz) with battery and m...
# 86   Approx. 269 g (including battery/batteries and...
# 87   Approx. 127 g (including battery/batteries and...
# 89   Approx. 441 g (including battery and memory card)
# 91   Approx. 217 g (including battery/batteries and...
# 92   Approx. 206 g (7.3 oz) (including battery and ...
# 93   Approx. 120 g (4.3 oz) (with battery and SD me...
# 94   Approx. 175 g (6.2 oz) (including battery and ...
# 95   Approx. 765 g (1 lb 11 oz) with battery and me...
# 96   Approx. 120 g (4.3 oz) (with battery and SD me...
# 98   Approx. 340g / 0.75 lb （Body only) / Approx. 6...
# 101  Approx. 687 g (including battery and memory card)
# 102  Approx. 530 g (1 lb 2.7 oz) with battery and m...
# 103  Approx. 508 g (1 lb 2.0 oz) (including batteri...
# 104  497g (CIPA compliant, with BLN-1 battery and S...
# 105  Approx. 460 g (1 lb 0.2 oz) with battery and m...
# 106  Approx. 313 g (including battery and memory card)
# 107  Approx. 127 g (including battery/batteries and...
# 109  Approx. 650 g (including battery and memory card)
# 110  Approx. 194 g (6.9 oz) (including battery and ...
# 111  Approx. 351 g without Battery and SD Memory Ca...
# 112  Approx. 130g (including battery/batteries and ...
# 113  Approx.840g, with battery and memory card but ...
# 114  Approx. 340g / 0.75 lb （Body only) / Approx. 6...
# 117  Approx. 214 g without Battery and SD Memory Ca...
#
# [91 rows x 3 columns]

# %%
def parse_weight(value):

    if pd.isna(value):
        return value
    else:
#         print(value)
        match1 = re.search('(Approx.|Approx.|)(\d*\,\d+|\d+)( g|g)', str(value))
        if match1 is None: 
            print("SKIP")
            print(value)
            return float("NaN")

        return float(match1.group(2))

# %%
df["weight"] = df["weight"].apply(parse_weight)

# %%
df.head()
# Out:
#                   spec_id                              dimensions w x h x d  \
# 0  www.cambuy.com.au//115                             109.9 x 64.1 x 27.6mm
# 1  www.cambuy.com.au//142                             95.3 x 56.8 x 23.7 mm
# 2  www.cambuy.com.au//103                                              None
# 3   www.cambuy.com.au//20  122.60x 70.7 x 54.6 mm / 4.83 x 2.78 x 2.15 inch
# 4   www.cambuy.com.au//98                                              None
#
#    weight
# 0   217.0
# 1   142.0
# 2     NaN
# 3   402.0
# 4   304.0

# %% [markdown]
# ## w x h x d

# %%
df[df['dimensions w x h x d'].notnull()]
# Out:
#                     spec_id  \
# 0    www.cambuy.com.au//115
# 1    www.cambuy.com.au//142
# 3     www.cambuy.com.au//20
# 5     www.cambuy.com.au//77
# 6    www.cambuy.com.au//139
# 7     www.cambuy.com.au//61
# 8     www.cambuy.com.au//36
# 9    www.cambuy.com.au//119
# 10    www.cambuy.com.au//16
# 11   www.cambuy.com.au//158
# 12    www.cambuy.com.au//94
# 13    www.cambuy.com.au//82
# 15   www.cambuy.com.au//162
# 16   www.cambuy.com.au//163
# 17     www.cambuy.com.au//7
# 18    www.cambuy.com.au//83
# 19    www.cambuy.com.au//95
# 20   www.cambuy.com.au//122
# 21    www.cambuy.com.au//56
# 22    www.cambuy.com.au//17
# 23   www.cambuy.com.au//118
# 24    www.cambuy.com.au//40
# 25    www.cambuy.com.au//37
# 27    www.cambuy.com.au//60
# 28    www.cambuy.com.au//99
# 29    www.cambuy.com.au//76
# 30    www.cambuy.com.au//21
# 32   www.cambuy.com.au//155
# 33   www.cambuy.com.au//143
# 34   www.cambuy.com.au//114
# ..                      ...
# 82    www.cambuy.com.au//13
# 83    www.cambuy.com.au//52
# 85    www.cambuy.com.au//91
# 86    www.cambuy.com.au//68
# 87    www.cambuy.com.au//87
# 88    www.cambuy.com.au//63
# 89     www.cambuy.com.au//8
# 90    www.cambuy.com.au//75
# 91    www.cambuy.com.au//22
# 92    www.cambuy.com.au//59
# 93   www.cambuy.com.au//101
# 94   www.cambuy.com.au//140
# 95    www.cambuy.com.au//38
# 96   www.cambuy.com.au//160
# 97    www.cambuy.com.au//80
# 98    www.cambuy.com.au//79
# 99   www.cambuy.com.au//121
# 100   www.cambuy.com.au//96
# 102   www.cambuy.com.au//14
# 103   www.cambuy.com.au//43
# 105   www.cambuy.com.au//54
# 106   www.cambuy.com.au//78
# 107  www.cambuy.com.au//120
# 108   www.cambuy.com.au//97
# 110   www.cambuy.com.au//81
# 112  www.cambuy.com.au//116
# 113  www.cambuy.com.au//157
# 114   www.cambuy.com.au//58
# 115  www.cambuy.com.au//100
# 116   www.cambuy.com.au//74
#
#                                   dimensions w x h x d  weight
# 0                                109.9 x 64.1 x 27.6mm   217.0
# 1                                95.3 x 56.8 x 23.7 mm   142.0
# 3     122.60x 70.7 x 54.6 mm / 4.83 x 2.78 x 2.15 inch   402.0
# 5    Approx. 97.1 x 57.9 x 19.9 mm (3.9 x 2.3 x 0.8...   125.0
# 6                                  116.2 x 87 x 56.5mm   346.0
# 7                                111.5 x 65.9 x 31.2mm   247.0
# 8       Approx. 124 x 98 x 75.5 mm (4.9 x 3.9 x 3 in.)   460.0
# 9    Approx. 143.5 × 110 × 66.5 mm (5.6 × 4.3 × 2.6...   765.0
# 10                               116.8 x 90.7 x 69.4mm     NaN
# 11   122.45 x 84.6 x 71.4 mm / 4.82 x 3.33 x 2.81 i...   340.0
# 12   Approx. 97.1 x 57.9 x 19.9 mm (3.9 x 2.3 x 0.8...   125.0
# 13      Approx. 124 x 98 x 75.5 mm (4.9 x 3.9 x 3 in.)   460.0
# 15                               95.3 x 56.8 x 23.7 mm   142.0
# 16                       Approx. 96.0 x 54.9 x 25.7 mm     NaN
# 17    122.60x 70.7 x 54.6 mm / 4.83 x 2.78 x 2.15 inch   402.0
# 18                                139 x 104.3 x 78.5mm     NaN
# 19   Approx. 93.8 x 58.4 x 19.8 mm (3.7 x 2.3 x 0.8...   120.0
# 20                      Approx. 120.0 x 66.9 x 45.1 mm     NaN
# 21      Approx. 124 x 98 x 75.5 mm (4.9 x 3.9 x 3 in.)   460.0
# 22   Approx. 108.6 x 61.0 x 31.6 mm (4.3 x 2.5 x 1....   206.0
# 23                    Approx. 96.4mm x 59.3mm x 15.4mm     NaN
# 24   Approx. 108.6 x 61.0 x 31.6 mm (4.3 x 2.5 x 1....   206.0
# 25                                139 x 104.3 x 78.5mm     NaN
# 27       Approx. 125 x 98 x 76 mm (49.2 x 3.9 x 3 in.)   530.0
# 28                              109.4 x 68.0 x 27.5 mm   218.0
# 29   Approx. 111.0 x 75.8 x 91.2 mm (4.4 x 3.0 x 3....   508.0
# 30   Approx. 97.1 x 57.9 x 19.9 mm (3.9 x 2.3 x 0.8...   125.0
# 32   Approx. 135.5 x 106.5 x 76 mm (5.3 x 4.2 x 3.0...   765.0
# 33     Approx. 141 x 113 x 82 mm (5.6 x 4.4 x 3.2 in.)   850.0
# 34      Approx.146, x123, x81.5mm (5.8, x4.9, x3.3in.)   980.0
# ..                                                 ...     ...
# 82                               111.5 x 65.9 x 31.2mm   247.0
# 83      Approx. 124 x 98 x 75.5 mm (4.9 x 3.9 x 3 in.)   460.0
# 85       Approx. 125 x 98 x 76 mm (49.2 x 3.9 x 3 in.)   530.0
# 86                              112.7 x 65.8 x 34.8 mm   269.0
# 87                               95.2 x 54.3 x 22.1 mm   127.0
# 88                                139 x 104.3 x 78.5mm     NaN
# 89                              120.0 x 81.7 x 91.9 mm   441.0
# 90                               116.8 x 90.7 x 69.4mm     NaN
# 91                               100.2 x 59.0 x 29.0mm   217.0
# 92   Approx. 108.6 x 61.0 x 31.6 mm (4.3 x 2.5 x 1....   206.0
# 93   Approx. 93.8 x 58.4 x 19.8 mm (3.7 x 2.3 x 0.8...   120.0
# 94   Approx. 107.6 x 66.1 x 40.4 mm (4.3 x 2.7 x 1....   175.0
# 95   Approx. 143.5 × 110 × 66.5 mm (5.6 × 4.3 × 2.6...   765.0
# 96   Approx. 93.8 x 58.4 x 19.8 mm (3.7 x 2.3 x 0.8...   120.0
# 97                               116.8 x 90.7 x 69.4mm     NaN
# 98   122.45 x 84.6 x 71.4 mm / 4.82 x 3.33 x 2.81 i...   340.0
# 99                                93.1 x 52.5 x 22.5mm     NaN
# 100                              133.1 x 99.8 x 78.8mm     NaN
# 102      Approx. 125 x 98 x 76 mm (49.2 x 3.9 x 3 in.)   530.0
# 103  Approx. 111.0 x 75.8 x 91.2 mm (4.4 x 3.0 x 3....   508.0
# 105     Approx. 124 x 98 x 75.5 mm (4.9 x 3.9 x 3 in.)   460.0
# 106                             104.4 x 69.1 x 80.1 mm   313.0
# 107                              95.2 x 54.3 x 22.1 mm   127.0
# 108                     Approx. 108.1 x 63.6 x 38.3 mm     NaN
# 110  Approx. 103.0 x 58.3 x 32.0mm (4.1 x 2.3 x 1.3...   194.0
# 112                               95.2 x 54.3 x 22.1mm   130.0
# 113                          Approx.140.5 x 113 x 78mm   840.0
# 114  122.45 x 84.6 x 71.4 mm / 4.82 x 3.33 x 2.81 i...   340.0
# 115                               139 x 104.3 x 78.5mm     NaN
# 116                     Approx. 129.0 x 88.1 x 102.2mm     NaN
#
# [99 rows x 3 columns]

# %%
def mm_to_inches(value):
    
    return round(float(value) / 25.4, 1)

# %%
def parse_whd(value):
    if pd.isna(value):
        return value
    else:
        m = re.search('(Approx. |)(\d*\.\d+|\d*\,\d+|\d+)(x | x |× | × )(\d*\.\d+|\d*\,\d+|\d+)(x | x |× | × )(\d*\.\d+|\d*\,\d+|\d+)( mm|mm)', str(value))
        if m is None:

            print("SKIP")
            print(value)
            return float("NaN")

        return 'h' + str(mm_to_inches(m.group(2).replace(",","."))) + 'w' + str(mm_to_inches(m.group(4).replace(",","."))) + "d" + str(mm_to_inches(m.group(6).replace(",",".")))

# %%
df["dimensions w x h x d"] = df["dimensions w x h x d"].apply(parse_whd)
# Out:
# SKIP
# Approx. 96.4mm x 59.3mm x 15.4mm
# SKIP
# Approx.146, x123, x81.5mm (5.8, x4.9, x3.3in.)
# SKIP
# 101.6 x 58.1x 41. mm

# %%
# Miss 3

# %%
df.head()
# Out:
#                   spec_id    dimensions  weight
# 0  www.cambuy.com.au//115  h4.3w2.5d1.1   217.0
# 1  www.cambuy.com.au//142  h3.8w2.2d0.9   142.0
# 2  www.cambuy.com.au//103          None     NaN
# 3   www.cambuy.com.au//20  h4.8w2.8d2.1   402.0
# 4   www.cambuy.com.au//98          None   304.0

# %% [markdown]
# ### Final cleaning

# %%
df.columns=['spec_id','dimensions',"weight" ]

# %%
df.to_csv("../../datasets/unlabeled/cleaned/cambuy.csv", index=False)

# %%
import os
import numpy as np
import json
import pandas as pd
import itertools
from tqdm import tqdm
import nltk
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
import re

# %%
def create_dataframe(dataset_path, source):
    """Function used to create a Pandas DataFrame containing specifications page titles

    Reads products specifications from the file system ("dataset_path" variable in the main function) and creates a Pandas DataFrame where each row is a
    specification. The columns are 'source' (e.g. www.sourceA.com), 'spec_number' (e.g. 1) and the 'page title'. Note that this script will consider only
    the page title attribute for simplicity.

    Args:
        dataset_path (str): The path to the dataset

    Returns:
        df (pd.DataFrame): The Pandas DataFrame containing specifications and page titles
    """

    print('>>> Creating dataframe...\n')
    columns_df = ['source', 'spec_number', 'spec_id', 'page_title']
    
    df = pd.DataFrame()
    progressive_id = 0
    progressive_id2row_df = {}
    #for source in tqdm(os.listdir(dataset_path)):
    #source = "buy.net"
    for specification in os.listdir(os.path.join(dataset_path, source)):
        specification_number = specification.replace('.json', '')
        specification_id = '{}//{}'.format(source, specification_number)
        with open(os.path.join(dataset_path, source, specification)) as specification_file:
            columns_df = ['source', 'spec_number', 'spec_id']
            specification_data = json.load(specification_file)
            attrs = []
            for k, v in specification_data.items():
                columns_df.append(k)
                attrs.append(v)
            row = [source, specification_number, specification_id]
            row.extend(attrs)
            progressive_id2row_df.update({progressive_id: row})
            progressive_id += 1
            df = df.append(pd.DataFrame.from_dict(progressive_id2row_df, orient='index', columns=columns_df))
            progressive_id2row_df = {}
    #print(df)
    print('>>> Dataframe created successfully!\n')
    return df

# %%
df = create_dataframe('../../datasets/unlabeled/2013_camera_specs', "www.shopmania.in")
# Out:
# >>> Creating dataframe...
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# >>> Dataframe created successfully!

# %%
cols = ['spec_id',"brand", "product name", "resolution", "screen size"]

# %%
df = df[cols]

# %%
df.head()
# Out:
#                   spec_id     brand               product name  \
# 0  www.shopmania.in//1659      Sony              Sony DSC-W630
# 1  www.shopmania.in//1120   Samsung               Samsung ES75
# 2  www.shopmania.in//1570      Sony               Sony DSC-RX1
# 3  www.shopmania.in//1065     Canon  Canon EOS 60D kit 18-55mm
# 4  www.shopmania.in//1527  Fujifilm               Fujifilm XQ1
#
#                 resolution         screen size
# 0  16.1 MP (more than 84%)                2.7"
# 1  14.2 MP (more than 75%)                2.7"
# 2  24.3 MP (more than 98%)  3" (more than 62%)
# 3    18 MP (more than 90%)  3" (more than 62%)
# 4    12 MP (more than 51%)  3" (more than 62%)

# %% [markdown]
# ## Brand

# %%
df['brand'] = df['brand'].apply(lambda x: x.lower())

# %%
df.head()
# Out:
#                   spec_id     brand               product name  \
# 0  www.shopmania.in//1659      sony              Sony DSC-W630
# 1  www.shopmania.in//1120   samsung               Samsung ES75
# 2  www.shopmania.in//1570      sony               Sony DSC-RX1
# 3  www.shopmania.in//1065     canon  Canon EOS 60D kit 18-55mm
# 4  www.shopmania.in//1527  fujifilm               Fujifilm XQ1
#
#                 resolution         screen size
# 0  16.1 MP (more than 84%)                2.7"
# 1  14.2 MP (more than 75%)                2.7"
# 2  24.3 MP (more than 98%)  3" (more than 62%)
# 3    18 MP (more than 90%)  3" (more than 62%)
# 4    12 MP (more than 51%)  3" (more than 62%)

# %% [markdown]
# ## Product name

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
stop_words = set(['itself', 'down', 'by', 'with', 'doesn', 'wouldn', 'other', 'ours', 'of', 'then', 'where', 'don', 'these', 'nor', 'she', "should've", 'won', 'ma', 'from', 'had', "you're", 'our', 'did', 'them', 'too', 'her', 'that', 'haven', 'after', "you'll", 'hers', 'because', 'yourself', 'against', 'mightn', 'as', 'll', 'whom', 'how', 'couldn', 'further', 'aren', "you'd", 'and', 'needn', "couldn't", 'those', 'to', "doesn't", "weren't", 'both', 'ourselves', 'in', 'which', 'yours', 'under', 'some', 'what', 'during', 'before', "needn't", "shan't", 'here', 'having', 'hasn', 'your', "hasn't", 'between', 'me', "she's", 'into', 'all', 'at', 'shan', 'who', 'o', 'an', 'very', 'can', 'you', 'shouldn', 'such', 'but', 'do', 'out', 'am', "shouldn't", 'above', 'wasn', 'or', 'were', 'own', 'didn', "you've", 'on', 'will', 'my', 'it', 'have', 'once', 'only', 'been', 'themselves', 'his', 'be', "mightn't", 'they', 'not', 'so', 'up', 'any', 'most', 'has', 'myself', 't', 'yourselves', 'isn', "it's", 'y', 'm', 'now', 'until', 're', 'there', 'their', 'mustn', "mustn't", 'again', 'being', 'hadn', 'doing', 'just', 'no', 'if', 've', "wasn't", "won't", 'we', 'below', 'does', 'more', 'this', 'should', "isn't", 'ain', "don't", 'i', "haven't", 'than', "didn't", 'are', 'about', 'off', 'him', 'for', 'few', "wouldn't", 'was', 'weren', 'why', 'he', "that'll", 'd', 'the', 'its', 'a', 'each', 'is', 'while', "aren't", 'when', 'theirs', 'same', 's', 'himself', 'herself', "hadn't", 'through', 'over'])
punctuation = "!#$%&'()*+,-./:;<=>?@[\]^_`{|}~€£¥₹₽"
def replace_punctuation(word):
    return ''.join(c for c in word if c not in punctuation)

def tokenize_stop_words_punctuation(x):
    return [i.lower() for i in list(map(lambda y: replace_punctuation(y), word_tokenize(str(x)))) if i and i.lower() not in stop_words]

# %%
df['product name'] = df['product name'].apply(tokenize_stop_words_punctuation)

# %%
df.head()
# Out:
#                   spec_id     brand                    product name  \
# 0  www.shopmania.in//1659      sony                 [sony, dscw630]
# 1  www.shopmania.in//1120   samsung                 [samsung, es75]
# 2  www.shopmania.in//1570      sony                  [sony, dscrx1]
# 3  www.shopmania.in//1065     canon  [canon, eos, 60d, kit, 1855mm]
# 4  www.shopmania.in//1527  fujifilm                 [fujifilm, xq1]
#
#                 resolution         screen size
# 0  16.1 MP (more than 84%)                2.7"
# 1  14.2 MP (more than 75%)                2.7"
# 2  24.3 MP (more than 98%)  3" (more than 62%)
# 3    18 MP (more than 90%)  3" (more than 62%)
# 4    12 MP (more than 51%)  3" (more than 62%)

# %% [markdown]
# ### Resolution

# %%
df[df['resolution'].notnull()]
# Out:
#                     spec_id      brand  \
# 0    www.shopmania.in//1659       sony
# 1    www.shopmania.in//1120    samsung
# 2    www.shopmania.in//1570       sony
# 3    www.shopmania.in//1065      canon
# 4    www.shopmania.in//1527   fujifilm
# 5    www.shopmania.in//1177   fujifilm
# 6     www.shopmania.in//904      nikon
# 7    www.shopmania.in//1462       sony
# 8    www.shopmania.in//1032   fujifilm
# 9    www.shopmania.in//1618       sony
# 10   www.shopmania.in//1248      canon
# 11   www.shopmania.in//1531      kodak
# 12   www.shopmania.in//1474      nikon
# 13    www.shopmania.in//912    samsung
# 14   www.shopmania.in//1136      canon
# 15    www.shopmania.in//945      kodak
# 16   www.shopmania.in//1423   fujifilm
# 17   www.shopmania.in//1589    olympus
# 18   www.shopmania.in//1264      canon
# 19    www.shopmania.in//894       sony
# 20   www.shopmania.in//1458       sony
# 21   www.shopmania.in//1399    olympus
# 22   www.shopmania.in//1663      casio
# 23   www.shopmania.in//1233      canon
# 24   www.shopmania.in//1726      canon
# 25   www.shopmania.in//1376      nikon
# 26   www.shopmania.in//1225       sony
# 27    www.shopmania.in//640      nikon
# 28   www.shopmania.in//1360      canon
# 29    www.shopmania.in//705  panasonic
# ..                      ...        ...
# 600  www.shopmania.in//1524       sony
# 601  www.shopmania.in//1477    samsung
# 602  www.shopmania.in//1498       sony
# 603  www.shopmania.in//1162      canon
# 604  www.shopmania.in//1532      nikon
# 605   www.shopmania.in//854  panasonic
# 606   www.shopmania.in//696  panasonic
# 607  www.shopmania.in//1709      casio
# 608  www.shopmania.in//1420       sony
# 609   www.shopmania.in//946      canon
# 610  www.shopmania.in//1565   fujifilm
# 611  www.shopmania.in//1135    olympus
# 612  www.shopmania.in//1267      canon
# 613   www.shopmania.in//878    olympus
# 614  www.shopmania.in//1725       sony
# 615   www.shopmania.in//710       sony
# 616   www.shopmania.in//655      nikon
# 617  www.shopmania.in//1660   fujifilm
# 618  www.shopmania.in//1119    samsung
# 619  www.shopmania.in//1549      canon
# 620  www.shopmania.in//1363      nikon
# 621   www.shopmania.in//706  panasonic
# 622  www.shopmania.in//1226       sony
# 623   www.shopmania.in//643    olympus
# 624   www.shopmania.in//993      canon
# 625  www.shopmania.in//1621       sony
# 626  www.shopmania.in//1271      nikon
# 627  www.shopmania.in//1158      canon
# 628  www.shopmania.in//1508       sony
# 629   www.shopmania.in//881     pentax
#
#                                           product name  \
# 0                                      [sony, dscw630]
# 1                                      [samsung, es75]
# 2                                       [sony, dscrx1]
# 3                       [canon, eos, 60d, kit, 1855mm]
# 4                                      [fujifilm, xq1]
# 5                           [fujifilm, finepix, s4800]
# 6                         [nikon, d7100, kit, 18140mm]
# 7                           [sony, cybershot, dsch100]
# 8                                      [fujifilm, xs1]
# 9                                 [sony, slta99, body]
# 10                           [canon, powershot, sx150]
# 11                          [kodak, m522, kodak, m522]
# 12                                       [nikon, l310]
# 13                                    [samsung, wb30f]
# 14                     [canon, eos, 650d, kit, 1855mm]
# 15    [kodak, easyshare, c143, kodak, easyshare, c143]
# 16                   [fujifilm, finepix, real, 3d, w3]
# 17                                    [olympus, vg150]
# 18   [canon, eos, 1000d, body, canon, eos, 1000d, b...
# 19                        [sony, slta77, kit, 18135mm]
# 20                             [sony, alpha, 7r, body]
# 21                                [olympus, pen, epm2]
# 22   [casio, exilim, hizoom, exh5, casio, exilim, h...
# 23      [canon, powershot, d10, canon, powershot, d10]
# 24                     [canon, eos, 600d, kit, 1855mm]
# 25   [nikon, 1, v1, kit, 1030mm, nikon, 1, v1, kit,...
# 26            [sony, slta65, body, sony, slta65, body]
# 27                              [nikon, coolpix, p600]
# 28      [canon, powershot, s90, canon, powershot, s90]
# 29   [panasonic, lumix, dmcfh20, panasonic, lumix, ...
# ..                                                 ...
# 600                        [sony, cybershot, dscwx220]
# 601                   [samsung, st200, samsung, st200]
# 602                        [sony, cybershot, dschx300]
# 603                        [canonpowershot, sx240, hs]
# 604                            [nikon, coolpix, s9500]
# 605             [panasonic, dmcsz7, panasonic, dmcsz7]
# 606                        [panasonic, lumix, dmcfs42]
# 607  [casio, exilim, zoom, exz33, casio, exilim, zo...
# 608                          [sony, nex3, kit, 1855mm]
# 609                    [canon, digital, ixus, 115, hs]
# 610                                  [fujifilm, sl260]
# 611                         [olympus, pen, epl5, body]
# 612   [canon, powershot, sx30, canon, powershot, sx30]
# 613                 [olympus, fe4020, olympus, fe4020]
# 614                     [sony, dsctx20, sony, dsctx20]
# 615                         [sony, cybershot, dscwx80]
# 616                        [nikon, d3300, kit, 1855mm]
# 617                         [fujifilm, finepix, s8500]
# 618                                  [samsung, st6500]
# 619                    [canon, eos, 60d, kit, 18200mm]
# 620                              [nikon, coolpix, s31]
# 621  [panasonic, lumix, dmczr3, panasonic, lumix, d...
# 622                        [sony, cybershot, dscwx300]
# 623           [olympus, mju, 9010, olympus, mju, 9010]
# 624                            [canon, powershot, g12]
# 625                      [sony, slta55, kit, 1855, mm]
# 626     [nikon, coolpix, p7000, nikon, coolpix, p7000]
# 627                                 [canon, ixus, 135]
# 628  [sony, cybershot, dscw370, sony, cybershot, ds...
# 629                                     [pentax, wg10]
#
#                   resolution           screen size
# 0    16.1 MP (more than 84%)                  2.7"
# 1    14.2 MP (more than 75%)                  2.7"
# 2    24.3 MP (more than 98%)    3" (more than 62%)
# 3      18 MP (more than 90%)    3" (more than 62%)
# 4      12 MP (more than 51%)    3" (more than 62%)
# 5      16 MP (more than 78%)    3" (more than 62%)
# 6    24.1 MP (more than 98%)                   NaN
# 7    16.1 MP (more than 84%)    3" (more than 62%)
# 8      12 MP (more than 51%)    3" (more than 62%)
# 9    24.3 MP (more than 98%)    3" (more than 62%)
# 10   14.1 MP (more than 73%)    3" (more than 62%)
# 11     14 MP (more than 67%)                  2.7"
# 12     14 MP (more than 67%)    3" (more than 62%)
# 13   16.2 MP (more than 88%)    3" (more than 62%)
# 14     18 MP (more than 90%)    3" (more than 62%)
# 15     12 MP (more than 51%)                  2.7"
# 16                     10 MP  3.5" (more than 98%)
# 17     12 MP (more than 51%)                  2.7"
# 18                   10.1 MP                  2.5"
# 19   24.3 MP (more than 98%)    3" (more than 62%)
# 20     36 MP (more than 99%)    3" (more than 62%)
# 21   16.1 MP (more than 84%)    3" (more than 62%)
# 22   12.1 MP (more than 57%)                  2.7"
# 23   12.1 MP (more than 57%)                  2.5"
# 24     18 MP (more than 90%)    3" (more than 62%)
# 25                   10.1 MP    3" (more than 62%)
# 26   24.3 MP (more than 98%)    3" (more than 62%)
# 27     16 MP (more than 78%)    3" (more than 62%)
# 28                     10 MP    3" (more than 62%)
# 29     14 MP (more than 67%)                  2.7"
# ..                       ...                   ...
# 600  18.2 MP (more than 94%)                  2.7"
# 601  16.2 MP (more than 88%)    3" (more than 62%)
# 602    20 MP (more than 95%)    3" (more than 62%)
# 603  12.1 MP (more than 57%)    3" (more than 62%)
# 604  18.1 MP (more than 94%)    3" (more than 62%)
# 605  14.1 MP (more than 73%)    3" (more than 62%)
# 606                  10.1 MP                  2.5"
# 607                  10.1 MP                  2.5"
# 608  14.2 MP (more than 75%)    3" (more than 62%)
# 609  12.1 MP (more than 57%)    3" (more than 62%)
# 610    14 MP (more than 67%)    3" (more than 62%)
# 611  16.1 MP (more than 84%)    3" (more than 62%)
# 612  14.1 MP (more than 73%)                  2.7"
# 613    14 MP (more than 67%)                  2.7"
# 614  16.2 MP (more than 88%)    3" (more than 62%)
# 615  16.2 MP (more than 88%)                  2.7"
# 616    24 MP (more than 97%)    3" (more than 62%)
# 617    16 MP (more than 78%)    3" (more than 62%)
# 618  16.1 MP (more than 84%)    3" (more than 62%)
# 619    18 MP (more than 90%)    3" (more than 62%)
# 620                  10.1 MP                  2.7"
# 621  14.1 MP (more than 73%)                  2.7"
# 622    18 MP (more than 90%)    3" (more than 62%)
# 623    14 MP (more than 67%)                  2.7"
# 624                    10 MP  2.8" (more than 61%)
# 625  16.2 MP (more than 88%)    3" (more than 62%)
# 626                  10.1 MP    3" (more than 62%)
# 627    16 MP (more than 78%)                  2.7"
# 628  14.1 MP (more than 73%)    3" (more than 62%)
# 629    14 MP (more than 67%)                  2.7"
#
# [614 rows x 5 columns]

# %%
def parse_megapixels(value):
    if pd.isna(value):
        return value
    else:
        match1 = re.search('(\d*\,\d+|\d+) MP', str(value))
        if match1 is None: 
            print("SKIP")
            print(value)
            return float("NaN")


        return (match1.group(1).replace(",","."))

# %%
df["resolution"] = df["resolution"].apply(parse_megapixels)

# %%
df.head()
# Out:
#                   spec_id     brand                    product name  \
# 0  www.shopmania.in//1659      sony                 [sony, dscw630]
# 1  www.shopmania.in//1120   samsung                 [samsung, es75]
# 2  www.shopmania.in//1570      sony                  [sony, dscrx1]
# 3  www.shopmania.in//1065     canon  [canon, eos, 60d, kit, 1855mm]
# 4  www.shopmania.in//1527  fujifilm                 [fujifilm, xq1]
#
#   resolution         screen size
# 0          1                2.7"
# 1          2                2.7"
# 2          3  3" (more than 62%)
# 3         18  3" (more than 62%)
# 4         12  3" (more than 62%)

# %% [markdown]
# ## Screen size

# %%
df[df['screen size'].notnull()]
# Out:
#                     spec_id      brand  \
# 0    www.shopmania.in//1659       sony
# 1    www.shopmania.in//1120    samsung
# 2    www.shopmania.in//1570       sony
# 3    www.shopmania.in//1065      canon
# 4    www.shopmania.in//1527   fujifilm
# 5    www.shopmania.in//1177   fujifilm
# 7    www.shopmania.in//1462       sony
# 8    www.shopmania.in//1032   fujifilm
# 9    www.shopmania.in//1618       sony
# 10   www.shopmania.in//1248      canon
# 11   www.shopmania.in//1531      kodak
# 12   www.shopmania.in//1474      nikon
# 13    www.shopmania.in//912    samsung
# 14   www.shopmania.in//1136      canon
# 15    www.shopmania.in//945      kodak
# 16   www.shopmania.in//1423   fujifilm
# 17   www.shopmania.in//1589    olympus
# 18   www.shopmania.in//1264      canon
# 19    www.shopmania.in//894       sony
# 20   www.shopmania.in//1458       sony
# 21   www.shopmania.in//1399    olympus
# 22   www.shopmania.in//1663      casio
# 23   www.shopmania.in//1233      canon
# 24   www.shopmania.in//1726      canon
# 25   www.shopmania.in//1376      nikon
# 26   www.shopmania.in//1225       sony
# 27    www.shopmania.in//640      nikon
# 28   www.shopmania.in//1360      canon
# 29    www.shopmania.in//705  panasonic
# 30   www.shopmania.in//1730     pentax
# ..                      ...        ...
# 600  www.shopmania.in//1524       sony
# 601  www.shopmania.in//1477    samsung
# 602  www.shopmania.in//1498       sony
# 603  www.shopmania.in//1162      canon
# 604  www.shopmania.in//1532      nikon
# 605   www.shopmania.in//854  panasonic
# 606   www.shopmania.in//696  panasonic
# 607  www.shopmania.in//1709      casio
# 608  www.shopmania.in//1420       sony
# 609   www.shopmania.in//946      canon
# 610  www.shopmania.in//1565   fujifilm
# 611  www.shopmania.in//1135    olympus
# 612  www.shopmania.in//1267      canon
# 613   www.shopmania.in//878    olympus
# 614  www.shopmania.in//1725       sony
# 615   www.shopmania.in//710       sony
# 616   www.shopmania.in//655      nikon
# 617  www.shopmania.in//1660   fujifilm
# 618  www.shopmania.in//1119    samsung
# 619  www.shopmania.in//1549      canon
# 620  www.shopmania.in//1363      nikon
# 621   www.shopmania.in//706  panasonic
# 622  www.shopmania.in//1226       sony
# 623   www.shopmania.in//643    olympus
# 624   www.shopmania.in//993      canon
# 625  www.shopmania.in//1621       sony
# 626  www.shopmania.in//1271      nikon
# 627  www.shopmania.in//1158      canon
# 628  www.shopmania.in//1508       sony
# 629   www.shopmania.in//881     pentax
#
#                                           product name resolution  \
# 0                                      [sony, dscw630]          1
# 1                                      [samsung, es75]          2
# 2                                       [sony, dscrx1]          3
# 3                       [canon, eos, 60d, kit, 1855mm]         18
# 4                                      [fujifilm, xq1]         12
# 5                           [fujifilm, finepix, s4800]         16
# 7                           [sony, cybershot, dsch100]          1
# 8                                      [fujifilm, xs1]         12
# 9                                 [sony, slta99, body]          3
# 10                           [canon, powershot, sx150]          1
# 11                          [kodak, m522, kodak, m522]         14
# 12                                       [nikon, l310]         14
# 13                                    [samsung, wb30f]          2
# 14                     [canon, eos, 650d, kit, 1855mm]         18
# 15    [kodak, easyshare, c143, kodak, easyshare, c143]         12
# 16                   [fujifilm, finepix, real, 3d, w3]         10
# 17                                    [olympus, vg150]         12
# 18   [canon, eos, 1000d, body, canon, eos, 1000d, b...          1
# 19                        [sony, slta77, kit, 18135mm]          3
# 20                             [sony, alpha, 7r, body]         36
# 21                                [olympus, pen, epm2]          1
# 22   [casio, exilim, hizoom, exh5, casio, exilim, h...          1
# 23      [canon, powershot, d10, canon, powershot, d10]          1
# 24                     [canon, eos, 600d, kit, 1855mm]         18
# 25   [nikon, 1, v1, kit, 1030mm, nikon, 1, v1, kit,...          1
# 26            [sony, slta65, body, sony, slta65, body]          3
# 27                              [nikon, coolpix, p600]         16
# 28      [canon, powershot, s90, canon, powershot, s90]         10
# 29   [panasonic, lumix, dmcfh20, panasonic, lumix, ...         14
# 30        [pentax, optio, ls465, pentax, optio, ls465]         16
# ..                                                 ...        ...
# 600                        [sony, cybershot, dscwx220]          2
# 601                   [samsung, st200, samsung, st200]          2
# 602                        [sony, cybershot, dschx300]         20
# 603                        [canonpowershot, sx240, hs]          1
# 604                            [nikon, coolpix, s9500]          1
# 605             [panasonic, dmcsz7, panasonic, dmcsz7]          1
# 606                        [panasonic, lumix, dmcfs42]          1
# 607  [casio, exilim, zoom, exz33, casio, exilim, zo...          1
# 608                          [sony, nex3, kit, 1855mm]          2
# 609                    [canon, digital, ixus, 115, hs]          1
# 610                                  [fujifilm, sl260]         14
# 611                         [olympus, pen, epl5, body]          1
# 612   [canon, powershot, sx30, canon, powershot, sx30]          1
# 613                 [olympus, fe4020, olympus, fe4020]         14
# 614                     [sony, dsctx20, sony, dsctx20]          2
# 615                         [sony, cybershot, dscwx80]          2
# 616                        [nikon, d3300, kit, 1855mm]         24
# 617                         [fujifilm, finepix, s8500]         16
# 618                                  [samsung, st6500]          1
# 619                    [canon, eos, 60d, kit, 18200mm]         18
# 620                              [nikon, coolpix, s31]          1
# 621  [panasonic, lumix, dmczr3, panasonic, lumix, d...          1
# 622                        [sony, cybershot, dscwx300]         18
# 623           [olympus, mju, 9010, olympus, mju, 9010]         14
# 624                            [canon, powershot, g12]         10
# 625                      [sony, slta55, kit, 1855, mm]          2
# 626     [nikon, coolpix, p7000, nikon, coolpix, p7000]          1
# 627                                 [canon, ixus, 135]         16
# 628  [sony, cybershot, dscw370, sony, cybershot, ds...          1
# 629                                     [pentax, wg10]         14
#
#               screen size
# 0                    2.7"
# 1                    2.7"
# 2      3" (more than 62%)
# 3      3" (more than 62%)
# 4      3" (more than 62%)
# 5      3" (more than 62%)
# 7      3" (more than 62%)
# 8      3" (more than 62%)
# 9      3" (more than 62%)
# 10     3" (more than 62%)
# 11                   2.7"
# 12     3" (more than 62%)
# 13     3" (more than 62%)
# 14     3" (more than 62%)
# 15                   2.7"
# 16   3.5" (more than 98%)
# 17                   2.7"
# 18                   2.5"
# 19     3" (more than 62%)
# 20     3" (more than 62%)
# 21     3" (more than 62%)
# 22                   2.7"
# 23                   2.5"
# 24     3" (more than 62%)
# 25     3" (more than 62%)
# 26     3" (more than 62%)
# 27     3" (more than 62%)
# 28     3" (more than 62%)
# 29                   2.7"
# 30                   2.7"
# ..                    ...
# 600                  2.7"
# 601    3" (more than 62%)
# 602    3" (more than 62%)
# 603    3" (more than 62%)
# 604    3" (more than 62%)
# 605    3" (more than 62%)
# 606                  2.5"
# 607                  2.5"
# 608    3" (more than 62%)
# 609    3" (more than 62%)
# 610    3" (more than 62%)
# 611    3" (more than 62%)
# 612                  2.7"
# 613                  2.7"
# 614    3" (more than 62%)
# 615                  2.7"
# 616    3" (more than 62%)
# 617    3" (more than 62%)
# 618    3" (more than 62%)
# 619    3" (more than 62%)
# 620                  2.7"
# 621                  2.7"
# 622    3" (more than 62%)
# 623                  2.7"
# 624  2.8" (more than 61%)
# 625    3" (more than 62%)
# 626    3" (more than 62%)
# 627                  2.7"
# 628    3" (more than 62%)
# 629                  2.7"
#
# [614 rows x 5 columns]

# %%
def parse_screen_size(value):
    if pd.isna(value):
        return value
    else:
        m = re.search('(\d*\.\d+|\d*\,\d+|\d+)\"', str(value))
        if m is None:

            print("SKIP")
            return float("NaN")

        return m.group(1).replace(",",".")

# %%
df["screen size"] = df["screen size"].apply(parse_screen_size)

# %%
df.head()
# Out:
#                   spec_id     brand                    product name  \
# 0  www.shopmania.in//1659      sony                 [sony, dscw630]
# 1  www.shopmania.in//1120   samsung                 [samsung, es75]
# 2  www.shopmania.in//1570      sony                  [sony, dscrx1]
# 3  www.shopmania.in//1065     canon  [canon, eos, 60d, kit, 1855mm]
# 4  www.shopmania.in//1527  fujifilm                 [fujifilm, xq1]
#
#   resolution screen size
# 0          1         2.7
# 1          2         2.7
# 2          3           3
# 3         18           3
# 4         12           3

# %% [markdown]
# ### Final cleaning

# %%
df.to_csv("../../datasets/unlabeled/cleaned/shopmania.csv", index=False)

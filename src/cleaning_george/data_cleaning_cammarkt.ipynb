# %%
import os
import numpy as np
import json
import pandas as pd
import itertools
from tqdm import tqdm
import nltk
from nltk.tokenize import word_tokenize
import re
import matplotlib.pyplot as plt

# %%
def create_dataframe(dataset_path, source):
    """Function used to create a Pandas DataFrame containing specifications page titles

    Reads products specifications from the file system ("dataset_path" variable in the main function) and creates a Pandas DataFrame where each row is a
    specification. The columns are 'source' (e.g. www.sourceA.com), 'spec_number' (e.g. 1) and the 'page title'. Note that this script will consider only
    the page title attribute for simplicity.

    Args:
        dataset_path (str): The path to the dataset

    Returns:
        df (pd.DataFrame): The Pandas DataFrame containing specifications and page titles
    """

    print('>>> Creating dataframe...\n')
    columns_df = ['source', 'spec_number', 'spec_id', 'page_title']
    
    df = pd.DataFrame()
    progressive_id = 0
    progressive_id2row_df = {}
    #for source in tqdm(os.listdir(dataset_path)):
    #source = "buy.net"
    for specification in os.listdir(os.path.join(dataset_path, source)):
        specification_number = specification.replace('.json', '')
        specification_id = '{}//{}'.format(source, specification_number)
        with open(os.path.join(dataset_path, source, specification)) as specification_file:
            columns_df = ['source', 'spec_number', 'spec_id']
            specification_data = json.load(specification_file)
            attrs = []
            for k, v in specification_data.items():
                columns_df.append(k)
                attrs.append(v)
            row = [source, specification_number, specification_id]
            row.extend(attrs)
            progressive_id2row_df.update({progressive_id: row})
            progressive_id += 1
            df = df.append(pd.DataFrame.from_dict(progressive_id2row_df, orient='index', columns=columns_df))
            progressive_id2row_df = {}
    #print(df)
    print('>>> Dataframe created successfully!\n')
    return df

# %%
df = create_dataframe('../../datasets/unlabeled/2013_camera_specs', "cammarkt.com")
# Out:
# >>> Creating dataframe...
# /Users/gfotiadis/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# >>> Dataframe created successfully!

# %%
df.head()
# Out:
#   35mm zoom lens 3d digital camera  \
# 0            NaN               NaN
# 1            NaN               NaN
# 2            NaN               NaN
# 3            NaN               NaN
# 4            NaN               NaN
#
#                                         <page title> additional features  \
# 0  CamMarkt | Pentax K-5 IIs 16.3 MP DSLR Camera ...                 NaN
# 1  CamMarkt | Nikon D5200 24.1 MP CMOS Digital SL...                 NaN
# 2  CamMarkt | Canon EOS Rebel T3i 18 MP CMOS APS-...                 NaN
# 3  CamMarkt | Pentax K-30 Weather-Sealed 16 MP CM...                 NaN
# 4  CamMarkt | Nikon 1 J3 14.2 MP HD Digital Camer...                 NaN
#
#   aperture range auto focus type battery life battery type   brand  \
# 0            NaN             NaN          NaN          NaN  Pentax
# 1            NaN             NaN          NaN          NaN   Nikon
# 2            NaN             NaN          NaN          NaN   Canon
# 3            NaN             NaN          NaN          NaN  Pentax
# 4            NaN             NaN          NaN          NaN   Nikon
#
#                                   builtin microphone  ...  \
# 0  SDHC Card\nSDXC Card\nWith Built-in Microphone...  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
# 3  SDHC Card\nSDXC Card\nWith Built-in Microphone...  ...
# 4                                                NaN  ...
#
#                                    video resolutions video speed  \
# 0  640 x 480 (VGA)\nA CCD sensor will provide a s...         NaN
# 1                                                NaN         NaN
# 2                                                NaN         NaN
# 3                                                NaN         NaN
# 4                                                NaN         NaN
#
#                                           viewfinder  \
# 0  Digital\nLCD stands for 'Liquid Crystal Displa...
# 1                                                NaN
# 2                                                NaN
# 3  Optical (Through-the-lens)\nLCD stands for 'Li...
# 4                                                NaN
#
#   viewfinder  field coverage viewfinder magnification viewfinder type  \
# 0                        NaN                      NaN             NaN
# 1                        NaN                      NaN             NaN
# 2                        NaN                      NaN             NaN
# 3                        NaN                      NaN             NaN
# 4                        NaN                      NaN             NaN
#
#                  warranty                                             weight  \
# 0                     NaN          [739.35 gr, 1.63 lb., 0 pounds, 1.63 lb.]
# 1                     NaN  [1,360.78 gr, 3 lb.\nA CCD sensor will provide...
# 2                     NaN  [1.14 lb.\nThe sensor in a digital camera is c...
# 3  1 year parts and labor                                         1.4 pounds
# 4                     NaN  [1.19 lb.\nThe optical zoom ratio of a digital...
#
#                                        white balance  \
# 0  Auto\nThe shutter speed of a camera depends on...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                width
# 0  [5.2 in., 13.2 cm\nA viewfinder is the small s...
# 1                                                NaN
# 2                                                NaN
# 3  [13 cm\nA viewfinder is the small square on th...
# 4                                                NaN
#
# [5 rows x 107 columns]

# %%
cols = ["spec_id", 'brand', "manufacturer", 'weight', "lcd screen size", "height", "depth", "width"]

# %%
df = df[cols]

# %%
df.head()
# Out:
#              spec_id   brand manufacturer  \
# 0  cammarkt.com//457  Pentax       Pentax
# 1  cammarkt.com//292   Nikon        Nikon
# 2  cammarkt.com//504   Canon        Canon
# 3  cammarkt.com//441  Pentax       Pentax
# 4  cammarkt.com//103   Nikon        Nikon
#
#                                               weight lcd screen size  \
# 0          [739.35 gr, 1.63 lb., 0 pounds, 1.63 lb.]           3 in.
# 1  [1,360.78 gr, 3 lb.\nA CCD sensor will provide...           3 in.
# 2  [1.14 lb.\nThe sensor in a digital camera is c...           3 in.
# 3                                         1.4 pounds             NaN
# 4  [1.19 lb.\nThe optical zoom ratio of a digital...             NaN
#
#               height              depth  \
# 0  [3.8 in., 9.7 cm]  [2.9 in., 7.4 cm]
# 1                NaN                NaN
# 2                NaN                NaN
# 3  [3.8 in., 9.7 cm]  [2.8 in., 7.1 cm]
# 4                NaN                NaN
#
#                                                width
# 0  [5.2 in., 13.2 cm\nA viewfinder is the small s...
# 1                                                NaN
# 2                                                NaN
# 3  [13 cm\nA viewfinder is the small square on th...
# 4                                                NaN

# %% [markdown]
# ## Brand

# %%
df["brand"].value_counts()
# Out:
# Nikon                 50
# Pentax                46
# Canon                 42
# Olympus               12
# [Pentax, Pentax]       9
# [Canon, Canon]         8
# Sony                   8
# [Nikon, Nikon]         8
# Panasonic              4
# [Olympus, Olympus]     2
# [NikonEu, Nikon]       1
# [Focus, Sony]          1
# Blackmagic Design      1
# Sigma                  1
# Leica                  1
# Samsung                1
# [Sony, Sony]           1
# Opteka                 1
# [Samsung, Samsung]     1
# Name: brand, dtype: int64

# %%
def clean_brand(value):
    if isinstance(value, list):
        return value[1].lower()
    else:
        value = value.replace(" design", "")
        return value.lower()

# %%
df["brand"] = df["brand"].apply(clean_brand)

# %%
df["brand"].value_counts()
# Out:
# nikon                59
# pentax               55
# canon                50
# olympus              14
# sony                 10
# panasonic             4
# samsung               2
# leica                 1
# sigma                 1
# opteka                1
# blackmagic design     1
# Name: brand, dtype: int64

# %%
df.head()
# Out:
#              spec_id   brand manufacturer  \
# 0  cammarkt.com//457  pentax       Pentax
# 1  cammarkt.com//292   nikon        Nikon
# 2  cammarkt.com//504   canon        Canon
# 3  cammarkt.com//441  pentax       Pentax
# 4  cammarkt.com//103   nikon        Nikon
#
#                                               weight lcd screen size  \
# 0          [739.35 gr, 1.63 lb., 0 pounds, 1.63 lb.]           3 in.
# 1  [1,360.78 gr, 3 lb.\nA CCD sensor will provide...           3 in.
# 2  [1.14 lb.\nThe sensor in a digital camera is c...           3 in.
# 3                                         1.4 pounds             NaN
# 4  [1.19 lb.\nThe optical zoom ratio of a digital...             NaN
#
#               height              depth  \
# 0  [3.8 in., 9.7 cm]  [2.9 in., 7.4 cm]
# 1                NaN                NaN
# 2                NaN                NaN
# 3  [3.8 in., 9.7 cm]  [2.8 in., 7.1 cm]
# 4                NaN                NaN
#
#                                                width
# 0  [5.2 in., 13.2 cm\nA viewfinder is the small s...
# 1                                                NaN
# 2                                                NaN
# 3  [13 cm\nA viewfinder is the small square on th...
# 4                                                NaN

# %% [markdown]
# ## Manufacturer

# %%
df["manufacturer"].value_counts()
# Out:
# Nikon                      54
# Pentax                     53
# Canon                      48
# Olympus                    14
# Sony                       10
# NIKO9                       4
# Panasonic                   4
# PENX9                       1
# Pentax-Ricoh                1
# Samsung                     1
# Canon Cameras, US           1
# Samsung Pleomax - Zirex     1
# CANU9                       1
# Blackmagic                  1
# Leica                       1
# NikonEu                     1
# SIGMA                       1
# Opteka                      1
# Name: manufacturer, dtype: int64

# %%
def clean_manufacturer(camera):
    if pd.isna(camera):
        return camera
    else:
        punctuation = "!#$%&'()*+,-./:;<=>?@[\]^_`{|}~€£¥₹₽"
        for p in punctuation:
            camera = camera.replace(p, "")
        camera = ' '.join(camera.split())
        return camera.lower()

# %%
df["manufacturer"] = df["manufacturer"].apply(clean_manufacturer)

# %%
df.head()
# Out:
#              spec_id   brand manufacturer  \
# 0  cammarkt.com//457  pentax       pentax
# 1  cammarkt.com//292   nikon        nikon
# 2  cammarkt.com//504   canon        canon
# 3  cammarkt.com//441  pentax       pentax
# 4  cammarkt.com//103   nikon        nikon
#
#                                               weight lcd screen size  \
# 0          [739.35 gr, 1.63 lb., 0 pounds, 1.63 lb.]           3 in.
# 1  [1,360.78 gr, 3 lb.\nA CCD sensor will provide...           3 in.
# 2  [1.14 lb.\nThe sensor in a digital camera is c...           3 in.
# 3                                         1.4 pounds             NaN
# 4  [1.19 lb.\nThe optical zoom ratio of a digital...             NaN
#
#               height              depth  \
# 0  [3.8 in., 9.7 cm]  [2.9 in., 7.4 cm]
# 1                NaN                NaN
# 2                NaN                NaN
# 3  [3.8 in., 9.7 cm]  [2.8 in., 7.1 cm]
# 4                NaN                NaN
#
#                                                width
# 0  [5.2 in., 13.2 cm\nA viewfinder is the small s...
# 1                                                NaN
# 2                                                NaN
# 3  [13 cm\nA viewfinder is the small square on th...
# 4                                                NaN

# %% [markdown]
# ## Weight

# %%
def clean_weight_regex(value):
    regex = r"([0-9]+([.][0-9]+)?) ([A-Z]+)*"
    if pd.isna(value):
        return value
    else:
        if re.match(regex, value):
            groups = re.match(regex, value)
        
            amount = groups.group(1)
            unit = value.split("\n")[0].split()[1].replace('.', "")
            unit = unit.lower()
            if unit == "pounds" or unit == "lb":
                return int(round(float(amount) * 454))
            elif unit == "oz":
                return int(round(float(amount) * 28.35))
            else:
                return int(round(float(amount)))
        else:
            value = int(round(float(value.split()[0].replace(",", ""))))
            return value

# %%
df["weight"] = df["weight"].apply(lambda shit : shit[0] if isinstance(shit, list) else shit)

# %%
df["weight"] = df["weight"].apply(clean_weight_regex)

# %%
df.head()
# Out:
#              spec_id   brand manufacturer  weight lcd screen size  \
# 0  cammarkt.com//457  pentax       pentax     739           3 in.
# 1  cammarkt.com//292   nikon        nikon    1361           3 in.
# 2  cammarkt.com//504   canon        canon     518           3 in.
# 3  cammarkt.com//441  pentax       pentax     636             NaN
# 4  cammarkt.com//103   nikon        nikon     540             NaN
#
#               height              depth  \
# 0  [3.8 in., 9.7 cm]  [2.9 in., 7.4 cm]
# 1                NaN                NaN
# 2                NaN                NaN
# 3  [3.8 in., 9.7 cm]  [2.8 in., 7.1 cm]
# 4                NaN                NaN
#
#                                                width
# 0  [5.2 in., 13.2 cm\nA viewfinder is the small s...
# 1                                                NaN
# 2                                                NaN
# 3  [13 cm\nA viewfinder is the small square on th...
# 4                                                NaN

# %% [markdown]
# ## Lcd screen size

# %%
df["lcd screen size"].value_counts()
# Out:
# 3 in.             88
# 2.5 in.           20
# 2.7 in.           14
# 3.2 in.            7
# 1.8 in.            7
# 2 in.              3
# [3 in., 3 in.]     1
# 7.6 in.            1
# Name: lcd screen size, dtype: int64

# %%
def clean_screen_size(value):
    if not isinstance(value, list) and pd.isna(value):
        return value
    else:
        if isinstance(value, list):
            return float(value[0].split()[0])
        else:
            return float(value.split()[0])

# %%
df["lcd screen size"] = df["lcd screen size"].apply(clean_screen_size)

# %%
df.head()
# Out:
#              spec_id   brand manufacturer  weight  lcd screen size  \
# 0  cammarkt.com//457  pentax       pentax     739              3.0
# 1  cammarkt.com//292   nikon        nikon    1361              3.0
# 2  cammarkt.com//504   canon        canon     518              3.0
# 3  cammarkt.com//441  pentax       pentax     636              NaN
# 4  cammarkt.com//103   nikon        nikon     540              NaN
#
#               height              depth  \
# 0  [3.8 in., 9.7 cm]  [2.9 in., 7.4 cm]
# 1                NaN                NaN
# 2                NaN                NaN
# 3  [3.8 in., 9.7 cm]  [2.8 in., 7.1 cm]
# 4                NaN                NaN
#
#                                                width
# 0  [5.2 in., 13.2 cm\nA viewfinder is the small s...
# 1                                                NaN
# 2                                                NaN
# 3  [13 cm\nA viewfinder is the small square on th...
# 4                                                NaN

# %% [markdown]
# ## Height

# %%
df["height"].value_counts()
# Out:
# [9.7 cm, 3.8 in.]                                                                               20
# [3.8 in., 9.7 cm]                                                                               13
# [4.2 in., 10.7 cm]                                                                               7
# [3.6 in., 9.1 cm]                                                                                6
# [3.7 in., 9.4 cm]                                                                                6
# [9.1 cm, 3.6 in.]                                                                                4
# 3.9 in.\nDisplay Rotation                                                                        4
# [9.4 cm, 3.71 in.]                                                                               3
# [6.6 cm, 2.6 in.]                                                                                3
# 4.2 in.\nDiagonal Screen Size is the size of your TV screen, measured diagonally in inches.      3
# 3.8 in.\nDiagonal Screen Size is the size of your TV screen, measured diagonally in inches.      3
# [4.4 in., 11.2 cm]                                                                               3
# [3.71 in., 9.4 cm]                                                                               2
# [9.7 cm, 3.82 in.]                                                                               2
# 4.4 in.\nDisplay Rotation                                                                        2
# [10.7 cm, 4.2 in.]                                                                               2
# [7 cm, 2.75 in.]                                                                                 2
# 3.42 in.                                                                                         2
# [8.4 cm, 3.29 in.]                                                                               2
# [2.72 in., 6.9 cm]                                                                               2
# [3.98 in., 10.1 cm]                                                                              1
# [9.4 cm, 3.7 in.]                                                                                1
# [8.1 cm, 3.2 in.]                                                                                1
# [4.37 in., 11.1 cm]                                                                              1
# [3.82 in., 9.7 cm]                                                                               1
# 2.3 in.                                                                                          1
# [9.2 cm, 3.64 in.]                                                                               1
# [5.9 in., 15 cm]                                                                                 1
# [11.7 cm, 4.6 in.]                                                                               1
# 3.98 in.                                                                                         1
# [4.1 in., 10.4 cm]                                                                               1
# [11.2 cm, 4.4 in.]                                                                               1
# [2.75 in., 7 cm]                                                                                 1
# [11.4 cm, 4.5 in.]                                                                               1
# [6.1 cm, 2.4 in.]                                                                                1
# 2.62 in.\nDiagonal Screen Size is the size of your TV screen, measured diagonally in inches.     1
# [10.6 cm, 4.17 in.]                                                                              1
# [3.9 in., 9.9 cm]                                                                                1
# [10.1 cm, 3.98 in.]                                                                              1
# 4.1 in.                                                                                          1
# [4.5 in., 11.4 cm]                                                                               1
# 3.7 in.                                                                                          1
# [3.09 in., 7.8 cm]                                                                               1
# [3.62 in., 9.2 cm]                                                                               1
# [3.84 in., 9.8 cm]                                                                               1
# [9.9 cm, 3.9 in.]                                                                                1
# 4.6 in.\nDiagonal Screen Size is the size of your TV screen, measured diagonally in inches.      1
# 3.4 in.\nDiagonal Screen Size is the size of your TV screen, measured diagonally in inches.      1
# [4.17 in., 10.6 cm]                                                                              1
# [12.2 cm, 4.8 in.]                                                                               1
# 4.232 in.                                                                                        1
# [9.7 cm, 3.8 in., 9.7 cm, 3.8 in.]                                                               1
# [3.88 in., 9.9 cm]                                                                               1
# [3.58 in., 9.1 cm]                                                                               1
# [2.29 in., 5.8 cm]                                                                               1
# 4.6 in.\nDisplay Rotation                                                                        1
# 3.6 in.                                                                                          1
# 4.19 in.                                                                                         1
# 3.71 in.\nDiagonal Screen Size is the size of your TV screen, measured diagonally in inches.     1
# Name: height, dtype: int64

# %%
def clean_dim(value):
    if not isinstance(value, list) and pd.isna(value):
        return value
    else:
        if isinstance(value, list):
            for e in value:
                if "in." in e:
                    return round(float(e.split()[0]), 1)
        else:
            return round(float(value.split("\n")[0].split()[0]), 1)

# %%
df["height"] = df["height"].apply(clean_dim)

# %%
df.head()
# Out:
#              spec_id   brand manufacturer  weight  lcd screen size  height  \
# 0  cammarkt.com//457  pentax       pentax     739              3.0     3.8
# 1  cammarkt.com//292   nikon        nikon    1361              3.0     NaN
# 2  cammarkt.com//504   canon        canon     518              3.0     NaN
# 3  cammarkt.com//441  pentax       pentax     636              NaN     3.8
# 4  cammarkt.com//103   nikon        nikon     540              NaN     NaN
#
#                depth                                              width
# 0  [2.9 in., 7.4 cm]  [5.2 in., 13.2 cm\nA viewfinder is the small s...
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3  [2.8 in., 7.1 cm]  [13 cm\nA viewfinder is the small square on th...
# 4                NaN                                                NaN

# %% [markdown]
# ## Depth

# %%
df["depth"] = df["depth"].apply(clean_dim)

# %%
df.head()
# Out:
#              spec_id   brand manufacturer  weight  lcd screen size  height  \
# 0  cammarkt.com//457  pentax       pentax     739              3.0     3.8
# 1  cammarkt.com//292   nikon        nikon    1361              3.0     NaN
# 2  cammarkt.com//504   canon        canon     518              3.0     NaN
# 3  cammarkt.com//441  pentax       pentax     636              NaN     3.8
# 4  cammarkt.com//103   nikon        nikon     540              NaN     NaN
#
#    depth                                              width
# 0    2.9  [5.2 in., 13.2 cm\nA viewfinder is the small s...
# 1    NaN                                                NaN
# 2    NaN                                                NaN
# 3    2.8  [13 cm\nA viewfinder is the small square on th...
# 4    NaN                                                NaN

# %% [markdown]
# ## Width

# %%
df["width"] = df["width"].apply(clean_dim)

# %%
df.head()
# Out:
#              spec_id   brand manufacturer  weight  lcd screen size  height  \
# 0  cammarkt.com//457  pentax       pentax     739              3.0     3.8
# 1  cammarkt.com//292   nikon        nikon    1361              3.0     NaN
# 2  cammarkt.com//504   canon        canon     518              3.0     NaN
# 3  cammarkt.com//441  pentax       pentax     636              NaN     3.8
# 4  cammarkt.com//103   nikon        nikon     540              NaN     NaN
#
#    depth  width
# 0    2.9    5.2
# 1    NaN    NaN
# 2    NaN    NaN
# 3    2.8    5.1
# 4    NaN    NaN

# %%
df["dimensions"] = df.apply(lambda row : str(row.height) + "h" + str(row.width) + "w" + str(row.depth) + "d" if not pd.isna(row.depth) and not pd.isna(row.height) and not pd.isna(row.width) else np.nan, axis = 1)

# %%
df.head()
# Out:
#              spec_id   brand manufacturer  weight  lcd screen size  height  \
# 0  cammarkt.com//457  pentax       pentax     739              3.0     3.8
# 1  cammarkt.com//292   nikon        nikon    1361              3.0     NaN
# 2  cammarkt.com//504   canon        canon     518              3.0     NaN
# 3  cammarkt.com//441  pentax       pentax     636              NaN     3.8
# 4  cammarkt.com//103   nikon        nikon     540              NaN     NaN
#
#    depth  width    dimensions
# 0    2.9    5.2  3.8h5.2w2.9d
# 1    NaN    NaN           NaN
# 2    NaN    NaN           NaN
# 3    2.8    5.1  3.8h5.1w2.8d
# 4    NaN    NaN           NaN

# %%
df = df.drop(columns=["height", "depth", "width"], axis = 1)

# %%
df.head()
# Out:
#              spec_id   brand manufacturer  weight  lcd screen size  \
# 0  cammarkt.com//457  pentax       pentax     739              3.0
# 1  cammarkt.com//292   nikon        nikon    1361              3.0
# 2  cammarkt.com//504   canon        canon     518              3.0
# 3  cammarkt.com//441  pentax       pentax     636              NaN
# 4  cammarkt.com//103   nikon        nikon     540              NaN
#
#      dimensions
# 0  3.8h5.2w2.9d
# 1           NaN
# 2           NaN
# 3  3.8h5.1w2.8d
# 4           NaN

# %% [markdown]
# ## Saving

# %%
df.to_csv("../../datasets/unlabeled/cleaned/cammarkt.csv", index=False)

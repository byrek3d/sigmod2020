# %%
import os
import numpy as np
import json
import pandas as pd
import itertools
from tqdm import tqdm

import matplotlib.pyplot as plt

# %%
def create_dataframe(dataset_path):
    """Function used to create a Pandas DataFrame containing specifications page titles

    Reads products specifications from the file system ("dataset_path" variable in the main function) and creates a Pandas DataFrame where each row is a
    specification. The columns are 'source' (e.g. www.sourceA.com), 'spec_number' (e.g. 1) and the 'page title'. Note that this script will consider only
    the page title attribute for simplicity.

    Args:
        dataset_path (str): The path to the dataset

    Returns:
        df (pd.DataFrame): The Pandas DataFrame containing specifications and page titles
    """

    print('>>> Creating dataframe...\n')
    #columns_df = set(['source', 'spec_number', 'spec_id', 'page_title'])
    columns_df = {}
    
    progressive_id = 0
    progressive_id2row_df = {}
    #for source in os.listdir(dataset_path):
    source = "buy.net"
    for specification in os.listdir(os.path.join(dataset_path, source)):
        specification_number = specification.replace('.json', '')
        specification_id = '{}//{}'.format(source, specification_number)
        with open(os.path.join(dataset_path, source, specification)) as specification_file:
            specification_data = json.load(specification_file)
            #print(specification_data)
            #print(specification_id)
            for e in specification_data:
                if e not in columns_df:
                    columns_df[e] = 1
                else:
                    columns_df[e] += 1
#                break

#     for specification in os.listdir(os.path.join(dataset_path, source)):
#             specification_number = specification.replace('.json', '')
#             specification_id = '{}//{}'.format(source, specification_number)
#             with open(os.path.join(dataset_path, source, specification)) as specification_file:
#             specification_data = json.load(specification_file)
#                 for col in columns_df:
#                     page_title = specification_data.get(col).lower()
#                     row = (source, specification_number, specification_id, page_title)
#                     progressive_id2row_df.update({progressive_id: row})
#                     progressive_id += 1
#        break
    #df = pd.DataFrame.from_dict(progressive_id2row_df, orient='index', columns=columns_df)
    print(columns_df)


    df = pd.DataFrame(columns_df, index=columns_df.keys())
    
    print("--------------------")
    #print(df)
    print("--------------------")
    print('>>> Dataframe created successfully!\n')
    return df

# %%
df = create_dataframe("../datasets/unlabeled/2013_camera_specs/")
# Out:
# >>> Creating dataframe...
#
# {'<page title>': 358, 'camera type': 339, 'depth': 317, 'digital zoom': 231, 'effective megapixels': 332, 'flash': 314, 'focal length': 247, 'focal length 35mm equivalent': 228, 'height': 318, 'image sensor': 316, 'image stabilization': 278, 'lcd screen size': 334, 'maximum video capture resolution': 308, 'memory card support': 332, 'optical zoom': 241, 'total pixels': 269, 'url': 333, 'warranty information': 308, 'weight': 317, 'width': 318, 'installed memory': 70, 'interface connection': 201, 'max aperture': 144, 'wifi': 87, 'lens mount': 139, 'camera body only': 142, 'brand name': 66, 'builtin flash': 50, 'iso sensitivity': 48, 'maximum diopter adjustment': 42, 'minimum diopter adjustment': 42, 'number of batteries support': 55, 'parent retsku': 21, 'product line': 50, 'product type': 6, 'green compliance': 94, 'environmental protection': 62, 'gps enabled': 44, 'battery builtin': 53, 'battery include': 53, 'bulb setting': 4, 'camera modes': 48, 'continuous shooting speed': 5, 'exposure compensation range ': 4, 'exposure control': 52, 'exposure settings': 8, 'focus features': 7, 'frequency band': 11, 'general features': 8, 'gps': 40, 'hd movie mode': 58, 'image format': 8, 'image sensor quantity': 6, 'image sensor size': 4, 'included components': 8, 'iso equivalencies': 6, 'lens construction': 44, 'max focal length': 6, 'max horizontal image resolution': 8, 'max vertical image resolution': 8, 'max zoom': 5, 'maximum frame rate': 60, 'maximum image resolution': 8, 'maximum shutter speed': 7, 'metering characteristics': 6, 'min aperture': 6, 'min focal length': 6, 'min focus distance': 5, 'minimum shutter speed': 7, 'normalizeddigital zoom': 36, 'normalizedheight': 42, 'normalizedinstalled memory': 5, 'normalizednumber of image sensor pixels': 8, 'normalizedoptical zoom': 36, 'normalizedweight': 43, 'number of resolution modes': 8, 'number of scene modes': 5, 'pictbridge': 43, 'power source': 9, 'product model': 64, 'product series': 34, 'shortest shutter speed': 56, 'software included': 28, 'video capture format': 7, 'viewfinder type': 56, 'white balance': 8, 'white balance modes': 54, 'battery rechargeable': 43, 'longest shutter speed': 55, 'parent product type': 28, 'wide angle': 34, 'focal length conversion factor slr': 4, 'shutter lag': 3, 'autofocus points': 31, 'battery model supported': 38, 'language support': 23, 'self timer': 14, 'you are reviewing': 15, 'analog video out': 30, 'removable flash memory included': 5, 'color': 4}
# --------------------
# --------------------
# >>> Dataframe created successfully!

# %%
df.head(10)
# Out:
#    <page title>  camera type  depth  digital zoom  effective megapixels  \
# 1           358          339    317           231                   332
#
#    flash  focal length  focal length 35mm equivalent  height  image sensor  \
# 1    314           247                           228     318           316
#
#    ...  focal length conversion factor slr  shutter lag  autofocus points  \
# 1  ...                                   4            3                31
#
#    battery model supported  language support  self timer  you are reviewing  \
# 1                       38                23          14                 15
#
#    analog video out  removable flash memory included  color
# 1                30                                5      4
#
# [1 rows x 101 columns]

# %%
df.head(1).max()
# Out:
# <page title>                               358
# camera type                                339
# depth                                      317
# digital zoom                               231
# effective megapixels                       332
# flash                                      314
# focal length                               247
# focal length 35mm equivalent               228
# height                                     318
# image sensor                               316
# image stabilization                        278
# lcd screen size                            334
# maximum video capture resolution           308
# memory card support                        332
# optical zoom                               241
# total pixels                               269
# url                                        333
# warranty information                       308
# weight                                     317
# width                                      318
# installed memory                            70
# interface connection                       201
# max aperture                               144
# wifi                                        87
# lens mount                                 139
# camera body only                           142
# brand name                                  66
# builtin flash                               50
# iso sensitivity                             48
# maximum diopter adjustment                  42
#                                           ...
# normalizedinstalled memory                   5
# normalizednumber of image sensor pixels      8
# normalizedoptical zoom                      36
# normalizedweight                            43
# number of resolution modes                   8
# number of scene modes                        5
# pictbridge                                  43
# power source                                 9
# product model                               64
# product series                              34
# shortest shutter speed                      56
# software included                           28
# video capture format                         7
# viewfinder type                             56
# white balance                                8
# white balance modes                         54
# battery rechargeable                        43
# longest shutter speed                       55
# parent product type                         28
# wide angle                                  34
# focal length conversion factor slr           4
# shutter lag                                  3
# autofocus points                            31
# battery model supported                     38
# language support                            23
# self timer                                  14
# you are reviewing                           15
# analog video out                            30
# removable flash memory included              5
# color                                        4
# Length: 101, dtype: int64

# %%
df.head()
# Out:
#                       <page title>  camera type  depth  digital zoom  \
# <page title>                   358          339    317           231
# camera type                    358          339    317           231
# depth                          358          339    317           231
# digital zoom                   358          339    317           231
# effective megapixels           358          339    317           231
#
#                       effective megapixels  flash  focal length  \
# <page title>                           332    314           247
# camera type                            332    314           247
# depth                                  332    314           247
# digital zoom                           332    314           247
# effective megapixels                   332    314           247
#
#                       focal length 35mm equivalent  height  image sensor  ...  \
# <page title>                                   228     318           316  ...
# camera type                                    228     318           316  ...
# depth                                          228     318           316  ...
# digital zoom                                   228     318           316  ...
# effective megapixels                           228     318           316  ...
#
#                       focal length conversion factor slr  shutter lag  \
# <page title>                                           4            3
# camera type                                            4            3
# depth                                                  4            3
# digital zoom                                           4            3
# effective megapixels                                   4            3
#
#                       autofocus points  battery model supported  \
# <page title>                        31                       38
# camera type                         31                       38
# depth                               31                       38
# digital zoom                        31                       38
# effective megapixels                31                       38
#
#                       language support  self timer  you are reviewing  \
# <page title>                        23          14                 15
# camera type                         23          14                 15
# depth                               23          14                 15
# digital zoom                        23          14                 15
# effective megapixels                23          14                 15
#
#                       analog video out  removable flash memory included  color
# <page title>                        30                                5      4
# camera type                         30                                5      4
# depth                               30                                5      4
# digital zoom                        30                                5      4
# effective megapixels                30                                5      4
#
# [5 rows x 101 columns]

# %%
df.get_values

# %%
def create_dataframe(dataset_path):
    """Function used to create a Pandas DataFrame containing specifications page titles

    Reads products specifications from the file system ("dataset_path" variable in the main function) and creates a Pandas DataFrame where each row is a
    specification. The columns are 'source' (e.g. www.sourceA.com), 'spec_number' (e.g. 1) and the 'page title'. Note that this script will consider only
    the page title attribute for simplicity.

    Args:
        dataset_path (str): The path to the dataset

    Returns:
        df (pd.DataFrame): The Pandas DataFrame containing specifications and page titles
    """

    print('>>> Creating dataframe...\n')
    columns_df = ['source', 'spec_number', 'spec_id', 'page_title']
    
    df = pd.DataFrame()
    progressive_id = 0
    progressive_id2row_df = {}
    for source in tqdm(os.listdir(dataset_path)):
        for specification in os.listdir(os.path.join(dataset_path, source)):
            specification_number = specification.replace('.json', '')
            specification_id = '{}//{}'.format(source, specification_number)
            with open(os.path.join(dataset_path, source, specification)) as specification_file:
                columns_df = ['source', 'spec_number', 'spec_id']
                specification_data = json.load(specification_file)
                attrs = []
                for k, v in specification_data.items():
                    columns_df.append(k)
                    attrs.append(v)
                row = [source, specification_number, specification_id]
                row.extend(attrs)
                progressive_id2row_df.update({progressive_id: row})
                progressive_id += 1
                df = df.append(pd.DataFrame.from_dict(progressive_id2row_df, orient='index', columns=columns_df))
                progressive_id2row_df = {}
    print(df)
    print('>>> Dataframe created successfully!\n')
    return df

# %%
df = create_dataframe('../datasets/unlabeled/2013_camera_specs')
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# >>> Creating dataframe...
#
# <page title> -> Nikon Coolpix AW120 Digital Camera - Camouflage (VNA593E1) - Wex Photographic
# an -> image is incorrect
# battery model -> EN-EL12
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Camouflage
# connectivity -> Hi-Speed USB 2.0, HDMI, WiFi
# exposure modes -> Scene Modes
# file formats -> JPEG
# flash type -> Built in
# focal length tele -> 120
# focal length wide -> 24
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 6400
# iso min -> 125
# manufacturers link -> Click here
# max aperture tele -> 4.9
# max aperture wide -> 2.8
# megapixels -> 16
# minimum focus distance -> 1cm
# movie mode -> 1080p Full HD
# needs additional -> specifications
# optical zoom x -> 5
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 921000
# screen size inches -> 3
# sensor size -> 1 / 2.3 inch
# sensor type -> CMOS
# shutter speed max -> 1/1500 sec
# shutter speed min -> 4 sec
# size -> 110.0 x 66.0 x 25.8 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 3 Inch OLED Monitor
# weight g -> 213
# Row: 41
# Columns: 41
# <page title> -> Canon IXUS 150 Digital Camera - Red (9148B007AA) - Wex Photographic
# an -> image is incorrect
# battery model -> NB-11L
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Red
# connectivity -> Hi-Speed USB (USB2.0)
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> 13 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, MOV
# flash type -> Built-in
# focal length tele -> 224
# focal length wide -> 28
# hd movie mode -> 720p
# image stabilisation -> Yes
# iso max -> 1600
# iso min -> 100
# manufacturers link -> Click here
# max aperture tele -> 6.9
# max aperture wide -> 3.2
# megapixels -> 16
# minimum focus distance -> 1 cm
# movie mode -> 720p
# needs additional -> specifications
# optical zoom x -> 8
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 230000
# screen size inches -> 2.7
# sensor type -> CCD
# shutter speed max -> 1/2000 sec
# shutter speed min -> 15 sec
# size -> 95 x 54 x 22 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 2.7 Inch TFT
# weight g -> 130
# Row: 43
# Columns: 43
# <page title> -> Fuji FinePix S1 Digital Camera (P10NC12730A) - Wex Photographic
# an -> image is incorrect
# battery model -> NP-85
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Black
# connectivity -> Hi-Speed USB (USB2.0), HDMI Mini Connector
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> Programmed AE, Shutter Priority AE, Aperture Priority AE, Manual exposure, 12 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, RAW, RAW+JPEG, MOV
# flash metering -> Forced, Suppressed, Slow Synchro
# flash type -> Built-in (pop-up), Hot Shoe
# focal length tele -> 1200
# focal length wide -> 24
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 12800
# iso min -> 100
# manufacturers link -> Click here
# max aperture tele -> 5.6
# max aperture wide -> 2.8
# megapixels -> 16.4
# minimum focus distance -> 5 cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 50.0
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 Ã 3456
# screen resolution pixels -> 920000
# screen size inches -> 3
# sensor size -> 1/2.3 inch CCD
# sensor type -> CMOS
# shutter speed max -> 1/2000 sec
# shutter speed min -> 30 sec
# size -> 133 x 90.9 x 110.3 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 0.2 Inch Electronic Viewfinder
# weight g -> 680
# Row: 45
# Columns: 45
# <page title> -> Nikon Coolpix S5300 Digital Camera - Black (VNA540E1) - Wex Photographic
# an -> image is incorrect
# battery model -> EN-EL19
# cant find a -> related accessory
# card format -> 25MB Internal, SD, SDHC, SDXC
# colour -> Black
# connectivity -> Hi-Speed USB (USB2.0), HDMI
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> 18 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, MOV, WAV
# flash type -> Built in
# focal length tele -> 200
# focal length wide -> 25
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 6400
# iso min -> 125
# manufacturers link -> Click here
# max aperture tele -> 6.6
# max aperture wide -> 3.7
# megapixels -> 16
# minimum focus distance -> 2 cm
# movie mode -> 1080p Full HD
# needs additional -> specifications
# optical zoom x -> 8
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 460000
# screen size inches -> 3
# sensor size -> 1/1.23 Inch
# sensor type -> CMOS
# shutter speed max -> 1/1500 sec
# shutter speed min -> 4 sec
# size -> 97 x 58 x 21 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 3 Inch LCD
# weight g -> 138
# Row: 43
# Columns: 43
# <page title> -> Fuji FinePix S8600 Digital Camera - Red (P10NC12690A) - Wex Photographic
# an -> image is incorrect
# battery model -> 3 x AA type alkaline batteries or 3 x AA type Ni-MH rechargeable batteries or 3 x AA type lithium batteries
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Red
# connectivity -> Hi-Speed USB (USB2.0)
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> Programmed AE, Shutter Priority AE, Manual exposure, 13 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, AVI
# flash metering -> Auto, Forced Flash, Suppressed Flash, Slow Synchro
# flash type -> Built-in (pop-up)
# focal length tele -> 900
# focal length wide -> 25
# image stabilisation -> Yes
# iso max -> 6400
# iso min -> 100
# max aperture tele -> 6.9
# max aperture wide -> 2.9
# megapixels -> 16
# minimum focus distance -> 7 cm
# movie mode -> AVI
# needs additional -> specifications
# optical zoom x -> 36
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 Ã 3456
# screen resolution pixels -> 460000
# screen size inches -> 3.0
# sensor type -> CCD
# shutter speed max -> 1/2000 sec
# size -> 121 x 81 x 65 mm
# the description needs -> further detail
# the information is -> incorrect
# weight g -> 450
# Row: 40
# Columns: 40
# <page title> -> Nikon Coolpix S3600 Digital Camera - Pink Line-Art (VNA555E1) - Wex Photographic
# an -> image is incorrect
# battery model -> EN-EL19
# cant find a -> related accessory
# card format -> 25MB Internal, SD, SDHC, SDXC
# colour -> Pink
# connectivity -> Hi-Speed USB (USB2.0)
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> 18 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, MOV, WAV
# flash type -> Built in
# focal length tele -> 200
# focal length wide -> 25
# hd movie mode -> 720p
# image stabilisation -> Yes
# iso max -> 3200
# iso min -> 80
# manufacturers link -> Click here
# max aperture tele -> 10.5
# max aperture wide -> 3.7
# megapixels -> 20.1
# minimum focus distance -> 2 cm
# movie mode -> 720p HD
# needs additional -> specifications
# optical zoom x -> 8
# please add -> more image angles
# requires -> compatibility information
# resolution -> 5152 x 3864
# screen resolution pixels -> 230000
# screen size inches -> 2.7
# sensor size -> 1/1.23 Inch
# sensor type -> CCD
# shutter speed max -> 1/1500 sec
# shutter speed min -> 4 sec
# size -> 97 x 58 x 20 mm
# the description needs -> further detail
# the information is -> incorrect
# weight g -> 125
# Row: 42
# Columns: 42
# <page title> -> Sony Cyber-Shot QX100 Lens Style Digital Camera - Black (DSCQX100B.CE7) - Wex Photographic
# an -> image is incorrect
# battery model -> NP-BN
# cant find a -> related accessory
# card format -> Memory Stick Micro, Memory Stick Micro (mark 2), microSD Memory Card, microSDHC Memory Card, microSDXC Memory Card
# colour -> Black
# connectivity -> Multi/Micro USB Terminal, Hi-Speed USB,
# face detection technology -> Yes
# file formats -> JPEG, MP4
# focal length tele -> 100
# focal length wide -> 28
# iso max -> 25600
# iso min -> 160
# manufacturers link -> Click here
# max aperture tele -> 4.9
# max aperture wide -> 1.8
# megapixels -> 20.2
# minimum focus distance -> 5 cm
# movie mode -> 1080
# needs additional -> specifications
# optical zoom x -> 3.6
# pictbridge -> No
# please add -> more image angles
# requires -> compatibility information
# resolution -> 5472Ã3648
# screen resolution pixels -> 0
# screen size inches -> 0
# sensor size -> 13.2 x 8.8 mm
# sensor type -> CMOS
# shutter speed max -> 1/2000 sec
# shutter speed min -> 4 sec
# size -> 62.5 x 62.5 x 55.5 mm
# the description needs -> further detail
# the information is -> incorrect
# weight g -> 179
# Row: 38
# Columns: 38
# <page title> -> Nikon Coolpix S5300 Digital Camera - Plum (VNA542E1) - Wex Photographic
# an -> image is incorrect
# battery model -> EN-EL19
# cant find a -> related accessory
# card format -> 25MB Internal, SD, SDHC, SDXC
# colour -> Purple
# connectivity -> Hi-Speed USB (USB2.0), HDMI
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> 18 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, MOV, WAV
# flash metering -> Built in
# focal length tele -> 200
# focal length wide -> 25
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 6400
# iso min -> 125
# manufacturers link -> Click here
# max aperture tele -> 6.6
# max aperture wide -> 3.7
# megapixels -> 16
# minimum focus distance -> 2 cm
# movie mode -> 1080p Full HD
# needs additional -> specifications
# optical zoom x -> 8
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 460000
# screen size inches -> 3
# sensor size -> 1/1.23 Inch
# sensor type -> CMOS
# shutter speed max -> 1/1500 sec
# shutter speed min -> 4 sec
# size -> 97 x 58 x 21 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 3 Inch LCD
# weight g -> 138
# Row: 43
# Columns: 43
# <page title> -> Nikon Coolpix S32 Digital Camera - Yellow (VNA583E1) - Wex Photographic
# an -> image is incorrect
# battery model -> EN-EL19
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Yellow
# connectivity -> Hi-Speed USB 2.0, HDMI
# file formats -> JPEG
# flash type -> Built in
# focal length tele -> 90
# focal length wide -> 30
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 1600
# iso min -> 125
# manufacturers link -> Click here
# max aperture tele -> 5.9
# max aperture wide -> 3.3
# megapixels -> 13.2
# minimum focus distance -> 5cm
# movie mode -> 1080p Full HD
# needs additional -> specifications
# optical zoom x -> 3
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4160 x 3120
# screen resolution pixels -> 230000
# screen size inches -> 2.7
# sensor size -> 1/3.1 inch
# sensor type -> CMOS
# shutter speed max -> 1/2000 sec
# shutter speed min -> 1 sec
# size -> 107.6 x 66.1 x 66.1 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 2.7 Inch TFT
# weight g -> 175
# Row: 40
# Columns: 40
# <page title> -> Samsung WB1100F Digital Smart Camera (EC-WB1100BPBGB) - Wex Photographic
# an -> image is incorrect
# battery model -> SLB-10A Lithium-Ion
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Black
# connectivity -> Hi-Speed USB (USB2.0), Wi-Fi & NFC
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> 19 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, MP4
# flash metering -> Built-in
# flash type -> Built-in (pop-up)
# focal length tele -> 875
# focal length wide -> 25
# hd movie mode -> 720p
# image stabilisation -> Yes
# iso max -> 3200
# iso min -> 80
# max aperture tele -> 5.9
# max aperture wide -> 3.0
# megapixels -> 16.2
# minimum focus distance -> 10 cm
# movie mode -> 720p
# needs additional -> specifications
# optical zoom x -> 35
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4611 x 3456
# screen resolution pixels -> 460000
# screen size inches -> 3
# sensor size -> 1/1.23 Inch
# sensor type -> CCD
# shutter speed max -> 1/2000 sec
# shutter speed min -> 1/8 sec
# size -> 124 x 86 x 97 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 3 Inch LCD
# weight g -> 462
# Row: 43
# Columns: 43
# <page title> -> Fuji X100T Digital Camera - Silver (P10NC13260A) - Wex Photographic
# an -> image is incorrect
# battery model -> NP-95
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Silver
# connectivity -> USB 2.0
# exposure control -> +/- 3.0EV 1/3 Step
# face detection technology -> Yes
# file formats -> JPEG, RAW, RAW+JPEG
# flash type -> Built-in
# focal length tele -> 23
# focal length wide -> 23
# image stabilisation -> Yes
# iso max -> 25600
# iso min -> 200
# max aperture tele -> 2.0
# max aperture wide -> 2.0
# megapixels -> 16.3
# minimum focus distance -> 10cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 0
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4896 x 3264
# screen resolution pixels -> 1040000
# screen size inches -> 3.0
# sensor size -> 23.6 x 15.6 mm
# sensor type -> CMOS
# shutter speed max -> 1/4000 sec
# shutter speed min -> 30 sec
# size -> 126.5 x 74.4 x 52.4 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> Hybrid viewfinder
# weight g -> 400
# Row: 41
# Columns: 41
# <page title> -> Nikon Coolpix AW120 Digital Camera - Black (VNA590E1) - Wex Photographic
# an -> image is incorrect
# battery model -> EN-EL12
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Black
# connectivity -> Hi-Speed USB 2.0, HDMI, WiFi
# exposure modes -> Scene Modes
# file formats -> JPEG
# flash type -> Built in
# focal length tele -> 120
# focal length wide -> 24
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 6400
# iso min -> 125
# manufacturers link -> Click here
# max aperture tele -> 4.9
# max aperture wide -> 2.8
# megapixels -> 16
# minimum focus distance -> 1cm
# movie mode -> 1080p Full HD
# needs additional -> specifications
# optical zoom x -> 5
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 921000
# screen size inches -> 3
# sensor size -> 1 / 2.3 inch
# sensor type -> CMOS
# shutter speed max -> 1/1500 sec
# shutter speed min -> 4 sec
# size -> 110.0 x 66.0 x 25.8 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 3 Inch OLED Monitor
# weight g -> 213
# Row: 41
# Columns: 41
# <page title> -> Sony Cyber-shot HX50 Digital Camera - Black (DSCHX50CASDN.YG) - Wex Photographic
# an -> image is incorrect
# battery model -> NP-BX1
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Black
# connectivity -> USB 2.0, HDMI
# exposure control -> ? 2.0EV, 1/3EV step
# exposure modes -> 15 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, MPEG-4, AVCHD
# flash metering -> Auto, On, Off, Slow Sync, Rear Sync, Advanced Flash
# flash type -> Built-in (pop-up)
# focal length tele -> 720
# focal length wide -> 24
# image stabilisation -> Yes
# iso max -> 12800
# iso min -> 100
# manufacturers link -> Click here
# max aperture tele -> 6.3
# max aperture wide -> 3.5
# megapixels -> 20.4
# minimum focus distance -> 5 cm
# movie mode -> 1080i
# needs additional -> specifications
# optical zoom x -> 30.0
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 5184 x 2920
# screen resolution pixels -> 921000
# screen size inches -> 3.0
# sensor size -> 1/2.3 inch
# sensor type -> CMOS
# shutter speed max -> 1/4000 sec
# shutter speed min -> 30 sec
# size -> 108 x 64 x 38 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> LCD
# weight g -> 272
# Row: 44
# Columns: 44
# <page title> -> Nikon Coolpix P600 Digital Camera - Red (VNA481E1) - Wex Photographic
# an -> image is incorrect
# battery model -> EN-EL23
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Red
# connectivity -> USB, Micro HDMI
# exposure control -> +/- 2.0EV, 1/3EV step
# exposure modes -> 29 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, WAV, MOV
# flash metering -> TTL auto flash with monitor preflashes
# flash type -> Built-in
# focal length tele -> 1440
# focal length wide -> 24
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 12800
# iso min -> 100
# manufacturers link -> Click here
# max aperture tele -> 6.5
# max aperture wide -> 3.3
# megapixels -> 16.1
# minimum focus distance -> 1cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 60
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 921000
# screen size inches -> 3.0
# sensor size -> 1/2.3 inch
# sensor type -> CMOS
# shutter speed max -> 1/4000 sec
# shutter speed min -> 15 sec
# size -> 25.0 x 85.0 x 106.5 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> TFT LCD
# weight g -> 565
# Row: 45
# Columns: 45
# <page title> -> Canon IXUS 265 HS Digital Camera - Pink (9354B007AA) - Wex Photographic
# an -> image is incorrect
# battery model -> NB-11LH
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Pink
# connectivity -> Hi-Speed USB, HDMI Micro Connector, Wi-Fi
# exposure control -> +/- 2.0EV, 1/3EV step
# exposure modes -> 32 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, MP4
# flash metering -> Auto, Manual Flash On / Off, Slow Synchro
# flash type -> Built-in
# focal length tele -> 300
# focal length wide -> 25
# image stabilisation -> Yes
# iso max -> 3200
# iso min -> 100
# manufacturers link -> Click here
# max aperture tele -> 7.0
# max aperture wide -> 3.6
# megapixels -> 16.0
# minimum focus distance -> 1cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 12.0
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 461000
# screen size inches -> 3.0
# sensor size -> 1/2.3 inch
# sensor type -> CMOS
# shutter speed max -> 1/2000 sec
# shutter speed min -> 15 sec
# size -> 99.7 x 57.6 x 22.4 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> LCD
# weight g -> 147
# Row: 44
# Columns: 44
# <page title> -> Nikon Coolpix A Digital Camera - Silver (VNA231E1) - Wex Photographic
# an -> image is incorrect
# battery model -> EN-EL20
# cant find a -> related accessory
# card format -> SD/SDHC/SDXC memory cards
# colour -> Silver
# connectivity -> Hi-Speed USB, mini HDMI (Type C)
# exposure control -> ? 5.0EV, 1/3EV step
# exposure modes -> 19 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, RAW (NEF; a proprietary Nikon format) Movies: MOV (Video: H.264/MPEG-4 AVC, Audio: Linear stereo PCM)
# flash metering -> Auto, On, Off, Red-Eye, Slow-sync
# flash type -> Built-in (pop-up)
# focal length tele -> 28
# focal length wide -> 28
# image stabilisation -> Yes
# iso max -> 25600
# iso min -> 100
# manufacturers link -> Click here
# max aperture tele -> 2.8
# max aperture wide -> 2.8
# megapixels -> 16.2
# minimum focus distance -> 10 cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 0
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4928 x 3264
# screen resolution pixels -> 921000
# screen size inches -> 3.0
# sensor size -> 23.6 x 15.6 mm
# sensor type -> CMOS
# shutter speed max -> 1/2000 sec
# shutter speed min -> 30 sec
# size -> 111 x 64 x 40 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> TFT LCD
# weight g -> 299
# Row: 44
# Columns: 44
# <page title> -> Samsung WB50F Digital Smart Camera - White (EC-WB50FZBPWGB) - Wex Photographic
# an -> image is incorrect
# battery model -> EA-SLB10A
# cant find a -> related accessory
# card format -> microSD, microSDHC, microSDXC
# colour -> White
# connectivity -> Hi-Speed USB (USB2.0), Wi-Fi & NFC
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> 20 Scenes Modes
# face detection technology -> Yes
# file formats -> JPEG, MP4
# flash type -> Built in
# focal length tele -> 288
# focal length wide -> 24
# hd movie mode -> 720p
# image stabilisation -> Yes
# iso max -> 3200
# iso min -> 80
# max aperture tele -> 6.3
# max aperture wide -> 3.1
# megapixels -> 16.2
# minimum focus distance -> 5 cm
# movie mode -> 720p
# needs additional -> specifications
# optical zoom x -> 12
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4609 x 3456
# screen resolution pixels -> 460000
# screen size inches -> 3
# sensor size -> 1/1.23 Inch
# sensor type -> CCD
# shutter speed max -> 1/2000 sec
# shutter speed min -> 1/8 sec
# size -> 101 x 68 x 27.1 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 3 Inch LCD
# weight g -> 157
# Row: 42
# Columns: 42
# <page title> -> Sony Cyber-Shot RX1R Digital Camera - Black (DSCRX1RDI.YG) - Wex Photographic
# an -> image is incorrect
# battery model -> NP-BX1
# cant find a -> related accessory
# card format -> MS Duo, SDXC Dual Slot
# colour -> Black
# file formats -> RAW, JPEG
# flash type -> Built-in
# focal length tele -> 35
# focal length wide -> 35
# iso max -> 102400
# iso min -> 50
# manufacturers link -> Click here
# max aperture tele -> 2.0
# max aperture wide -> 2.0
# megapixels -> 24.3
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 0
# please add -> more image angles
# requires -> compatibility information
# resolution -> 6000 x 4000
# screen resolution pixels -> 1229000
# screen size inches -> 3.0
# sensor type -> CMOS
# shutter speed max -> 30 sec
# shutter speed min -> 1/4000 sec
# size -> 113.3 x 65.4 x 69.6 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> Xtra Fine LCD Screen
# weight g -> 482
# Row: 35
# Columns: 35
# <page title> -> Fuji X30 Digital Camera - Black (P10NC13270A) - Wex Photographic
# an -> image is incorrect
# battery model -> NP-95
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Black
# connectivity -> USB2.0, HDMI MicroD
# exposure control -> +/- 3.0EV
# exposure modes -> 16 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, RAW, RAW+JPEG
# flash metering -> Auto, Forced Flash, Slow Synchro., Commander, Suppressed Flash
# flash type -> Pop-up
# focal length tele -> 112
# focal length wide -> 28
# image stabilisation -> Yes
# iso max -> 12800
# iso min -> 100
# max aperture tele -> 2.8
# max aperture wide -> 2.0
# megapixels -> 12.0
# minimum focus distance -> 1cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 4
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4000 x 3000
# screen resolution pixels -> 920000
# screen size inches -> 3.0
# sensor size -> 2/3 inch
# sensor type -> CMOS
# shutter speed max -> 1/4000 sec
# shutter speed min -> 30 sec
# size -> 118.7 x 71.6 x 60.3 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> Electronic Viewfinder
# weight g -> 383
# Row: 43
# Columns: 43
# <page title> -> Panasonic LUMIX DMC-TZ60 Digital Camera (DMC-TZ60EB) - Wex Photographic
# an -> image is incorrect
# battery model -> DMW-BCM13
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Black
# connectivity -> microHDMI, AV Output (PAL / NTSC), USB (AV/USB Multi)
# exposure control -> 1/3 EV step, +/-2 EV
# exposure modes -> 33 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, RAW, AVCHD, MP4
# flash metering -> Auto, Auto/Red-eye Reduction, Forced On, Slow Sync./Red-eye Reduction, Forced Off/0.6 - 6.4m (Wide / ISO Auto), 2.0 - 3.3m (Tele / ISO Auto)
# flash type -> Built-in
# focal length tele -> 720
# focal length wide -> 24
# image stabilisation -> Yes
# iso max -> 6400
# iso min -> 100
# manufacturers link -> Click here
# max aperture tele -> 6.4
# max aperture wide -> 3.3
# megapixels -> 18.1
# minimum focus distance -> 3cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 30.0
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4896 x 3672
# screen resolution pixels -> 920000
# screen size inches -> 3.0
# sensor size -> 1/2.3 inch
# sensor type -> MOS
# shutter speed max -> 1/2000 sec
# shutter speed min -> 30 sec
# size -> 110.6 x 34.4 x 64.3 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> LCD
# weight g -> 214
# Row: 44
# Columns: 44
# <page title> -> Olympus Stylus SH-60 Digital Camera - Silver (V107070SE000) - Wex Photographic
# an -> image is incorrect
# battery model -> LI-90B
# cant find a -> related accessory
# card format -> SD / SDHC / SDXC cards (UHS-I compatible) Eye-Fi card, FlashAir
# colour -> Silver
# connectivity -> DC input, AV ouput, USB 2.0 Hi-Speed
# exposure control -> +/- 2.0 EV (1/3 EV steps)
# exposure modes -> 17 Scene Modes
# face detection technology -> Yes
# file formats -> DCF, EXIF 2.3, PIM III, DPOF, QuickTime Motion JPEGÂ®
# flash metering -> Auto, Red-eye reduction, Fill-in, Off
# flash type -> Internal Flash
# focal length tele -> 600
# focal length wide -> 25
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 6400
# iso min -> 125
# manufacturers link -> Click here
# max aperture tele -> 6.9
# max aperture wide -> 3
# megapixels -> 16
# minimum focus distance -> 4.5mm
# movie mode -> 1080i
# needs additional -> specifications
# optical zoom x -> 24
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 460000
# screen resolution pixels -> 460000
# screen size inches -> 3
# sensor size -> 1/ 2.3 inch
# sensor type -> CMOS
# shutter speed max -> 1/2000
# shutter speed min -> 1/4
# size -> 112.1 x 63.5 x 42.4
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> LCD Touch Panel
# weight g -> 269
# Row: 45
# Columns: 45
# <page title> -> Sony CyberShot W830 Digital Camera - Pink (DSCW830P.CEH) - Wex Photographic
# an -> image is incorrect
# battery model -> NP-BN
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Pink
# connectivity -> Hi-Speed USB
# exposure control -> Â± 2.0EV, 1 / 3EV step
# face detection technology -> Yes
# file formats -> JPEG, MP4
# flash type -> Built-in
# focal length tele -> 200
# focal length wide -> 25
# hd movie mode -> 720p
# image stabilisation -> Yes
# iso max -> 3200
# iso min -> 80
# manufacturers link -> Click here
# max aperture tele -> 6.3
# max aperture wide -> 3.3
# megapixels -> 20.1
# minimum focus distance -> 5cm
# movie mode -> 720p
# needs additional -> specifications
# optical zoom x -> 8.0
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# screen resolution pixels -> 230400
# screen size inches -> 2.7
# sensor size -> 1/2.3 inch
# sensor type -> CCD
# shutter speed max -> 1/1600 sec
# shutter speed min -> 1 sec
# size -> 93.1 x 52.5 x 22.5 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> LCD
# Row: 41
# Columns: 41
# <page title> -> Canon PowerShot SX700 HS Digital Camera - Red (9339B014AA) - Wex Photographic
# an -> image is incorrect
# battery model -> NB-6LH
# cant find a -> related accessory
# card format -> SD, SDHC and SDXC
# colour -> Red
# connectivity -> Hi-Speed USB, HDMI Mini Connector, Wi-Fi
# file formats -> JPEG, MP4
# flash type -> Built-in
# focal length tele -> 750
# focal length wide -> 25
# iso max -> 3200
# iso min -> 100
# max aperture tele -> 6.9
# max aperture wide -> 3.2
# megapixels -> 16.1
# minimum focus distance -> 1cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 30.0
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 922000
# screen size inches -> 3.0
# sensor size -> 1/2.3 inch
# sensor type -> CMOS
# shutter speed max -> 1/3200 sec
# shutter speed min -> 15 sec
# size -> 112.7 x 65.8 x 34.8 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> PureColor II G (TFT)
# weight g -> 269
# Row: 37
# Columns: 37
# <page title> -> Ricoh Theta Spherical Digital Camera (175760) - Wex Photographic
# an -> image is incorrect
# battery model -> Lithium Ion Rechargeable
# cant find a -> related accessory
# card format -> 4GB internal memory
# colour -> White
# connectivity -> USB, WiFi
# file formats -> JPEG
# focal length tele -> 0
# focal length wide -> 0
# iso max -> 1600
# iso min -> 100
# manufacturers link -> https://theta360.com/uk/
# max aperture tele -> 0
# max aperture wide -> 0
# megapixels -> 0
# minimum focus distance -> 10 cm
# needs additional -> specifications
# optical zoom x -> 0
# please add -> more image angles
# requires -> compatibility information
# screen resolution pixels -> 0
# screen size inches -> 0
# shutter speed max -> 1/8000 sec
# shutter speed min -> 1/7.5 sec
# size -> 42 x 129 x 23 mm
# the description needs -> further detail
# the information is -> incorrect
# weight g -> 95
# Row: 32
# Columns: 32
# <page title> -> Canon PowerShot D30 Digital Camera (9337B012AA) - Wex Photographic
# an -> image is incorrect
# battery model -> NB-6LH
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Blue
# connectivity -> Hi-Speed USB, HDMI Mini Connector
# file formats -> JPEG, MOV
# flash type -> Built-in
# focal length tele -> 140
# focal length wide -> 28
# hd movie mode -> 1080p
# iso max -> 3200
# iso min -> 100
# max aperture tele -> 4.8
# max aperture wide -> 3.9
# megapixels -> 12.1
# minimum focus distance -> 1cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 5.0
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4000 x 3000
# screen resolution pixels -> 461000
# screen size inches -> 3.0
# sensor size -> 1/2.3 inch
# sensor type -> CMOS
# shutter speed max -> 1/1600 sec
# shutter speed min -> 15 sec
# size -> 109.4 x 68.0 x 27.5 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> PureColor II LCD (TFT)
# weight g -> 218
# Row: 38
# Columns: 38
# <page title> -> Ricoh WG-4 Digital Camera - Silver (08571) - Wex Photographic
# an -> image is incorrect
# battery model -> D-LI92
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Silver
# connectivity -> USB2.0(Hi-Speed): USB/AV terminal, HDMI terminal (Type D, Micro port)
# exposure control -> +/- 2.0EV, 1/3EV step
# exposure modes -> 29 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, MPEG-4
# flash metering -> Flash-on and Flash-off modes. ,Red-eye, compensation function employs a pre-discharge
# flash type -> Built-in
# focal length tele -> 100
# focal length wide -> 25
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 6400
# iso min -> 125
# max aperture tele -> 4.9
# max aperture wide -> 2.0
# megapixels -> 16.0
# minimum focus distance -> 1cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 4.0
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 460000
# screen size inches -> 3.0
# sensor size -> 1/2.3 inch
# sensor type -> CMOS
# shutter speed max -> 1/4000 sec
# shutter speed min -> 4 sec
# size -> 125.0 x 64.5 x 32.0 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> TFT colour LCD
# weight g -> 209
# Row: 44
# Columns: 44
# <page title> -> Olympus Stylus SH-1 Digital Camera - Black (V107080BE000) - Wex Photographic
# an -> image is incorrect
# battery model -> LI-92B
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC, 37MB Internal Memory
# colour -> Black
# connectivity -> WiFi, USB (2.0), AV Output, HDMI
# exposure modes -> 16 Scene Modes
# face detection technology -> Yes
# flash type -> Built-in
# focal length tele -> 600
# focal length wide -> 25
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 6400
# iso min -> 0
# manufacturers link -> Click here
# max aperture tele -> 8.7
# max aperture wide -> 3
# megapixels -> 16
# minimum focus distance -> 3cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 24
# please add -> more image angles
# requires -> compatibility information
# screen resolution pixels -> 460000
# screen size inches -> 3
# sensor type -> BSI CMOS
# shutter speed min -> 1/4 Sec
# size -> 109 x 63 x 42 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 3 Inch LCD
# weight g -> 271
# Row: 38
# Columns: 38
# <page title> -> Samsung WB50F Digital Smart Camera - Black (EC-WB50FZBPBGB) - Wex Photographic
# an -> image is incorrect
# battery model -> EA-SLB10A
# cant find a -> related accessory
# card format -> microSD, microSDHC, microSDXC
# colour -> Black
# connectivity -> Hi-Speed USB (USB2.0), Wi-Fi & NFC
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> 20 Scenes Modes
# face detection technology -> Yes
# file formats -> JPEG, MP4
# flash type -> Built in
# focal length tele -> 288
# focal length wide -> 24
# hd movie mode -> 720p
# image stabilisation -> Yes
# iso max -> 3200
# iso min -> 80
# max aperture tele -> 6.3
# max aperture wide -> 3.1
# megapixels -> 16.2
# minimum focus distance -> 5 cm
# movie mode -> 720p
# needs additional -> specifications
# optical zoom x -> 12
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4609 x 3456
# screen resolution pixels -> 460000
# screen size inches -> 3
# sensor size -> 1/1.23 Inch
# sensor type -> CCD
# shutter speed max -> 1/2000 sec
# shutter speed min -> 1/8 sec
# size -> 101 x 68 x 27.1 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 3 Inch LCD
# weight g -> 157
# Row: 42
# Columns: 42
# <page title> -> Sony Cyber-shot H400 Digital Camera (DSCH400B.CEH) - Wex Photographic
# an -> image is incorrect
# battery model -> NP-BX1
# cant find a -> related accessory
# card format -> 55MB Internal, SD, SDHC, SDXC, Pro Duo
# colour -> Black
# connectivity -> Multi (AV/USB), Hi-Speed USB (USB2.0)
# exposure control -> +/- 2.0 EV (1/3 EV steps)
# file formats -> JPEG
# flash metering -> Auto , Flash On , Slow Synchro , Flash Off , Advanced Flash
# flash type -> Built-in
# focal length tele -> 277
# focal length wide -> 4.4
# iso max -> 3200
# iso min -> 80
# manufacturers link -> Click here
# max aperture tele -> 6.5
# max aperture wide -> 3.4
# megapixels -> 20.1
# movie mode -> 720p
# needs additional -> specifications
# optical zoom x -> 63.0
# please add -> more image angles
# requires -> compatibility information
# resolution -> 5152 x 3864
# screen resolution pixels -> 460800
# screen size inches -> 3.0
# sensor size -> 1/2.3 inch
# sensor type -> CMOS
# shutter speed max -> 1/2000 sec
# shutter speed min -> 30 sec
# size -> 129.6 x 95.0 x 122.3 mm
# the description needs -> further detail
# the information is -> incorrect
# weight g -> 655
# Row: 38
# Columns: 38
# <page title> -> Canon IXUS 150 Digital Camera - Grey (9145B007AA) - Wex Photographic
# an -> image is incorrect
# battery model -> NB-11L
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Grey
# connectivity -> Hi-Speed USB (USB2.0)
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> 13 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, MOV
# flash type -> Built-in
# focal length tele -> 224
# focal length wide -> 28
# hd movie mode -> 720p
# image stabilisation -> Yes
# iso max -> 1600
# iso min -> 100
# manufacturers link -> Click here
# max aperture tele -> 6.9
# max aperture wide -> 3.2
# megapixels -> 16
# minimum focus distance -> 1 cm
# movie mode -> 720p
# needs additional -> specifications
# optical zoom x -> 8
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 230000
# screen size inches -> 2.7
# sensor type -> CCD
# shutter speed max -> 1/2000 sec
# shutter speed min -> 15 sec
# size -> 95 x 54 x 22 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 2.7 Inch TFT
# weight g -> 130
# Row: 43
# Columns: 43
# <page title> -> Canon PowerShot G1 X Mark II Digital Camera Premium Kit (9167B022AA) - Wex Photographic
# an -> image is incorrect
# battery model -> NB-12L
# cant find a -> related accessory
# card format -> SD, SDHC and SDXC
# colour -> Black
# connectivity -> Hi-Speed USB, HDMI Micro Connector, Wi-Fi
# file formats -> RAW, JPEG, MP4
# focal length tele -> 120
# focal length wide -> 24
# iso max -> 12800
# iso min -> 100
# max aperture tele -> 3.9
# max aperture wide -> 2.0
# megapixels -> 12.8
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 5.0
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4352 x 2904
# screen resolution pixels -> 1040000
# screen size inches -> 3.0
# sensor size -> 18.7 x 14.0 mm
# sensor type -> CMOS
# shutter speed max -> 1/4000 sec
# shutter speed min -> 60 sec
# size -> 116.3 x 74.0 x 66.2 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> sRGB PureColor II Touchscreen LCD or Included Electronic Viewfinder EVF-DC1
# weight g -> 558
# Row: 35
# Columns: 35
# <page title> -> Panasonic LUMIX DMC-LX100 Digital Camera - Silver (DMC-LX100EBS) - Wex Photographic
# an -> image is incorrect
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Silver
# connectivity -> USB 2.0, microHDMI
# exposure control -> +/- 3.0EV 1/3 Step
# face detection technology -> Yes
# flash type -> Built-in
# focal length tele -> 75
# focal length wide -> 24
# image stabilisation -> Yes
# iso max -> 25600
# iso min -> 100
# max aperture tele -> 2.8
# max aperture wide -> 1.7
# megapixels -> 12.8
# minimum focus distance -> 3cm
# movie mode -> 4K
# needs additional -> specifications
# optical zoom x -> 3.1
# please add -> more image angles
# requires -> compatibility information
# screen resolution pixels -> 0
# screen size inches -> 3.0
# sensor size -> 17.3 x 13 mm
# sensor type -> CMOS
# shutter speed max -> 1/16000 sec
# shutter speed min -> 60 sec
# size -> 116 x 74 x 66 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> Electronic Viewfinder
# weight g -> 553
# Row: 37
# Columns: 37
# <page title> -> Fuji FinePix XQ1 Digital Camera - Silver (P10NC11770A) - Wex Photographic
# an -> image is incorrect
# battery model -> NP-48
# cant find a -> related accessory
# card format -> 66MB Internal, SD, SDHC, SDXC
# colour -> Silver
# connectivity -> USB 2.0, HDMI Micro connector
# exposure modes -> 14 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, RAW, MOV, H.264
# flash metering -> Auto, Forced Flash, Suppressed Flash, Slow Synchro.
# flash type -> Pop-up flash
# focal length tele -> 100
# focal length wide -> 25
# image stabilisation -> Yes
# iso max -> 12800
# iso min -> 100
# manufacturers link -> Click here
# max aperture tele -> 4.9
# max aperture wide -> 1.8
# megapixels -> 12.0
# minimum focus distance -> 3 cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 4.0
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4000 x 3000
# screen resolution pixels -> 920000
# screen size inches -> 3.0
# sensor size -> 2/3 inch
# sensor type -> CMOS
# shutter speed max -> 1/4000 sec
# shutter speed min -> 30 sec
# size -> 100 x 58.5 x 33.3 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> TFT colour LCD
# weight g -> 206
# Row: 43
# Columns: 43
# <page title> -> Ricoh WG-4 GPS Digital Camera - Blue (08556) - Wex Photographic
# an -> image is incorrect
# battery model -> D-LI92
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Blue
# connectivity -> USB2.0(Hi-Speed): USB/AV terminal, HDMI terminal (Type D, Micro port)
# exposure control -> +/- 2.0EV, 1/3EV step
# exposure modes -> 29 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, MPEG-4
# flash metering -> Flash-on and Flash-off modes. ,Red-eye, compensation function employs a pre-discharge
# flash type -> Built-in
# focal length tele -> 100
# focal length wide -> 25
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 6400
# iso min -> 125
# max aperture tele -> 4.9
# max aperture wide -> 2.0
# megapixels -> 16.0
# minimum focus distance -> 1cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 4.0
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 460000
# screen size inches -> 3.0
# sensor size -> 1/2.3 inch
# sensor type -> CMOS
# shutter speed max -> 1/4000 sec
# shutter speed min -> 4 sec
# size -> 125.0 x 64.5 x 32.0 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> TFT colour LCD
# weight g -> 209
# Row: 44
# Columns: 44
# <page title> -> Nikon Coolpix P340 Digital Camera - Black (VNA490E1) - Wex Photographic
# an -> image is incorrect
# battery model -> EN-EL12
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Black
# connectivity -> USB, Micro HDMI
# exposure control -> +/- 2.0EV, 1/3EV step
# exposure modes -> 26 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, RAW, WAV, MOV
# flash metering -> TTL auto flash with monitor preflashes
# flash type -> Bulit-in
# focal length tele -> 120
# focal length wide -> 24
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 25600
# iso min -> 80
# manufacturers link -> Click here
# max aperture tele -> 5.6
# max aperture wide -> 1.8
# megapixels -> 12.2
# minimum focus distance -> 2cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 5.0
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4000 x 3000
# screen resolution pixels -> 921000
# screen size inches -> 3.0
# sensor size -> 1/1.7 inch
# sensor type -> CMOS
# shutter speed max -> 1/2000 sec
# shutter speed min -> 60 sec
# size -> 103.0 x 58.3 x 32.0 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> TFT LCD
# weight g -> 194
# Row: 45
# Columns: 45
# <page title> -> Sony Cyber-Shot RX100 II Digital Camera - Black (DSCRX100M2CDN.YG) - Wex Photographic
# an -> image is incorrect
# battery model -> NP-BX1
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC, Memory Stick Duo, Pro Duo, Pro-HG Duo
# colour -> Black
# connectivity -> HDMI terminal, BRAVIA PhotoTV HD, âBRAVIA Linkâ, USB, Stereo microphone, mono speaker
# file formats -> RAW, JPEG
# flash metering -> Auto, On, Off, Slow Sync
# flash type -> Built-in
# focal length tele -> 100
# focal length wide -> 28
# iso max -> 12800
# iso min -> 160
# manufacturers link -> Click here
# max aperture tele -> 4.9
# max aperture wide -> 1.8
# megapixels -> 20.2
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 3.6
# please add -> more image angles
# requires -> compatibility information
# resolution -> 5472 x 3648
# screen resolution pixels -> 1229000
# screen size inches -> 3.0
# sensor type -> CMOS
# shutter speed max -> 1/2000 sec
# shutter speed min -> 30 sec
# size -> 101.6 x 58.1 x 35.9 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> Tiltable White Magic Display LCD Screen
# weight g -> 254
# Row: 37
# Columns: 37
# <page title> -> Samsung WB35F Digital Smart Camera - White (EC-WB35FZBPWGB) - Wex Photographic
# an -> image is incorrect
# battery model -> EA-SLB10A
# cant find a -> related accessory
# card format -> microSD, microSDHC, microSDXC
# colour -> White
# connectivity -> Hi-Speed USB (USB2.0), WiFi, NFC
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> 20 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, MP4
# flash type -> Built in
# focal length tele -> 288
# focal length wide -> 24
# hd movie mode -> 720p
# image stabilisation -> Yes
# iso max -> 3200
# iso min -> 80
# max aperture tele -> 6.3
# max aperture wide -> 3.1
# megapixels -> 16.2
# minimum focus distance -> 5 cm
# movie mode -> 720p
# needs additional -> specifications
# optical zoom x -> 12
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 230000
# screen size inches -> 2.7
# sensor size -> 1/1.23 Inch
# sensor type -> CCD
# shutter speed max -> 1/2000 sec
# shutter speed min -> 1/8 sec
# size -> 101 x 61 x 28 mm
# the description needs -> further detail
# the information is -> incorrect
# weight g -> 142
# Row: 41
# Columns: 41
# <page title> -> Olympus Stylus Tough TG-850 Digital Camera - White (V104150WE000) - Wex Photographic
# an -> image is incorrect
# battery model -> LI-50B
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> White
# connectivity -> Hi-Speed USB 2.0
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> 18 Scene Modes
# face detection technology -> Yes
# flash type -> Built-in
# focal length tele -> 105
# focal length wide -> 21
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 6400
# iso min -> 0
# manufacturers link -> Click here
# max aperture tele -> 5.7
# max aperture wide -> 3.5
# megapixels -> 16
# minimum focus distance -> 1cm
# movie mode -> 1080p Full HD
# needs additional -> specifications
# optical zoom x -> 5
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 460000
# screen size inches -> 3
# sensor size -> 1/ 2.3 inch
# sensor type -> CMOS
# shutter speed max -> 1/2000 sec
# shutter speed min -> 4 sec
# size -> 109 x 64 x 27 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 3 Inch LCD
# weight g -> 218
# Row: 43
# Columns: 43
# <page title> -> Fuji FinePix XP70 Digital Camera - Orange (P10NC12620A) - Wex Photographic
# an -> image is incorrect
# battery model -> Li-ion battery NP-45S
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Orange
# connectivity -> Hi-Speed USB (USB2.0)
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> 13 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, MOV
# flash metering -> Auto, Forced Flash, Suppressed Flash, Slow Synchro
# flash type -> Built in
# focal length tele -> 140
# focal length wide -> 28
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 6400
# iso min -> 100
# max aperture tele -> 4.9
# max aperture wide -> 3.9
# megapixels -> 16.4
# minimum focus distance -> 9 cm
# movie mode -> 1080p Full HD
# needs additional -> specifications
# optical zoom x -> 5
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 460000
# screen size inches -> 2.7
# sensor type -> CMOS
# shutter speed min -> 4 sec
# size -> 104 x 67 x 26 mm
# the description needs -> further detail
# the information is -> incorrect
# weight g -> 179
# Row: 41
# Columns: 41
# <page title> -> Nikon Coolpix S9700 Digital Camera - Black (VNA650E1) - Wex Photographic
# an -> image is incorrect
# battery model -> EN-EL12
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC, Internal Memory Approx 3.6GB
# colour -> Black
# connectivity -> Hi-Speed USB 2.0, HDMI, WiFi
# exposure modes -> Scene Modes
# file formats -> JPEG
# focal length tele -> 750
# focal length wide -> 25
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 1600
# iso min -> 125
# manufacturers link -> Click here
# max aperture tele -> 6.4
# max aperture wide -> 3.7
# megapixels -> 16
# minimum focus distance -> 1cm
# movie mode -> 1080p Full HD
# needs additional -> specifications
# optical zoom x -> 30
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 921000
# screen size inches -> 3
# sensor size -> 1 / 2.3 inch
# sensor type -> CMOS
# shutter speed max -> 1/2000 sec
# shutter speed min -> 8 sec
# size -> 109.6 x 63.5 x 34.5 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 3 Inch OLED Monitor
# weight g -> 228
# Row: 40
# Columns: 40
# <page title> -> Nikon Coolpix S6700 Digital Camera - Red (VNA661E1) - Wex Photographic
# an -> image is incorrect
# battery model -> EN-EL19
# cant find a -> related accessory
# card format -> 25MB Internal, SD, SDHC, SDXC
# colour -> Red
# connectivity -> Hi-Speed USB (USB2.0)
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> 18 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, AVI, WAV
# flash type -> Built in
# focal length tele -> 250
# focal length wide -> 25
# hd movie mode -> 720p
# image stabilisation -> Yes
# iso max -> 3200
# iso min -> 80
# manufacturers link -> Click here
# max aperture tele -> 6.5
# max aperture wide -> 3.5
# megapixels -> 20.1
# minimum focus distance -> 5 cm
# movie mode -> 720p
# needs additional -> specifications
# optical zoom x -> 10
# please add -> more image angles
# requires -> compatibility information
# resolution -> 5152 x 3864
# screen resolution pixels -> 230000
# screen size inches -> 3
# sensor size -> 1/1.23 Inch
# sensor type -> CCD
# shutter speed max -> 1/2000 sec
# ...
# an -> image is incorrect
# cant find a -> related accessory
# card format -> 70MB Internal, SD/SDHC/SDXC
# colour -> Black
# connectivity -> USB 2.0, HDMI mini (Type C)
# exposure modes -> 16 Scene Modes
# face detection technology -> Yes
# file formats -> RAW, JPEG, MPO, MPEG-4, AVCHD
# flash metering -> Auto, On, Off, Red-Eye, Slow Sync
# flash type -> Built-in (pop-up)
# focal length tele -> 90
# focal length wide -> 24
# image stabilisation -> Yes
# iso max -> 12800
# iso min -> 80
# manufacturers link -> Click here
# max aperture tele -> 2.3
# max aperture wide -> 1.4
# megapixels -> 10.1
# minimum focus distance -> 1 cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 3.8
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 3648 x 2736
# screen resolution pixels -> 920000
# screen size inches -> 3.0
# sensor size -> 1/1.7 inch
# sensor type -> CMOS
# shutter speed max -> 1/4000 sec
# shutter speed min -> 60 sec
# size -> 111 x 68 x 46 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> TFT colour LCD
# weight g -> 269
# Row: 42
# Columns: 42
# <page title> -> Ricoh GR Digital Camera - Black (175749) - Wex Photographic
# an -> image is incorrect
# battery model -> DB-65
# cant find a -> related accessory
# card format -> Internal memory (approx. 54 MB), SD/SDHC, SDXC memory card, Eye-Fi card
# colour -> Black
# connectivity -> High-Speed USB, HDMI, Video output
# exposure control -> 4.0EV, 1/3EV step
# exposure modes -> 8 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, RAW, MPEG-4
# flash metering -> Auto, Flash On, Slow Synchro, Manual, AUTO Red-Eye Flash, Flash On Red-Eye, Slow Synchro Red-Eye
# flash type -> Built-in
# focal length tele -> 28
# focal length wide -> 28
# image stabilisation -> No
# iso max -> 25600
# iso min -> 100
# manufacturers link -> Click here
# max aperture tele -> 16.0
# max aperture wide -> 2.8
# megapixels -> 16.2
# minimum focus distance -> 10 cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 0.0
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4928 x 3264
# screen resolution pixels -> 1230000
# screen size inches -> 3.0
# sensor type -> CMOS
# shutter speed max -> 1/4000 sec
# shutter speed min -> 30 sec
# size -> 117 x 61 x 347 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> TFT LCD
# weight g -> 245
# Row: 43
# Columns: 43
# <page title> -> Samsung WB350F Digital Smart Camera - White (EC-WB350FBPWGB) - Wex Photographic
# an -> image is incorrect
# battery model -> SLB-10A Lithium-Ion
# cant find a -> related accessory
# card format -> microSD, microSDHC, microSDXC
# colour -> White
# connectivity -> Hi-Speed USB (USB2.0), Wi-Fi & NFC
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> 20 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, MP4
# flash type -> Built-in
# focal length tele -> 483
# focal length wide -> 23
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 3200
# iso min -> 80
# max aperture tele -> 5.9
# max aperture wide -> 2.8
# megapixels -> 16.3
# minimum focus distance -> 10 cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 21
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 460000
# screen size inches -> 3
# sensor size -> 1/1.23 Inch
# sensor type -> CMOS
# shutter speed max -> 1/2000 sec
# shutter speed min -> 1/8 sec
# size -> 114 x 65 x 25 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 3 Inch LCD
# weight g -> 276
# Row: 42
# Columns: 42
# <page title> -> Samsung WB350F Digital Smart Camera - Black (EC-WB350FBPBGB) - Wex Photographic
# an -> image is incorrect
# battery model -> SLB-10A Lithium-Ion
# cant find a -> related accessory
# card format -> microSD, microSDHC, microSDXC
# colour -> Black
# connectivity -> Hi-Speed USB (USB2.0), Wi-Fi & NFC
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> 20 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, MP4
# flash type -> Built-in
# focal length tele -> 483
# focal length wide -> 23
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 3200
# iso min -> 80
# max aperture tele -> 5.9
# max aperture wide -> 2.8
# megapixels -> 16.3
# minimum focus distance -> 10 cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 21
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 460000
# screen size inches -> 3
# sensor size -> 1/1.23 Inch
# sensor type -> CMOS
# shutter speed max -> 1/2000 sec
# shutter speed min -> 1/8 sec
# size -> 114 x 65 x 25 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 3 Inch LCD
# weight g -> 276
# Row: 42
# Columns: 42
# <page title> -> Olympus Stylus Tough TG-3 Digital Camera - Black (V104140BE000) - Wex Photographic
# an -> image is incorrect
# battery model -> LI-92B
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC, 36MB Internal Memory
# colour -> Black
# connectivity -> WiFi
# exposure modes -> 22 Scene Modes
# face detection technology -> Yes
# flash type -> Built in
# focal length tele -> 100
# focal length wide -> 25
# hd movie mode -> 1080p
# image stabilisation -> Yes
# iso max -> 6400
# iso min -> 0
# manufacturers link -> Click here
# max aperture tele -> 4.9
# max aperture wide -> 2
# megapixels -> 16
# minimum focus distance -> 3cm
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 4
# please add -> more image angles
# requires -> compatibility information
# screen resolution pixels -> 460000
# screen size inches -> 3
# sensor type -> BSI CMOS
# size -> 111 x 66 x 31 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 3 Inch LCD
# weight g -> 247
# Row: 37
# Columns: 37
#   4%|▍         | 1/24 [00:01<00:45,  1.96s/it]
# <page title> -> Nikon Coolpix L330 Digital Camera (VNA690E1) - Wex Photographic
# an -> image is incorrect
# battery model -> 4 x AA Alkaline Batteries or 4 x AA Ni-MH Batteries EN-MH2 or 4 x AA Lithium Batteries
# cant find a -> related accessory
# card format -> SD/SDHC/SDXC
# colour -> Black
# connectivity -> Hi-Speed USB (USB2.0), A/V
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> 19 Scene Modes
# face detection technology -> Yes
# file formats -> 460000
# flash type -> Pop-up
# focal length tele -> 585
# focal length wide -> 22.5
# image stabilisation -> Yes
# iso max -> 1600
# iso min -> 80
# manufacturers link -> Click here
# max aperture tele -> 9.9
# max aperture wide -> 3.1
# megapixels -> 20.2
# minimum focus distance -> 1 cm
# movie mode -> 720p
# needs additional -> specifications
# optical zoom x -> 26
# please add -> more image angles
# requires -> compatibility information
# resolution -> 5152 x 3864
# screen resolution pixels -> 0
# screen size inches -> 3
# sensor type -> CCD
# shutter speed max -> 1/1500 sec
# shutter speed min -> 4 sec
# size -> 111 x 76 x 83 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 3 Inch TFT
# weight g -> 430
# Row: 41
# Columns: 41
# <page title> -> Sony Cyber-Shot RX10 Digital Camera (DSCRX10.CEH) - Wex Photographic
# an -> image is incorrect
# battery model -> NP-FW50
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC, Memory Stick
# colour -> Black
# connectivity -> USB 2.0, micro-HDMI, NFC
# exposure control -> +/- 3.0EV
# face detection technology -> Yes
# file formats -> JPEG, RAW, MPEG-4, AVCHD
# focal length tele -> 200
# focal length wide -> 24
# image stabilisation -> Yes
# iso max -> 12800
# iso min -> 125
# max aperture tele -> 2.8
# max aperture wide -> 2.8
# megapixels -> 20.2
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 8.3
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 5472 x 3648
# screen resolution pixels -> 1290000
# screen size inches -> 3.0
# sensor size -> 13.2 x 8.8 mm
# sensor type -> BSI-CMOS
# shutter speed max -> 1/3200 sec
# shutter speed min -> 30 sec
# size -> 129 x 88 x 102 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> 3.0 inch WhiteMagic LCD
# weight g -> 813
# Row: 39
# Columns: 39
# <page title> -> Canon PowerShot SX60 HS Digital Camera (9543B009AA) - Wex Photographic
# an -> image is incorrect
# battery model -> NB-10L
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Black
# connectivity -> USB, Wi-Fi, NFC
# face detection technology -> Yes
# file formats -> JPEG, JPEG + RAW
# flash type -> Built-in
# focal length tele -> 1365
# focal length wide -> 21
# image stabilisation -> Yes
# iso max -> 6400
# iso min -> 100
# max aperture tele -> 6.5
# max aperture wide -> 3.4
# megapixels -> 16.1
# movie mode -> 1080p
# needs additional -> specifications
# optical zoom x -> 65
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 2592
# screen resolution pixels -> 922000
# screen size inches -> 3.0
# sensor size -> 1/2.3 inch
# sensor type -> CMOS
# shutter speed max -> 1/2000 sec
# shutter speed min -> 15 sec
# size -> 127.6 x 92.6 x 114.3 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> Electronic Viewfinder
# weight g -> 607
# Row: 39
# Columns: 39
# <page title> -> Canon PowerShot SX600 HS Digital Camera - Black (9340B012AA) - Wex Photographic
# an -> image is incorrect
# battery model -> NB-6LH
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Black
# connectivity -> Hi-Speed USB, HDMI Micor Connector, Wi-Fi
# exposure control -> +/- 2.0EV, 1/3EV step
# exposure modes -> 32 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, MP4
# flash metering -> Auto, Manual Flash On / Off, Slow Synchro
# flash type -> Built-in
# focal length tele -> 450
# focal length wide -> 25
# image stabilisation -> Yes
# iso max -> 3200
# iso min -> 100
# manufacturers link -> Click here
# max aperture tele -> 6.9
# max aperture wide -> 3.8
# megapixels -> 16.0
# minimum focus distance -> 5cm
# movie mode -> 1080p HD
# needs additional -> specifications
# optical zoom x -> 18.0
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4608 x 3456
# screen resolution pixels -> 461000
# screen size inches -> 3.0
# sensor size -> 1/2.3 inch
# sensor type -> CMOS
# shutter speed max -> 1/2000 sec
# shutter speed min -> 15 sec
# size -> 103.8 x 61.0 x 26.0 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> LCD
# weight g -> 188
# Row: 44
# Columns: 44
# <page title> -> Panasonic LUMIX DMC-LX100 Digital Camera - Black (DMC-LX100EBK ) - Wex Photographic
# an -> image is incorrect
# cant find a -> related accessory
# card format -> SD, SDHC, SDXC
# colour -> Black
# connectivity -> USB 2.0, microHDMI
# exposure control -> +/- 3.0EV 1/3 Step
# face detection technology -> Yes
# flash type -> Built-in
# focal length tele -> 120
# focal length wide -> 24
# image stabilisation -> Yes
# iso max -> 25600
# iso min -> 100
# max aperture tele -> 2.8
# max aperture wide -> 1.7
# megapixels -> 12.8
# minimum focus distance -> 3cm
# movie mode -> 4K
# needs additional -> specifications
# optical zoom x -> 3.1
# pictbridge -> Yes
# please add -> more image angles
# requires -> compatibility information
# resolution -> 4112 x 3088
# screen resolution pixels -> 0
# screen size inches -> 3.0
# sensor size -> 17.3 x 13 mm
# sensor type -> CMOS
# shutter speed max -> 1/16000 sec
# shutter speed min -> 60 sec
# size -> 116 x 74 x 66 mm
# the description needs -> further detail
# the information is -> incorrect
# viewfinder type -> Electronic Viewfinder
# weight g -> 553
# Row: 39
# Columns: 39
# <page title> -> Nikon Coolpix S3600 Digital Camera - Silver (VNA550E1) - Wex Photographic
# an -> image is incorrect
# battery model -> EN-EL19
# cant find a -> related accessory
# card format -> 25MB Internal, SD, SDHC, SDXC
# colour -> Silver
# connectivity -> Hi-Speed USB (USB2.0)
# exposure control -> Â±2.0EV 1/3EV step
# exposure modes -> 18 Scene Modes
# face detection technology -> Yes
# file formats -> JPEG, MOV, WAV
# flash type -> Built in
# focal length tele -> 200
# focal length wide -> 25
# hd movie mode -> 720p
# image stabilisation -> Yes
# iso max -> 3200
# iso min -> 80
# manufacturers link -> Click here
# max aperture tele -> 10.5
# max aperture wide -> 3.7
# megapixels -> 20.1
# minimum focus distance -> 2 cm
# movie mode -> 720p HD
# needs additional -> specifications
# optical zoom x -> 8
# please add -> more image angles
# requires -> compatibility information
# resolution -> 5152 x 3864
# screen resolution pixels -> 230000
# screen size inches -> 2.7
# sensor size -> 1/1.23 Inch
# sensor type -> CCD
# shutter speed max -> 1/1500 sec
# shutter speed min -> 4 sec
# size -> 97 x 58 x 20 mm
# the description needs -> further detail
# the information is -> incorrect
# weight g -> 125
# Row: 42
# Columns: 42
# <page title> -> Pentax WG 10 Point & Shoot Camera best price in India 2014, Specs and Review | Valid in Delhi, Mumbai, Bangalore, Hyderabad, Chennai, Kolkata, Ahmedabad, Surat | Price-Hunt
# additional features -> Voice Memo, Index (6 or 12 Thumbnails), Cropping, Protect, Movie Edit: Save as Still Image, Dpof, ink Rubbing Filter, Image / Sound Copy, Image Stabilization: Still - Pixel Track sr, Small Face Filter, Weather Resistant: jis Class 8 Waterproof Submersible to 33ft, Original Frame, Natural, Date-Time, Frame Composite, Histogram, Magnification, Movie: Movie Shake Reduction Mode (Movie Sr), Sound Playback, Mode Pallet: Slideshow, Crushproof Construction with Stand Weights Upto 220 lbf (Pound-Force), Operating Temperature: 10Â° c - 40Â° c (Coldproof), set Automatically) 0.4x, High Sensitivity Anti-Shake Mode (Digital Sr), Digital Filter (Black and White / Sepia, toy Camera, Retro, Color, Extract Color, Color Emphasis, High Contrast, Starburst, Soft, Fish-Eye, Brightness Filter, Miniature), Folder Display, Calendar, Scrollable, add Title Picture, Interface : pc / AV Terminal, Digital Filters (Capture): Image Tone (Bright, Startup Screen, Face Close up Playback, Movie Divide, Collage, Movie Playback, Monochrome), Playback Modes: Mode Selection: one Shot, Blur-Free Images, HDMI Terminal (Type d), Image Rotation, Select and Delete, Movie Edit, jis Class 6 Dustproof, Magnification: Upto 10x, Resize, Timing: Startup - 1.3 Sec, ), Digital Shake Reduction Ensure Sharp, Time (not Available in Green Mode), Minimum Aperture: f4.2 (w) - f6.6 (t, 1 cm Macro: 0.03 (1cm) to 0.98ft (at Mid-Zoom, Red-eye Compensation, Shockproof 4.9ft, Date Stamp: Date, Release lag - 0.037 Sec, Construction Material (s): Reinforced Polycarbonate Plastic with Aluminum Accents
# aperture range -> ), f3.5 (w) - f5.5 (t
# audio formats -> Pcm, WAV, Monaural
# audio video interface -> Ntsc, pal
# auto focus -> Ttl Contrast Detection af
# battery type -> Lithium Battery
# blink detection -> Blink Detection
# brand -> Pentax
# built in flash -> Built in Flash
# continuous shots -> Continuous Shots
# digital zoom -> 6.7x
# dimensions -> ) x 27.94 (d) mm, 114.3 (w) x 58.42 (h
# drive modes -> Auto Bracket Continuous, Optional), Shooting: 2.27 fps for 19 Frames (5 m or 4 m) 5.26 fps for 19 Frames at iso 3200 - 6400 (5 m or 4 m, ) Self-Timer, Interval, Continuous, Remote Control, Remote Control (Immediate 3 Sec) Remote Control: (Infrared, Self-Timer, Burst (5 m or 4 m), Shooting: 0.68 fps High-Speed Continuous, Mode Selection: one Shot
# dynamic range adjustment -> Highlight, Shadow Correction
# exposure compensation -> 1/3 ev Steps +/- 2 ev
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-ad19157d4f4b> in <module>
# ----> 1 df = create_dataframe('../datasets/unlabeled/2013_camera_specs')
#
# <ipython-input-40-a6f0bbacbb0b> in create_dataframe(dataset_path)
#      28                 attrs = []
#      29                 for k, v in specification_data.items():
# ---> 30                     print(k + ' -> ' + v)
#      31                     columns_df.append(k)
#      32                     attrs.append(v)
#
# TypeError: can only concatenate str (not "list") to str

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
